# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import os
import sys
import json
from matplotlib import pyplot as plt

# %%
poptypeNumber = 55 # max 55
celltypeNumber = 207 # max 207
#------------------------------------------------------------------------------  
# Load 55 Morphological Names and Cell pop numbers -> L1:6 L23:10 L4:12 L5:13 L6:14
# Load 207 Morpho-electrical Names used to import the cells from 'cell_data/' -> L1:14 L23:43 L4:46 L5:52 L6:52
# Create [Morphological,Electrical] = number of cell metype in the sub-pop   

with open('../info/anatomy/S1-cells-distributions-Rat.txt') as mtype_file:
    mtype_content = mtype_file.read()       

n2 = 0
metag = {}
popNumber2 = {}
cellNumber = {} 
popLabel = {} 
popParam = []
cellParam = []
meParamLabels = {} 
for line in mtype_content.split('\n')[:-1]:
	metype, mtype, etype, n, m = line.split()
	cellNumber[metype] = int(n)
	popLabel[metype] = mtype
	popNumber2[mtype] = int(m)
	metag[metype] = n2;    n2 = n2 + 1

	if mtype not in popParam:
		popParam.append(mtype)
	cellParam.append(metype)

# %%
rootFolder = '/home/fernando/Downloads/hoc_combos_syn.1_0_10.allzips/'
os.chdir(rootFolder)
folder = os.listdir(rootFolder)
folder = sorted(folder)

# %%
folder = ['L23_PC_cADpyr229_1',
 'L23_PC_cADpyr229_2',
 'L23_PC_cADpyr229_3',
 'L23_PC_cADpyr229_4',
 'L23_PC_cADpyr229_5']

# %%
Epops = ['L23_PC', 'L4_PC', 'L4_SS', 'L4_SP', 
             'L5_TTPC1', 'L5_TTPC2', 'L5_STPC', 'L5_UTPC',
             'L6_TPC_L1', 'L6_TPC_L4', 'L6_BPC', 'L6_IPC', 'L6_UTPC']

Ipops = []
for popName in popParam:
    if popName not in Epops:
        Ipops.append(popName)

# %%
values_GABAB_ratio = {}
for pre in Ipops:
    values_GABAB_ratio[pre] = {}
    for post in popParam:
        values_GABAB_ratio[pre][post] = []       
        
for popName in folder:
    cellName = popName[:-2]
    #------------------------------------------------------------------------------
    with open(rootFolder + popName + '/synapses/mtype_map.tsv') as mtype_map_file:
        mtype_map_content = mtype_map_file.read()

    mtype_map = {}
    mtype_map2 = {}
    for line in mtype_map_content.split('\n')[:-1]:
        n, mtype = line.split()
        mtype_map[mtype] = int(n)
        mtype_map2[int(n)] = mtype

    #------------------------------------------------------------------------------
    with open(rootFolder + popName + '/synapses/synapses.tsv') as mtype_map_file:
        mtype_map_content2 = mtype_map_file.read()
        
    parameters_name = {}

    parameters_name[0] = 'synapse_id'
    parameters_name[1] = 'pre_cell_id'
    parameters_name[2] = 'pre_mtype'
    parameters_name[3] = 'sectionlist_id'
    parameters_name[4] = 'sectionlist_index'
    parameters_name[5] = 'seg_x'
    parameters_name[6] = 'synapse_type'
    parameters_name[7] = 'dep'
    parameters_name[8] = 'fac'
    parameters_name[9] = 'use'
    parameters_name[10] = 'tau_d'
    parameters_name[11] = 'delay'
    parameters_name[12] = 'weight'
    
    n = -1    
    parameters_syn = {}
    for line in mtype_map_content2.split('\n')[:-1]:
        if n < 0:
            nsynapses, nparameters = [int(x) for x in line.split()]        
#             print (popLabel[cellName],popName,nsynapses, nparameters)
        else:
            n2 = 0
            parameters_list = line.split()   
            for parameter in parameters_list:
                if n2 < 7:
                    prmtr = float(parameter)
                    parameters_syn[n,parameters_name[n2]] = int(prmtr)
                else:
                    parameters_syn[n,parameters_name[n2]] = float(parameter)
                n2 = n2 + 1
        n = n + 1
    #------------------------------------------------------------------------------
            
    with open(rootFolder + popName + '/synapses/synconf.txt') as mtype_map_file:
        mtype_map_content3 = mtype_map_file.read()

    previousline = 'nan'
    for line in mtype_map_content3.split('\n')[:-1]:
        
        if previousline == 'GABAB_ratio':
            parameters_list = line.split()  
            for parameter in parameters_list[:-1]:
                pre = mtype_map2[parameters_syn[int(parameter),'pre_mtype']]
                post = popLabel[cellName]
                values_GABAB_ratio[pre][post].append(float(parvalues.split('=')[1]))
#                 if pre == 'L4_SP' and post == 'L4_SP':
#                     print(pre,post,'GABAB_ratio =',float(parvalues.split('=')[1]),parameters_syn[int(parameter),'synapse_id'])
        
        if '=' in line:
            for parvalues in line.split('%s.')[1:]:
                if 'GABAB_ratio' in parvalues.split('=')[0]:
                    if parvalues.split('=')[1] != ' 1.0':
#                         print(parvalues.split('=')[0],'=',parvalues.split('=')[1])
                        previousline = 'GABAB_ratio'
        else:
            previousline = 'nan'
            

    #         parameters_list = line.split()
    #     if '.mg' in line:
    #         previousline = 'mg'
    #         print(line.split(' = ')[-1])
    #         print(np.size(line.split()))

# %%
value_GABAB_ratio = {}
for pre in Ipops+Epops:
    value_GABAB_ratio[pre] = {}
    for post in Epops+Ipops:
        value_GABAB_ratio[pre][post] = 0

for pre in Ipops:
    for post in Epops+Ipops:
        if np.size(values_GABAB_ratio[pre][post])>0:
            value_GABAB_ratio[pre][post] = values_GABAB_ratio[pre][post][-1]
            print('%s:%s %.2f %.2f %.2f' % (pre,post,np.mean(values_GABAB_ratio[pre][post]),np.std(values_GABAB_ratio[pre][post]),values_GABAB_ratio[pre][post][-1]))
# Out:
# L1_DAC:L23_PC 0.75 0.00 0.75
# L1_DAC:L4_PC 0.75 0.00 0.75
# L1_DAC:L4_SS 0.75 0.00 0.75
# L1_DAC:L4_SP 0.75 0.00 0.75
# L1_DAC:L5_TTPC1 0.75 0.00 0.75
# L1_DAC:L5_TTPC2 0.75 0.00 0.75
# L1_DAC:L5_STPC 0.75 0.00 0.75
# L1_DAC:L6_TPC_L1 0.75 0.00 0.75
# L1_DLAC:L4_SP 0.75 0.00 0.75
# L1_DLAC:L5_TTPC1 0.75 0.00 0.75
# L1_DLAC:L5_TTPC2 0.75 0.00 0.75
# L1_DLAC:L5_STPC 0.75 0.00 0.75
# L1_HAC:L23_PC 0.75 0.00 0.75
# L1_HAC:L4_SP 0.75 0.00 0.75
# L1_HAC:L5_TTPC1 0.75 0.00 0.75
# L1_HAC:L5_TTPC2 0.75 0.00 0.75
# L1_HAC:L5_STPC 0.75 0.00 0.75
# L1_NGC-DA:L23_PC 0.75 0.00 0.75
# L1_NGC-DA:L4_SP 0.75 0.00 0.75
# L1_NGC-DA:L5_TTPC1 0.75 0.00 0.75
# L1_NGC-DA:L5_TTPC2 0.75 0.00 0.75
# L1_NGC-DA:L5_STPC 0.75 0.00 0.75
# L1_NGC-SA:L5_TTPC1 0.75 0.00 0.75
# L1_NGC-SA:L5_TTPC2 0.75 0.00 0.75
# L1_NGC-SA:L5_STPC 0.75 0.00 0.75
# L1_SLAC:L5_TTPC2 0.75 0.00 0.75
# L1_SLAC:L5_STPC 0.75 0.00 0.75
# L23_NGC:L23_PC 0.75 0.00 0.75
# L23_NGC:L4_PC 0.75 0.00 0.75
# L23_NGC:L4_SS 0.75 0.00 0.75
# L23_NGC:L5_TTPC1 0.75 0.00 0.75
# L23_NGC:L5_STPC 0.75 0.00 0.75
# L23_NGC:L6_TPC_L4 0.75 0.00 0.75

# %%
value_GABAB_ratio
# Out:
# {'L1_DAC': {'L23_PC': 0.75,
#   'L4_PC': 0.75,
#   'L4_SS': 0.75,
#   'L4_SP': 0.75,
#   'L5_TTPC1': 0.75,
#   'L5_TTPC2': 0.75,
#   'L5_STPC': 0.75,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0.75,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L1_DLAC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0.75,
#   'L5_TTPC1': 0.75,
#   'L5_TTPC2': 0.75,
#   'L5_STPC': 0.75,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L1_HAC': {'L23_PC': 0.75,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0.75,
#   'L5_TTPC1': 0.75,
#   'L5_TTPC2': 0.75,
#   'L5_STPC': 0.75,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L1_NGC-DA': {'L23_PC': 0.75,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0.75,
#   'L5_TTPC1': 0.75,
#   'L5_TTPC2': 0.75,
#   'L5_STPC': 0.75,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L1_NGC-SA': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0.75,
#   'L5_TTPC2': 0.75,
#   'L5_STPC': 0.75,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L1_SLAC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0.75,
#   'L5_STPC': 0.75,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L23_BP': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L23_BTC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L23_ChC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L23_DBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L23_LBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L23_MC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L23_NBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L23_NGC': {'L23_PC': 0.75,
#   'L4_PC': 0.75,
#   'L4_SS': 0.75,
#   'L4_SP': 0,
#   'L5_TTPC1': 0.75,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0.75,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0.75,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L23_SBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_BP': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_BTC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_ChC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_DBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_LBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_MC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_NBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_NGC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_SBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_BP': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_BTC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_ChC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_DBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_LBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_MC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_NBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_NGC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_SBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_BP': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_BTC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_ChC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_DBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_LBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_MC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_NBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_NGC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_SBC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L23_PC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_PC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_SS': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L4_SP': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_TTPC1': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_TTPC2': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_STPC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L5_UTPC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_TPC_L1': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_TPC_L4': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_BPC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_IPC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0},
#  'L6_UTPC': {'L23_PC': 0,
#   'L4_PC': 0,
#   'L4_SS': 0,
#   'L4_SP': 0,
#   'L5_TTPC1': 0,
#   'L5_TTPC2': 0,
#   'L5_STPC': 0,
#   'L5_UTPC': 0,
#   'L6_TPC_L1': 0,
#   'L6_TPC_L4': 0,
#   'L6_BPC': 0,
#   'L6_IPC': 0,
#   'L6_UTPC': 0,
#   'L1_DAC': 0,
#   'L1_DLAC': 0,
#   'L1_HAC': 0,
#   'L1_NGC-DA': 0,
#   'L1_NGC-SA': 0,
#   'L1_SLAC': 0,
#   'L23_BP': 0,
#   'L23_BTC': 0,
#   'L23_ChC': 0,
#   'L23_DBC': 0,
#   'L23_LBC': 0,
#   'L23_MC': 0,
#   'L23_NBC': 0,
#   'L23_NGC': 0,
#   'L23_SBC': 0,
#   'L4_BP': 0,
#   'L4_BTC': 0,
#   'L4_ChC': 0,
#   'L4_DBC': 0,
#   'L4_LBC': 0,
#   'L4_MC': 0,
#   'L4_NBC': 0,
#   'L4_NGC': 0,
#   'L4_SBC': 0,
#   'L5_BP': 0,
#   'L5_BTC': 0,
#   'L5_ChC': 0,
#   'L5_DBC': 0,
#   'L5_LBC': 0,
#   'L5_MC': 0,
#   'L5_NBC': 0,
#   'L5_NGC': 0,
#   'L5_SBC': 0,
#   'L6_BP': 0,
#   'L6_BTC': 0,
#   'L6_ChC': 0,
#   'L6_DBC': 0,
#   'L6_LBC': 0,
#   'L6_MC': 0,
#   'L6_NBC': 0,
#   'L6_NGC': 0,
#   'L6_SBC': 0}}
