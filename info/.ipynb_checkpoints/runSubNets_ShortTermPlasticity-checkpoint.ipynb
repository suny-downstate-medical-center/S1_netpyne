# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
## collab user
# !pip install neuron
# !pip install netpyne
# !git clone https://github.com/suny-downstate-medical-center/S1_netpyne.git
# import os
# os.chdir('S1_netpyne/info')

# %%
import matplotlib
import os
os.chdir('../sim')

# %%
# !nrnivmodl mod/

# %%
"""
cfg.py 

Simulation configuration for S1 model (using NetPyNE)
This file has sim configs as well as specification for parameterized values in netParams.py 

Contributors: salvadordura@gmail.com, fernandodasilvaborges@gmail.com
"""

from netpyne import specs, sim
import pickle, json
import numpy as np

# %matplotlib inline

cfg = specs.SimConfig()  

#------------------------------------------------------------------------------
#
# SIMULATION CONFIGURATION
#
#------------------------------------------------------------------------------

#------------------------------------------------------------------------------
# Run parameters
#------------------------------------------------------------------------------
cfg.duration = 1.0*1e3 ## Duration of the sim, in ms  
cfg.dt = 0.025
cfg.seeds = {'conn': 4321, 'stim': 4321, 'loc': 4321} 
cfg.hParams = {'celsius': 34, 'v_init': -65}  
cfg.verbose = True
cfg.createNEURONObj = True
cfg.createPyStruct = True  
cfg.cvode_active = False
cfg.cvode_atol = 1e-6
cfg.cache_efficient = True
cfg.printRunTime = 0.1

cfg.includeParamsLabel = False
cfg.printPopAvgRates = True

cfg.checkErrors = True

cfg.poptypeNumber = 55
cfg.celltypeNumber = 207

cfg.rootFolder = os.getcwd()

# %%
#------------------------------------------------------------------------------  
# S1 Cells
# Load 55 Morphological Names and Cell pop numbers -> L1:6 L23:10 L4:12 L5:13 L6:14
# Load 207 Morpho-electrical Names used to import the cells from 'cell_data/' -> L1:14 L23:43 L4:46 L5:52 L6:52
# Create [Morphological,Electrical] = number of cell metype in the sub-pop

with open('../info/anatomy/S1-cells-distributions-Rat.txt') as mtype_file:
    mtype_content = mtype_file.read()       

cfg.popNumber = {}
cfg.cellNumber = {} 
cfg.popLabel = {} 
popParam = []
cellParam = []
cfg.meParamLabels = {} 
cfg.popLabelEl = {} 
cfg.cellLabel = {}

for line in mtype_content.split('\n')[:-1]:
    cellname, mtype, etype, n, m = line.split()
    metype = mtype + '_' + etype[0:3]
    cfg.cellNumber[metype] = int(n)
    cfg.popLabel[metype] = mtype
    cfg.popNumber[mtype] = int(m)
    cfg.cellLabel[metype] = cellname

    if mtype not in popParam:
        popParam.append(mtype)
        cfg.popLabelEl[mtype] = [] 
               
    cfg.popLabelEl[mtype].append(metype)
    
    cellParam.append(mtype + '_' + etype[0:3])
    
cfg.S1pops = popParam
cfg.S1cells = cellParam

cfg.popParamLabels = popParam
cfg.cellParamLabels = cellParam
#------------------------------------------------------------------------------  
# number=0
# for mtype in cfg.S1pops:
#     for cellEl in range(np.size(cfg.popLabelEl[mtype])):
#         number+=1
#         print(number,cfg.popLabelEl[mtype][cellEl], cfg.popLabel[cfg.popLabelEl[mtype][cellEl]], popLabelEl[cfg.popLabelEl[mtype][cellEl]])

# %%
#------------------------------------------------------------------------------
# Cells
#------------------------------------------------------------------------------

# TO DEBUG - import and simulate only the Cell soma (to study only the Net)
cfg.reducedtest = False    

# TO DEBUG - Create only 5 Cells for each MEtype in S1
cfg.oneCellperMEtypeS1 = True

# %%
#------------------------------------------------------------------------------  
# TO DEBUG - Create only one Cell per MEtype in S1 cells
if cfg.oneCellperMEtypeS1:
	cfg.popNumber = {}
	cfg.cellNumber = {} 
	for mtype in cfg.S1pops:
		cfg.popNumber[mtype] = 0

	for line in mtype_content.split('\n')[:-1]:
		cellname, mtype, etype, n, m = line.split()
		metype = mtype + '_' + etype[0:3]
		if int(n) < 5:
			cfg.cellNumber[metype] = int(n)
			cfg.popNumber[mtype] = cfg.popNumber[mtype] + int(n)
		else:
			cfg.cellNumber[metype] = 5
			cfg.popNumber[mtype] = cfg.popNumber[mtype] + 5

# %%
# testpop = ['L4_SS', 'L5_STPC', 'L5_UTPC', 'L23_LBC', 'L23_MC', 'L4_LBC', 'L4_MC', 'L5_LBC', 'L5_MC']
# Nsyn=513042, N=2684

# 'L5_LBC': 210,
# 'L5_MC': 395,
# 'L5_TTPC2': 2003,

# %%
# popParam = popParam[6:16]
# cellParam = cellParam[14:57]

cfg.S1pops = popParam
cfg.S1cells = cellParam

cfg.popParamLabels = popParam
cfg.cellParamLabels = cellParam

# %%
# subPopLabels = ['L5_LBC','L5_MC', 'L5_TTPC2']
subPopLabels = cfg.S1pops
for metype in cfg.cellParamLabels:
    if cfg.popLabel[metype] in subPopLabels:
        print(metype,cfg.cellNumber[metype],cfg.popLabel[metype],cfg.popNumber[cfg.popLabel[metype]])
# Out:
# L1_DAC_bNA 5 L1_DAC 10
# L1_DAC_cNA 5 L1_DAC 10
# L1_DLAC_cNA 5 L1_DLAC 5
# L1_HAC_bNA 5 L1_HAC 15
# L1_HAC_cIR 5 L1_HAC 15
# L1_HAC_cNA 5 L1_HAC 15
# L1_NGC-DA_bNA 5 L1_NGC-DA 20
# L1_NGC-DA_cAC 5 L1_NGC-DA 20
# L1_NGC-DA_cNA 5 L1_NGC-DA 20
# L1_NGC-DA_cST 5 L1_NGC-DA 20
# L1_NGC-SA_cNA 5 L1_NGC-SA 5
# L1_SLAC_bNA 5 L1_SLAC 15
# L1_SLAC_cAC 5 L1_SLAC 15
# L1_SLAC_cNA 5 L1_SLAC 15
# L23_BP_bAC 3 L23_BP 24
# L23_BP_bIR 4 L23_BP 24
# L23_BP_bNA 5 L23_BP 24
# L23_BP_cAC 5 L23_BP 24
# L23_BP_cNA 4 L23_BP 24
# L23_BP_dST 3 L23_BP 24
# L23_BTC_bAC 5 L23_BTC 25
# L23_BTC_bIR 5 L23_BTC 25
# L23_BTC_bNA 5 L23_BTC 25
# L23_BTC_cAC 5 L23_BTC 25
# L23_BTC_cNA 5 L23_BTC 25
# L23_ChC_cAC 5 L23_ChC 15
# L23_ChC_cNA 5 L23_ChC 15
# L23_ChC_dNA 5 L23_ChC 15
# L23_DBC_bAC 5 L23_DBC 20
# L23_DBC_bIR 5 L23_DBC 20
# L23_DBC_bNA 5 L23_DBC 20
# L23_DBC_cAC 5 L23_DBC 20
# L23_LBC_bAC 5 L23_LBC 30
# L23_LBC_bNA 5 L23_LBC 30
# L23_LBC_cAC 5 L23_LBC 30
# L23_LBC_cNA 5 L23_LBC 30
# L23_LBC_cST 5 L23_LBC 30
# L23_LBC_dNA 5 L23_LBC 30
# L23_MC_bAC 5 L23_MC 25
# L23_MC_bNA 5 L23_MC 25
# L23_MC_cAC 5 L23_MC 25
# L23_MC_cNA 5 L23_MC 25
# L23_MC_dNA 5 L23_MC 25
# L23_NBC_bAC 5 L23_NBC 30
# L23_NBC_bNA 5 L23_NBC 30
# L23_NBC_cAC 5 L23_NBC 30
# L23_NBC_cIR 5 L23_NBC 30
# L23_NBC_cNA 5 L23_NBC 30
# L23_NBC_dNA 5 L23_NBC 30
# L23_NGC_bNA 5 L23_NGC 20
# L23_NGC_cAC 5 L23_NGC 20
# L23_NGC_cNA 5 L23_NGC 20
# L23_NGC_cST 5 L23_NGC 20
# L23_PC_cAD 5 L23_PC 5
# L23_SBC_bNA 5 L23_SBC 15
# L23_SBC_cAC 5 L23_SBC 15
# L23_SBC_dNA 5 L23_SBC 15
# L4_BP_bAC 1 L4_BP 8
# L4_BP_bIR 1 L4_BP 8
# L4_BP_bNA 2 L4_BP 8
# L4_BP_cAC 2 L4_BP 8
# L4_BP_cNA 1 L4_BP 8
# L4_BP_dST 1 L4_BP 8
# L4_BTC_bAC 2 L4_BTC 16
# L4_BTC_bIR 2 L4_BTC 16
# L4_BTC_bST 2 L4_BTC 16
# L4_BTC_cAC 5 L4_BTC 16
# L4_BTC_cNA 3 L4_BTC 16
# L4_BTC_dNA 2 L4_BTC 16
# L4_ChC_cAC 3 L4_ChC 8
# L4_ChC_cNA 3 L4_ChC 8
# L4_ChC_dNA 2 L4_ChC 8
# L4_DBC_bAC 4 L4_DBC 30
# L4_DBC_bIR 5 L4_DBC 30
# L4_DBC_bNA 4 L4_DBC 30
# L4_DBC_bST 4 L4_DBC 30
# L4_DBC_cAC 4 L4_DBC 30
# L4_DBC_cIR 5 L4_DBC 30
# L4_DBC_cNA 4 L4_DBC 30
# L4_LBC_cAC 5 L4_LBC 25
# L4_LBC_cNA 5 L4_LBC 25
# L4_LBC_cST 5 L4_LBC 25
# L4_LBC_dNA 5 L4_LBC 25
# L4_LBC_dST 5 L4_LBC 25
# L4_MC_bAC 5 L4_MC 23
# L4_MC_bNA 4 L4_MC 23
# L4_MC_cAC 5 L4_MC 23
# L4_MC_cNA 5 L4_MC 23
# L4_MC_dNA 4 L4_MC 23
# L4_NBC_cAC 5 L4_NBC 20
# L4_NBC_cIR 5 L4_NBC 20
# L4_NBC_cNA 5 L4_NBC 20
# L4_NBC_dNA 5 L4_NBC 20
# L4_NGC_bNA 1 L4_NGC 6
# L4_NGC_cAC 1 L4_NGC 6
# L4_NGC_cNA 3 L4_NGC 6
# L4_NGC_cST 1 L4_NGC 6
# L4_PC_cAD 5 L4_PC 5
# L4_SBC_bNA 5 L4_SBC 15
# L4_SBC_cAC 5 L4_SBC 15
# L4_SBC_dNA 5 L4_SBC 15
# L4_SP_cAD 5 L4_SP 5
# L4_SS_cAD 5 L4_SS 5
# L5_BP_bAC 3 L5_BP 26
# L5_BP_bIR 5 L5_BP 26
# L5_BP_bNA 5 L5_BP 26
# L5_BP_cAC 5 L5_BP 26
# L5_BP_cNA 5 L5_BP 26
# L5_BP_dST 3 L5_BP 26
# L5_BTC_bAC 5 L5_BTC 15
# L5_BTC_cAC 5 L5_BTC 15
# L5_BTC_cNA 5 L5_BTC 15
# L5_ChC_cAC 5 L5_ChC 15
# L5_ChC_cNA 5 L5_ChC 15
# L5_ChC_dNA 5 L5_ChC 15
# L5_DBC_bAC 5 L5_DBC 35
# L5_DBC_bIR 5 L5_DBC 35
# L5_DBC_bNA 5 L5_DBC 35
# L5_DBC_bST 5 L5_DBC 35
# L5_DBC_cAC 5 L5_DBC 35
# L5_DBC_cIR 5 L5_DBC 35
# L5_DBC_cNA 5 L5_DBC 35
# L5_LBC_bAC 5 L5_LBC 35
# L5_LBC_cAC 5 L5_LBC 35
# L5_LBC_cIR 5 L5_LBC 35
# L5_LBC_cNA 5 L5_LBC 35
# L5_LBC_cST 5 L5_LBC 35
# L5_LBC_dNA 5 L5_LBC 35
# L5_LBC_dST 5 L5_LBC 35
# L5_MC_bAC 5 L5_MC 35
# L5_MC_bIR 5 L5_MC 35
# L5_MC_bST 5 L5_MC 35
# L5_MC_cAC 5 L5_MC 35
# L5_MC_cNA 5 L5_MC 35
# L5_MC_cST 5 L5_MC 35
# L5_MC_dNA 5 L5_MC 35
# L5_NBC_bAC 5 L5_NBC 40
# L5_NBC_bIR 5 L5_NBC 40
# L5_NBC_bST 5 L5_NBC 40
# L5_NBC_cAC 5 L5_NBC 40
# L5_NBC_cIR 5 L5_NBC 40
# L5_NBC_cNA 5 L5_NBC 40
# L5_NBC_cST 5 L5_NBC 40
# L5_NBC_dST 5 L5_NBC 40
# L5_NGC_bNA 1 L5_NGC 8
# L5_NGC_cAC 1 L5_NGC 8
# L5_NGC_cNA 5 L5_NGC 8
# L5_NGC_cST 1 L5_NGC 8
# L5_SBC_bNA 5 L5_SBC 15
# L5_SBC_cAC 5 L5_SBC 15
# L5_SBC_dNA 5 L5_SBC 15
# L5_STPC_cAD 5 L5_STPC 5
# L5_TTPC1_cAD 5 L5_TTPC1 5
# L5_TTPC2_cAD 5 L5_TTPC2 5
# L5_UTPC_cAD 5 L5_UTPC 5
# L6_BPC_cAD 5 L6_BPC 5
# L6_BP_bAC 5 L6_BP 30
# L6_BP_bIR 5 L6_BP 30
# L6_BP_bNA 5 L6_BP 30
# L6_BP_cAC 5 L6_BP 30
# L6_BP_cNA 5 L6_BP 30
# L6_BP_dST 5 L6_BP 30
# L6_BTC_bAC 5 L6_BTC 15
# L6_BTC_cAC 5 L6_BTC 15
# L6_BTC_cNA 5 L6_BTC 15
# L6_ChC_cAC 5 L6_ChC 14
# L6_ChC_cNA 5 L6_ChC 14
# L6_ChC_dNA 4 L6_ChC 14
# L6_DBC_bAC 3 L6_DBC 25
# L6_DBC_bIR 5 L6_DBC 25
# L6_DBC_bNA 3 L6_DBC 25
# L6_DBC_bST 3 L6_DBC 25
# L6_DBC_cAC 3 L6_DBC 25
# L6_DBC_cIR 5 L6_DBC 25
# L6_DBC_cNA 3 L6_DBC 25
# L6_IPC_cAD 5 L6_IPC 5
# L6_LBC_bAC 5 L6_LBC 30
# L6_LBC_bIR 5 L6_LBC 30
# L6_LBC_bNA 5 L6_LBC 30
# L6_LBC_bST 5 L6_LBC 30
# L6_LBC_cNA 5 L6_LBC 30
# L6_LBC_cST 5 L6_LBC 30
# L6_MC_bAC 5 L6_MC 35
# L6_MC_bIR 5 L6_MC 35
# L6_MC_bNA 5 L6_MC 35
# L6_MC_bST 5 L6_MC 35
# L6_MC_cAC 5 L6_MC 35
# L6_MC_cIR 5 L6_MC 35
# L6_MC_cNA 5 L6_MC 35
# L6_NBC_bAC 5 L6_NBC 40
# L6_NBC_bIR 5 L6_NBC 40
# L6_NBC_bST 5 L6_NBC 40
# L6_NBC_cAC 5 L6_NBC 40
# L6_NBC_cIR 5 L6_NBC 40
# L6_NBC_cNA 5 L6_NBC 40
# L6_NBC_cST 5 L6_NBC 40
# L6_NBC_dST 5 L6_NBC 40
# L6_NGC_bNA 2 L6_NGC 11
# L6_NGC_cAC 2 L6_NGC 11
# L6_NGC_cNA 5 L6_NGC 11
# L6_NGC_cST 2 L6_NGC 11
# L6_SBC_bNA 5 L6_SBC 15
# L6_SBC_cAC 5 L6_SBC 15
# L6_SBC_dNA 5 L6_SBC 15
# L6_TPC_L1_cAD 5 L6_TPC_L1 5
# L6_TPC_L4_cAD 5 L6_TPC_L4 5
# L6_UTPC_cAD 5 L6_UTPC 5

# %%
#------------------------------------------------------------------------------  
cfg.S1pops = subPopLabels
cfg.S1cells = []
for metype in cfg.cellParamLabels:
    if cfg.popLabel[metype] in subPopLabels:        
        cfg.S1cells.append(metype)
        
cfg.thalamicpops = []

cfg.popParamLabels = cfg.S1pops
cfg.cellParamLabels = cfg.S1cells

# %%
# subPopLabels = cfg.cellParamLabels

# %%
#--------------------------------------------------------------------------
# Recording 
#--------------------------------------------------------------------------
cfg.allpops = cfg.cellParamLabels
cfg.cellsrec = 2
if cfg.cellsrec == 0:  cfg.recordCells = cfg.allpops # record all cells
elif cfg.cellsrec == 1: cfg.recordCells = [(pop,0) for pop in cfg.allpops] # record one cell of each pop
elif cfg.cellsrec == 2: # record one cell of each cellMEtype
    cfg.recordCells = []
    for metype in cfg.cellParamLabels:
        if cfg.cellNumber[metype] < 5:
            for numberME in range(cfg.cellNumber[metype]):
                cfg.recordCells.append((metype,numberME))
        else:
            numberME = 0
            diference = cfg.cellNumber[metype] - 5.0*int(cfg.cellNumber[metype]/5.0)
            
            for number in range(5):            
                cfg.recordCells.append((metype,numberME))
                
                if number < diference:              
                    numberME+=int(np.ceil(cfg.cellNumber[metype]/5.0))  
                else:
                    numberME+=int(cfg.cellNumber[metype]/5.0)
                
        
cfg.recordTraces = {'V_soma': {'sec':'soma', 'loc':0.5, 'var':'v'}}  ## Dict with traces to record
cfg.recordStim = False
cfg.recordTime = False
cfg.recordStep = 0.1

# %%
#------------------------------------------------------------------------------
# Saving
#------------------------------------------------------------------------------
cfg.simLabel = 'subNets_test0'
cfg.saveFolder = '../info/test/'+cfg.simLabel
# cfg.filename =                	## Set file output name
cfg.savePickle = False         	## Save pkl file
cfg.saveJson = True	           	## Save json file
cfg.saveDataInclude = ['simConfig'] ## , 'netParams', 'simConfig', ,'simData'
cfg.backupCfgFile = None 		##  
cfg.gatherOnlySimData = False	##  
cfg.saveCellSecs = False			
cfg.saveCellConns = True

# %%
"""
netParams.py
"""
# Network parameters
netParams = specs.NetParams()  # object of class NetParams to store the network parameters

netParams.scale = 1.0 # Scale factor for number of cells
netParams.sizeX = 420.0 # x-dimension (horizontal length) size in um
netParams.sizeY = 2082.0 # y-dimension (vertical height or cortical depth) size in um
netParams.sizeZ = 420.0 # z-dimension (horizontal depth) size in um
netParams.shape = 'cylinder' # cylindrical (column-like) volume

# r = 210 um and hexagonal side length = 230.9 um

# %%
#------------------------------------------------------------------------------
# General network parameters
#------------------------------------------------------------------------------
# Layer	height (um)	height (norma)	from	to
# L1	165		    0.079		    0.000	0.079
# L2	149		    0.072		    0.079	0.151
# L3	353		    0.170		    0.151	0.320
# L4	190		    0.091		    0.320	0.412
# L5	525		    0.252		    0.412	0.664
# L6	700		    0.336		    0.664	1.000
# L23	502		    0.241		    0.079	0.320
# All	2082	    1.000	


cellModels = ['HH_full']
Epops = ['L23_PC', 'L4_PC', 'L4_SS', 'L4_SP', 
             'L5_TTPC1', 'L5_TTPC2', 'L5_STPC', 'L5_UTPC',
             'L6_TPC_L1', 'L6_TPC_L4', 'L6_BPC', 'L6_IPC', 'L6_UTPC']
Ipops = []
for popName in cfg.S1pops:
    if popName not in Epops:
        Ipops.append(popName)

Epops = []
for popName in cfg.S1pops:
    if popName not in Ipops:
        Epops.append(popName)   

layer = {'1':[0.0, 0.079], '2': [0.079,0.151], '3': [0.151,0.320], '23': [0.079,0.320], '4':[0.320,0.412], '5': [0.412,0.664], '6': [0.664,1.0], 
'longS1': [2.2,2.3], 'longS2': [2.3,2.4]}  # normalized layer boundaries

# %%
#------------------------------------------------------------------------------
# General connectivity parameters
#------------------------------------------------------------------------------
netParams.defaultThreshold = -10.0 # spike threshold, 10 mV is NetCon default, lower it for all cells
netParams.defaultDelay = 0.1 # default conn delay (ms)(M1: 2.0 ms)
netParams.propVelocity = 300.0 #  300 μm/ms (Stuart et al., 1997)(M1: 500.0um/ms)
# netParams.scaleConnWeight = 0.001 # weight conversion factor (from nS to uS)
netParams.scaleConnWeightNetStims = 0.001  # weight conversion factor (from nS to uS)

# %%
# #------------------------------------------------------------------------------
# # Cell parameters  # L1 70  L23 215  L4 230 L5 260  L6 260  = 1035
# #------------------------------------------------------------------------------
# ## Load cell rules using BBP template
# def loadTemplateName(cellMe):     
#     outFolder = cfg.rootFolder+'/cell_data/'+cellMe
#     try:
#         f = open(outFolder+'/template.hoc', 'r')
#         for line in f.readlines():
#             if 'begintemplate' in line:
#                 return str(line)[14:-1]     
#     except:
#         print('Cannot read cell template from %s' % (outFolder))
#         return False


# cellnumber = 0    
# for cellName in cfg.S1cells:
    
#     if cfg.cellNumber[cellName] < 5:
#         morphoNumbers = cfg.cellNumber[cellName]
#     else:
#         morphoNumbers = 5
    
#     cellFraction = 1.0/morphoNumbers
    
#     for morphoNumber in range(morphoNumbers):
#         cellMe = cfg.cellLabel[cellName] + '_' + str(morphoNumber+1)
#         print(cellMe,cellName)
        
#         cellTemplateName = loadTemplateName(cellMe)
        
#         if cellTemplateName:
            
#             cellRule = netParams.importCellParams(label=cellMe, somaAtOrigin=True,
#                 conds={'cellType': cellMe, 'cellModel': 'HH_full'},
#                 fileName='cellwrapper.py',
#                 cellName='loadCell',
#                 cellInstance = True,
#                 cellArgs={'cellName': cellMe, 'cellTemplateName': cellTemplateName})
            
#             netParams.renameCellParamsSec(label=cellMe, oldSec='soma_0', newSec='soma')              
#             for secname2 in netParams.cellParams[cellMe]['secLists'].keys():
#              if 'soma_0' in netParams.cellParams[cellMe]['secLists'][secname2]:
#                print(cellMe,secname2,netParams.cellParams[cellMe]['secLists'][secname2][0])
#                netParams.cellParams[cellMe]['secLists'][secname2][0] = 'soma'

# %%
#------------------------------------------------------------------------------
# Population parameters
#------------------------------------------------------------------------------
# S1
cfg.scaleDensity = 1.0

# for popName in cfg.S1pops:
# 	layernumber = popName[1:2]
# 	if layernumber == '2':
# 		netParams.popParams[popName] = {'cellType': popName, 'cellModel': 'HH_full', 'ynormRange': layer['23'], 
#                                         'numCells': int(np.ceil(cfg.scaleDensity*cfg.popNumber[popName])), 'diversity': True}
# 	else:
# 		netParams.popParams[popName] = {'cellType': popName, 'cellModel': 'HH_full', 'ynormRange': layer[layernumber], 
#                                         'numCells': int(np.ceil(cfg.scaleDensity*cfg.popNumber[popName])), 'diversity': True}

for cellName in cfg.S1cells:
	layernumber = cellName[1:2]
	if layernumber == '2':
		netParams.popParams[cellName] = {'cellType': cellName, 'cellModel': 'HH_full', 'ynormRange': layer['23'], 
                                        'numCells': int(np.ceil(cfg.scaleDensity*cfg.cellNumber[cellName])), 'diversity': True}
	else:
		netParams.popParams[cellName] = {'cellType': cellName, 'cellModel': 'HH_full', 'ynormRange': layer[layernumber], 
                                        'numCells': int(np.ceil(cfg.scaleDensity*cfg.cellNumber[cellName])), 'diversity': True}

# for metype in cfg.cellParamLabels:
#     if cfg.popLabel[metype] in subPopLabels:
#         print(metype,cfg.cellNumber[metype],cfg.popLabel[metype],cfg.popNumber[cfg.popLabel[metype]])     
#         netParams.popParams[metype] = {'cellType': metype, 'cellModel': 'HH_full', 'ynormRange': layer['5'], 
#                                         'numCells': int(np.ceil(cfg.scaleDensity*cfg.cellNumber[metype])), 'diversity': True}

# %%
## S1 cell property rules
cellnumber = 0    
for cellName in cfg.S1cells:
    
    if cfg.cellNumber[cellName] < 5:
        morphoNumbers = cfg.cellNumber[cellName]
    else:
        morphoNumbers = 5
    
    cellFraction = 1.0/morphoNumbers
    
    for morphoNumber in range(morphoNumbers):
        cellMe = cfg.cellLabel[cellName] + '_' + str(morphoNumber+1)
        
        # Load cell rules previously saved using netpyne format
        netParams.loadCellParamsRule(label = cellMe, fileName = 'cell_data/' + cellMe + '/' + cellMe + '_cellParams.json')   
        
        #-----------------------------------------------------------------------------------#
        if cfg.reducedtest:
            cellRule = {'conds': {'cellType': cellName}, 'diversityFraction': cellFraction, 'secs': {}}  # cell rule dict
            cellRule['conds'] = netParams.cellParams[cellMe]['conds']    
            cellRule['secs'] = {}
            cellRule['secs']['soma'] = netParams.cellParams[cellMe]['secs']['soma']
            cellRule['secLists']['spiny'] = ['soma']
            cellRule['secLists']['spinyEE'] = ['soma']
            cellRule['secLists']['all'] = ['soma']
            cellRule['secLists']['basal'] = ['soma']    
            netParams.cellParams[cellMe] = cellRule   # add dict to list of cell params   
        #-----------------------------------------------------------------------------------#

# %%
# for cellName in cfg.S1cells:    
#     if cfg.cellNumber[cellName] < 5:
#         morphoNumbers = cfg.cellNumber[cellName]
#     else:
#         morphoNumbers = 5    
    
#     for morphoNumber in range(morphoNumbers):
#         cellMe = cfg.cellLabel[cellName] + '_' + str(morphoNumber+1)
#         outFolder = cfg.rootFolder+'/cell_data/'+cellMe
#         netParams.saveCellParamsRule(label=cellMe, fileName=outFolder+'/'+cellMe+'_cellParams.json')

# %%
#------------------------------------------------------------------------------
# Synaptic mechanism parameters  - mods from M1 detailed - Spont and BG
#------------------------------------------------------------------------------
## S1
netParams.synMechParams['AMPA'] = {'mod':'MyExp2SynBB', 'tau1': 0.2, 'tau2': 1.74, 'e': 0}
netParams.synMechParams['GABAA'] = {'mod':'MyExp2SynBB', 'tau1': 0.2, 'tau2': 8.3, 'e': -80}

# %%
#------------------------------------------------------------------------------
# load data from S1 conn pre-processing file 
#------------------------------------------------------------------------------
with open('conn/conn.pkl', 'rb') as fileObj: connData = pickle.load(fileObj)

lmat = connData['lmat']
a0mat = connData['a0mat']
d0 = connData['d0']
dfinal = connData['dfinal']
pmat = {}
pmat[12.5] = connData['pmat12um']
pmat[25] = connData['pmat25um']
pmat[50] = connData['pmat50um']
pmat[75] = connData['pmat75um']
pmat[100] = connData['pmat100um']
pmat[125] = connData['pmat125um']
pmat[150] = connData['pmat150um']
pmat[175] = connData['pmat175um']
pmat[200] = connData['pmat200um'] #max value for d0=200

synperconnNumber = connData['synperconnNumber']
connNumber = connData['connNumber']
decay = connData['decay']
gsyn = connData['gsyn']
use = connData['use']

ConnTypesNumber = connData['ConnTypesNumber'] 
ConnTypes = connData['ConnTypes']   

connIEtype = connData['connIEtype']  
connEItype = connData['connEItype']
parameters_syn = connData['parameters_syn']

# %%
import pandas as pd

physColumnNames = []
syntypes = []
for name,syntype in parameters_syn:    
    if name not in physColumnNames:
        physColumnNames.append(name) 
    if syntype not in syntypes:
        syntypes.append(syntype)
        
#     print(name,syntype,parameters_syn[name,syntype])
dfS6 = pd.DataFrame(index=syntypes, columns=physColumnNames)
for syntype in syntypes:
    for name in physColumnNames:    
        dfS6.loc[syntype][name] = parameters_syn[name,syntype]
dfS6
# Out:
#     ConnType  gsyn gsynStd  decay decayStd    use useStd     dep depStd  \
# 0          0  0.83    0.55   10.4      6.1   0.16    0.1    45.0   21.0
# 3          1  0.91    0.61   10.4      6.1   0.16    0.1    45.0   21.0
# 13         2  0.75    0.32   10.4      6.1  0.415  0.212   162.0   69.0
# 1          3  0.83    0.55    8.3      2.2   0.25   0.13   706.0  405.0
# 4          4  0.91    0.61    8.3      2.2   0.25   0.13   706.0  405.0
# 8          5  0.75    0.32    8.3      2.2   0.25   0.13   706.0  405.0
# 9          6  0.75    0.32    8.3      2.2    0.3   0.08  1250.0  520.0
# 10         7  0.91    0.61    8.3      2.2   0.14   0.05   875.0  285.0
# 12         8  2.97    0.95    8.3      2.2   0.25   0.13   706.0  405.0
# 5          9  0.91    0.61   6.44      1.7   0.32   0.14   144.0   80.0
# 11        10  0.83    0.55  36.55     0.71   0.25   0.13   706.0  405.0
# 114       11  0.43    0.28   1.74     0.18   0.02  0.001   194.0   10.0
# 115       12  0.72     0.5   1.74     0.18   0.02  0.001   194.0   10.0
# 132       13  0.72     0.5   1.74     0.18   0.01  0.001   242.0   15.0
# 133       14  0.11    0.08   1.74     0.18   0.09   0.12   138.0  211.0
# 116       15  0.72     0.5   1.74     0.18    0.5   0.02   671.0   17.0
# 117       16  0.43    0.28   1.74     0.18    0.5   0.02   671.0   17.0
# 118       17  0.72     0.5   1.74     0.18    0.5   0.02   671.0   17.0
# 119       18  0.68    0.46   1.74     0.18   0.46   0.26   671.0   17.0
# 120       19  0.68    0.46   1.74     0.18   0.86  0.049   671.0   17.0
# 121       20  0.19    0.12   1.74     0.18   0.79   0.04   671.0   17.0
# 122       21   0.8    0.53   1.74     0.18   0.39   0.03   671.0   17.0
# 123       22   1.5    1.05   1.74     0.18    0.5   0.02   671.0   17.0
# 127       23   0.8    0.53   1.74     0.18  0.391  0.134   780.0   54.0
# 131       24  0.72     0.5   1.74     0.18   0.58   0.07   240.0   43.0
# 134       25  0.72     0.5   1.74     0.18   0.72  0.065   227.0   38.0
# 126       26   0.8    0.53   1.74     0.18   0.21  0.032   460.0   53.0
# 128       27   0.8    0.53   1.74     0.18   0.27  0.033   559.0  238.0
# 129       28   0.8    0.53   1.74     0.18  0.222  0.053   535.0  134.0
#
#        fac facStd s-types type
# 0    376.0  253.0      I1   II
# 3    376.0  253.0      I1   IE
# 13   690.0    5.0      I1   IE
# 1     21.0    9.0      I2   II
# 4     21.0    9.0      I2   IE
# 8     21.0    9.0      I2   IE
# 9      2.0    4.0      I2   IE
# 10    22.0    5.0      I2   IE
# 12    21.0    9.0      I2   IE
# 5     62.0   31.0      I3   IE
# 11    21.0    9.0      I3   IE
# 114  507.0   20.0      E1   EI
# 115  507.0   20.0      E1   EI
# 132  563.0   32.0      E1   EI
# 133  670.0  830.0      E1   EI
# 116   17.0    5.0      E2   EE
# 117   17.0    5.0      E2   EI
# 118   17.0    5.0      E2   EI
# 119   17.0    5.0      E2   EE
# 120   17.0    5.0      E2   EE
# 121   17.0    5.0      E2   EE
# 122   17.0    5.0      E2   EE
# 123   17.0    5.0      E2   EE
# 127   51.0   36.0      E2   EE
# 131   71.0   47.0      E2   EI
# 134   14.0   12.0      E2   EI
# 126  230.0   69.0      E3   EE
# 128  200.0   92.0      E3   EE
# 129  116.0   81.0      E3   EE

# %%
#------------------------------------------------------------------------------
# Synaptic mechanism parameters  - mods from S1 BBP - deterministic version
#------------------------------------------------------------------------------
for syntype in syntypes:
    if syntype > 50:  # Exc
        
        netParams.synMechParams['S1_EE_STP_Det_' + str(syntype)] = {'mod': 'DetAMPANMDA',
                                         'Use': dfS6['use'][syntype], # ± dfS6['useStd'][syntype]
                                         'Dep': dfS6['dep'][syntype], # ± dfS6['depStd'][syntype] 
                                         'Fac': dfS6['fac'][syntype], # ± dfS6['facStd'][syntype]
                                         'tau_d_AMPA': 1.74, # ± L5_LBC_cIR0.18 ms
                                         'tau_r_AMPA': 0.2, 
                                         'tau_r_NMDA': 0.29,
                                         'tau_d_NMDA': 43,   
                                         'NMDA_ratio': 0.8, # ± 0.1 for EE -- experimentally measured for some path?
                                         'mg':1.0, #    0.5mM where exceptionally specified?                                                                
                                            }
        netParams.synMechParams['S1_EI_STP_Det_' + str(syntype)] = {'mod': 'DetAMPANMDA',
                                         'Use': dfS6['use'][syntype], # ± dfS6['useStd'][syntype]
                                         'Dep': dfS6['dep'][syntype], # ± dfS6['depStd'][syntype] 
                                         'Fac': dfS6['fac'][syntype], # ± dfS6['facStd'][syntype]
                                         'tau_d_AMPA': 1.74, # ± 0.18 ms
                                         'tau_r_AMPA': 0.2,
                                         'tau_r_NMDA': 0.29,
                                         'tau_d_NMDA': 43,   
                                         'NMDA_ratio': 0.4, # ± 0.1  for EI -- experimentally measured for some path?
                                         'mg':1.0, #    0.5mM where exceptionally specified?                                                                
                                            }
    else: # Inh
        
        netParams.synMechParams['S1_II_STP_Det_' + str(syntype)] = {'mod': 'DetGABAAB',
                                         'Use': dfS6['use'][syntype], # ± dfS6['useStd'][syntype]
                                         'Dep': dfS6['dep'][syntype], # ± dfS6['depStd'][syntype]  
                                         'Fac': dfS6['fac'][syntype], # ± dfS6['facStd'][syntype]
                                         'tau_d_GABAA': dfS6['decay'][syntype], # ± dfS6['decayStd'][syntype]
                                         'tau_r_GABAA': 0.2,   #rng.lognormal(0.2, 0.1) in synapses.hoc  
                                         'tau_d_GABAB': 260.9,
                                         'tau_r_GABAB': 3.5,
#                                          'GABAB_ratio': 1.0,  #=0(1):The ratio of GABAB to GABAA            
                                            }
        
        netParams.synMechParams['S1_IE_STP_Det_' + str(syntype)] = {'mod': 'DetGABAAB',
                                         'Use': dfS6['use'][syntype], # ± dfS6['useStd'][syntype]
                                         'Dep': dfS6['dep'][syntype], # ± dfS6['depStd'][syntype]  
                                         'Fac': dfS6['fac'][syntype], # ± dfS6['facStd'][syntype]
                                         'tau_d_GABAA': dfS6['decay'][syntype], # ± dfS6['decayStd'][syntype]
                                         'tau_r_GABAA': 0.2,   #rng.lognormal(0.2, 0.1) in synapses.hoc  
                                         'tau_d_GABAB': 260.9,
                                         'tau_r_GABAB': 3.5,
#                                          'GABAB_ratio': 1.0,  #=0(1):The ratio of GABAB to GABAA            
                                            }

# %%
netParams.synMechParams['S1_EI_STP_Det_' + str(syntype)]
# Out:
# {'mod': 'DetAMPANMDA',
#  'Use': 0.222,
#  'Dep': 535.0,
#  'Fac': 116.0,
#  'tau_d_AMPA': 1.74,
#  'tau_r_AMPA': 0.2,
#  'tau_r_NMDA': 0.29,
#  'tau_d_NMDA': 43,
#  'NMDA_ratio': 0.4,
#  'mg': 1.0}

# %%
def exponential(x, a, b):
    return a*np.exp(-b*x)

def linear(x, a, b):
    return a*x + b

def Gauss(x, a, x0, sigma):
    return a * np.exp(-(x - x0)**2 / (2 * sigma**2))

# %%
if d_init == 0:
    if abs(dexpl) <= abs(dgauss):                   
        Netinfo[proj]['best_fit'] = 'exp'
    else:            
        Netinfo[proj]['best_fit'] = 'gauss'                             
else:
    if abs(dgauss) <= abs(dexp) and abs(dgauss) <= abs(dexp):                    
        Netinfo[proj]['best_fit'] = 'gauss'                              
    else:
        if abs(dexpl) <= abs(dexp):            
            Netinfo[proj]['best_fit'] = 'expl' 
        else:                  
            Netinfo[proj]['best_fit'] = 'exp'

# %%
#------------------------------------------------------------------------------
# S1 Local connectivity parameters 
#------------------------------------------------------------------------------
cfg.addConn = True

cfg.synWeightFractionEE = [1.0, 1.0] # E -> E AMPA to NMDA ratio
cfg.synWeightFractionEI = [1.0, 1.0] # E -> I AMPA to NMDA ratio
cfg.synWeightFractionII = [1.0, 1.0]  # I -> I GABAA to GABAB ratio
cfg.synWeightFractionIE = [1.0, 1.0]  # I -> E GABAA to GABAB ratio
cfg.EEGain = 1.0
cfg.EIGain = 1.0
cfg.IIGain = 1.0
cfg.IEGain = 1.0

contA = 0

if cfg.addConn:    
    for pre in Ipops+Epops:
        for post in Ipops+Epops:
            if float(connNumber[pre][post]) > 0:    
#                 print('\n-------------------------------------------------------------------------------------------\n                               %s:%s                               \n-------------------------------------------------------------------------------------------' % (pre,post)) 
            
                # ------------------------------------------------------------------------------    
                #  2D distance prob rules
                # ------------------------------------------------------------------------------ 
                if int(float(d0[pre][post])) < 25:    #d0==12.5 -> single exponential fit
                    linear = 0
                    angular = 0
                    prob = '%s*exp(-dist_2D/%s)*(dist_2D<%s)' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post])                     
                elif int(float(d0[pre][post])) == 25:    #d0==25 -> exponential fit when dist_2D>25, else prob[0um:25um] = pmat[12.5]
                    linear = float(pmat[12.5][pre][post])
                    angular = 0
                    prob = '%s*exp(-dist_2D/%s)*(dist_2D<%s) if dist_2D > %s else %f*dist_2D+%f' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post],d0[pre][post],angular,linear)
                else:    #d0>25 -> exponential fit when dist_2D>d0, else prob[0um:d0] = linear interpolation [25:d0]
                    d01 = int(float(d0[pre][post]))
                    y1 = float(pmat[25][pre][post])
                    y2 = float(pmat[d01][pre][post])
                    x1 = 25
                    x2 = d01                   
                    angular = (y2 - y1)/(x2 - x1)
                    linear = y2 - x2*angular
                    prob = '%s*exp(-dist_2D/%s)*(dist_2D<%s) if dist_2D > %s else %f * dist_2D + %f' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post],d0[pre][post],angular,linear)

                # ------------------------------------------------------------------------------    
                # I -> I
                # ------------------------------------------------------------------------------
                if pre in Ipops:
                    if post in Ipops:                             
                        connID = ConnTypes[pre][post][0]                        
                        synMechType = 'S1_II_STP_Det_' + str(connID)   
                        contA+= 1
                        netParams.connParams['II_' + pre + '_' + post] = { 
                                        'preConds': {'pop': cfg.popLabelEl[pre]}, 
                                        'postConds': {'pop': cfg.popLabelEl[post]},
                                        'synMech': synMechType,
                                        'probability': prob,
                                        'weight': parameters_syn['gsyn',connID] * cfg.IIGain, 
                                        'synMechWeightFactor': cfg.synWeightFractionII,
                                        'delay': 'defaultDelay+dist_3D/propVelocity',
                                        'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                                        'sec': 'spiny'}        
                # ------------------------------------------------------------------------------
                #  I -> E  # with ME conn diversity
                # ------------------------------------------------------------------------------
                if pre in Ipops:
                    if post in Epops:                                                       
                        cellpreList_A = []
                        cellpreList_B = []
                        cellpreList_C = []
                        connID_B = -1    
                        connID_C = -1                               
                        if 'SBC' in pre or 'LBC' in pre or 'NBC' in pre:                              
                            cellpost = cfg.popLabelEl[post][0]   
                            for npre,cellpre in enumerate(cfg.popLabelEl[pre]):   
                                premtype = pre[-3:]
                                preetype = cellpre[-3:]                                    
                                connID = connIEtype[premtype][preetype]                                     
                                if connID == ConnTypes[pre][post][0]:
                                    cellpreList_A.append(cellpre)    
                                elif connID == ConnTypes[pre][post][1]:
                                    cellpreList_B.append(cellpre)
                                    connID_B = ConnTypes[pre][post][1]
                                elif connID == ConnTypes[pre][post][2]:
                                    cellpreList_C.append(cellpre)
                                    connID_C = ConnTypes[pre][post][2]
                                else:
                                    print('ERROR')                                    
                        else:   
                            cellpreList_A = cfg.popLabelEl[pre]                              
                            
                        connID = ConnTypes[pre][post][0]                            
                        synMechType = 'S1_IE_STP_Det_' + str(connID)
#                         if 'L1' in pre: 
#                             print('%s:%s (ID_BBP=%d or ID_new=%d)  gsyn=%4.4f (%s , IE-L1=%s)  %s' % (pre,post,
#                                             connID,parameters_syn['ConnType',connID],parameters_syn['gsyn',connID], 
#                                             parameters_syn['s-types',connID],parameters_syn['type',connID], synMechType))      
#                         else: 
#                             print('%s:%s (ID_BBP=%d or ID_new=%d)  gsyn=%4.4f (%s , %s)  %s' % (pre,post,
#                                             connID,parameters_syn['ConnType',connID],parameters_syn['gsyn',connID], 
#                                             parameters_syn['s-types',connID],parameters_syn['type',connID], synMechType))    
                        contA+= 1                          
                        netParams.connParams['IE_'+pre+'_'+post] = { 
                                    'preConds': {'pop': cellpreList_A}, 
                                    'postConds': {'pop': post},
                                    'synMech': synMechType,
                                    'probability': prob,
                                    'weight': parameters_syn['gsyn',connID] * cfg.IEGain, 
                                    'synMechWeightFactor': cfg.synWeightFractionIE,
                                    'delay': 'defaultDelay+dist_3D/propVelocity',
                                    'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                                    'sec': 'spiny'}  
                

                        if connID_B >= 0:          
                            connID = connID_B
                            synMechType = 'S1_IE_STP_Det_' + str(connID)         
                            netParams.connParams['IE_'+pre+'_'+post+'_B'] = { 
                                        'preConds': {'pop': cellpreList_B}, 
                                        'postConds': {'pop': post},
                                        'synMech': synMechType,
                                        'probability': prob,
                                        'weight': parameters_syn['gsyn',connID] * cfg.IEGain, 
                                        'synMechWeightFactor': cfg.synWeightFractionIE,
                                        'delay': 'defaultDelay+dist_3D/propVelocity',
                                        'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                                        'sec': 'spiny'}                       
                
                                
                            if connID_C >= 0:          
                                connID = connID_C
                                synMechType = 'S1_IE_STP_Det_' + str(connID)         
                                netParams.connParams['IE_'+pre+'_'+post+'_C'] = { 
                                            'preConds': {'pop': cellpreList_C}, 
                                            'postConds': {'pop': post},
                                            'synMech': synMechType,
                                            'probability': prob,
                                            'weight': parameters_syn['gsyn',connID] * cfg.IEGain, 
                                            'synMechWeightFactor': cfg.synWeightFractionIE,
                                            'delay': 'defaultDelay+dist_3D/propVelocity',
                                            'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                                            'sec': 'spiny'}                       
                                
                #------------------------------------------------------------------------------   
                # E -> E
                #------------------------------------------------------------------------------
                if pre in Epops:
                    if post in Epops:    
                        connID = ConnTypes[pre][post][0]                        
                        synMechType = 'S1_EE_STP_Det_' + str(connID)   
                        contA+= 1   
                        netParams.connParams['EE_'+pre+'_'+post] = { 
                            'preConds': {'pop': cfg.popLabelEl[pre]}, 
                            'postConds': {'pop': cfg.popLabelEl[post]},
                            'synMech': synMechType,
                            'probability': prob, 
                            'weight': parameters_syn['gsyn',connID] * cfg.EEGain, 
                            'synMechWeightFactor': cfg.synWeightFractionEE,
                            'delay': 'defaultDelay+dist_3D/propVelocity',
                            'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                            'sec': 'spinyEE'}    
    
                #------------------------------------------------------------------------------               
                #  E -> I  with ME conn diversity
                #------------------------------------------------------------------------------   
                if pre in Epops:
                    if post in Ipops:                        
                        cellpostList_A = []
                        cellpostList_B = []
                        connID_B = -1                          
                        if ConnTypes[pre][post][0] == 131 or ConnTypes[pre][post][0] == 132: # EXCEPTIONS -> L6_IPC:L6_(DBC-LBC-NBC-SBC) and  L6_TPC_L:L6_(DBC-LBC-NBC-SBC)    
                            cellpostList_A = cfg.popLabelEl[post]     
                        elif 'LBC' in post or 'NBC' in post or 'BP' in post or 'DBC' in post or 'BTC' in post:    
                            cellpre = cfg.popLabelEl[pre][0]
                            for npost,cellpost in enumerate(cfg.popLabelEl[post]):                                
                                postmtype = post[-3:]
                                postetype = cellpost[-3:]
                                if 'BP' in postmtype:
                                    postmtype = post[-2:]       
                                connID = connEItype[postmtype][postetype]                                
                                if connID == ConnTypes[pre][post][0]:
                                    cellpostList_A.append(cellpost)    
                                elif connID == ConnTypes[pre][post][1]:
                                    cellpostList_B.append(cellpost)
                                    connID_B = ConnTypes[pre][post][1]
                                else:
                                    print('ERROR')                                
                        else:                           
                            cellpostList_A = cfg.popLabelEl[post]         
                             
                        connID = ConnTypes[pre][post][0]      
                        synMechType = 'S1_EI_STP_Det_' + str(connID)  
                        contA+= 1                                                              
                        netParams.connParams['EI_'+pre+'_'+post] = { 
                                        'preConds': {'pop': pre}, 
                                        'postConds': {'pop': cellpostList_A},
                                        'synMech': synMechType,
                                        'probability': prob, 
                                        'weight': parameters_syn['gsyn',connID] * cfg.EIGain, 
                                        'synMechWeightFactor': cfg.synWeightFractionEI,
                                        'delay': 'defaultDelay+dist_3D/propVelocity',
                                        'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                                        'sec': 'spiny'}   

                        if connID_B >= 0:          
                            connID = connID_B
                            synMechType = 'S1_EI_STP_Det_' + str(connID)        
                            netParams.connParams['EI_'+pre+'_'+post+'_B'] = { 
                                            'preConds': {'pop': pre}, 
                                            'postConds': {'pop': cellpostList_B},
                                            'synMech': synMechType,
                                            'probability': prob, 
                                            'weight': parameters_syn['gsyn',connID] * cfg.EIGain, 
                                            'synMechWeightFactor': cfg.synWeightFractionEI,
                                            'delay': 'defaultDelay+dist_3D/propVelocity',
                                            'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                                            'sec': 'spiny'}

# %%
contA = 0
contB = 0
contC = 0
for connpath in netParams.connParams.keys():
    if '_B' in connpath[-2:]:
        contB+=1        
#         print()
#         print(connpathAnt)
#         print(netParams.connParams[connpathAnt])
#         print(connpath)
#         print(netParams.connParams[connpath])
    elif '_C' in connpath[-2:]:
        contC+=1        
#         print(connpath)
#         print(netParams.connParams[connpath])
    else:        
        contA+=1        
    connpathAnt = connpath
print(contA,contB,contC)
print(contA+contB+contC)
# Out:
# 1941 370 47
# 2358

# %%
#------------------------------------------------------------------------------
# Spontaneous synapses + background - data from Rat
#------------------------------------------------------------------------------
cfg.addStimSynS1 = False
cfg.rateStimE = 9.0
cfg.rateStimI = 9.0

#------------------------------------------------------------------------------
# NetStim inputs to simulate Spontaneous synapses + background in S1 neurons - data from Rat
#------------------------------------------------------------------------------
SourcesNumber = 5 # for each post Mtype - sec distribution
synperNeuronStimI = connData['synperNeuronStimI']
synperNeuronStimE = connData['synperNeuronStimE']
GsynStimI = connData['GsynStimI']
GsynStimE = connData['GsynStimE']
   
if cfg.addStimSynS1:      
    for post in Ipops + Epops:

        synperNeuron = synperNeuronStimI[post]
        ratespontaneous = cfg.rateStimI
        for qSnum in range(SourcesNumber):
            ratesdifferentiation = (0.8 + 0.4*qSnum/(SourcesNumber-1)) * (synperNeuron*ratespontaneous)/SourcesNumber
            netParams.stimSourceParams['StimSynS1_S_all_INH->' + post + '_' + str(qSnum)] = {'type': 'NetStim', 'rate': ratesdifferentiation, 'noise': 1.0}

        synperNeuron = synperNeuronStimE[post]
        ratespontaneous = cfg.rateStimE
        for qSnum in range(SourcesNumber):
            ratesdifferentiation = (0.8 + 0.4*qSnum/(SourcesNumber-1)) * (synperNeuron*ratespontaneous)/SourcesNumber
            netParams.stimSourceParams['StimSynS1_S_all_EXC->' + post + '_' + str(qSnum)] = {'type': 'NetStim', 'rate': ratesdifferentiation, 'noise': 1.0}
            
    #------------------------------------------------------------------------------
    for post in Epops:
        for qSnum in range(SourcesNumber):
            netParams.stimTargetParams['StimSynS1_T_all_EXC->' + post + '_' + str(qSnum)] = {
                'source': 'StimSynS1_S_all_EXC->' + post + '_' + str(qSnum), 
                'conds': {'cellType': cfg.popLabelEl[post]}, 
                'ynorm':[0,1], 
                'sec': 'spinyEE', 
                'loc': 0.5, 
                'synMechWeightFactor': [1.0],
                'weight': GsynStimE[post],
                'delay': 0.1, 
                'synMech': 'AMPA'}

    for post in Ipops:
        for qSnum in range(SourcesNumber):
            netParams.stimTargetParams['StimSynS1_T_all_EXC->' + post + '_' + str(qSnum)] = {
                'source': 'StimSynS1_S_all_EXC->' + post + '_' + str(qSnum), 
                'conds': {'cellType': cfg.popLabelEl[post]}, 
                'ynorm':[0,1], 
                'sec': 'spiny', 
                'loc': 0.5, 
                'synMechWeightFactor': [1.0],
                'weight': GsynStimE[post],
                'delay': 0.1, 
                'synMech': 'AMPA'}

    for post in Epops+Ipops:
        for qSnum in range(SourcesNumber):
            netParams.stimTargetParams['StimSynS1_T_all_INH->' + post + '_' + str(qSnum)] = {
                'source': 'StimSynS1_S_all_INH->' + post + '_' + str(qSnum), 
                'conds': {'cellType': cfg.popLabelEl[post]}, 
                'ynorm':[0,1], 
                'sec': 'spiny', 
                'loc': 0.5, 
                'synMechWeightFactor': [1.0],
                'weight': GsynStimI[post],
                'delay': 0.1, 
                'synMech': 'GABAA'}

# %%
# for stimpath in netParams.stimSourceParams.keys():
#     print(stimpath)
#     print(netParams.stimSourceParams[stimpath])
#     print()

# %%
# for stimpath in netParams.stimTargetParams.keys():
#     print(stimpath)
#     print(netParams.stimTargetParams[stimpath])
#     print()

# %% [markdown]
# ## Run small Nets in a sigle job

# %%
# for cell in netParams.cellParams.keys():    
#     for sect in netParams.cellParams[cell]['secs'].keys():
#         if 'ions' not in netParams.cellParams[cell]['secs'][sect].keys():
#             print(cell,sect,netParams.cellParams[cell]['secs'][sect].keys())

# %%
sim.initialize(
    simConfig = cfg, 	
    netParams = netParams)  				# create network object and set cfg and net params

sim.net.createPops()               			# instantiate network populations
# Out:
# Start time:  2021-10-13 11:45:41.715297
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ...
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# ERROR: cellParams -> secs ('soma') -> topol: At least 3 parameters (parentSec, parentX and childX) must be specified for topology. Values specified are: '[]'.
# {L1_DAC_bNA: <netpyne.network.pop.Pop object at 0x7f0939876ed0>, L1_DAC_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a1cc10>, L1_DLAC_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a1cc90>, L1_HAC_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a1ccd0>, L1_HAC_cIR: <netpyne.network.pop.Pop object at 0x7f08d4a1cd10>, L1_HAC_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a1cd50>, L1_NGC-DA_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a1cd90>, L1_NGC-DA_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a1cc50>, L1_NGC-DA_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a1cdd0>, L1_NGC-DA_cST: <netpyne.network.pop.Pop object at 0x7f08d4a1ce10>, L1_NGC-SA_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a1ce50>, L1_SLAC_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a1ce90>, L1_SLAC_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a1ced0>, L1_SLAC_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a1cf10>, L23_BP_bAC: <netpyne.network.pop.Pop object at 0x7f08d4a1cf50>, L23_BP_bIR: <netpyne.network.pop.Pop object at 0x7f08d4a1cf90>, L23_BP_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a1cfd0>, L23_BP_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a25050>, L23_BP_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a25090>, L23_BP_dST: <netpyne.network.pop.Pop object at 0x7f08d4a250d0>, L23_BTC_bAC: <netpyne.network.pop.Pop object at 0x7f08d4a25110>, L23_BTC_bIR: <netpyne.network.pop.Pop object at 0x7f08d4a25150>, L23_BTC_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a25190>, L23_BTC_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a251d0>, L23_BTC_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a25210>, L23_ChC_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a25250>, L23_ChC_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a25290>, L23_ChC_dNA: <netpyne.network.pop.Pop object at 0x7f08d4a252d0>, L23_DBC_bAC: <netpyne.network.pop.Pop object at 0x7f08d4a25310>, L23_DBC_bIR: <netpyne.network.pop.Pop object at 0x7f08d4a25350>, L23_DBC_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a25390>, L23_DBC_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a253d0>, L23_LBC_bAC: <netpyne.network.pop.Pop object at 0x7f08d4a25410>, L23_LBC_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a25450>, L23_LBC_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a25490>, L23_LBC_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a254d0>, L23_LBC_cST: <netpyne.network.pop.Pop object at 0x7f08d4a25510>, L23_LBC_dNA: <netpyne.network.pop.Pop object at 0x7f08d4a25550>, L23_MC_bAC: <netpyne.network.pop.Pop object at 0x7f08d4a25590>, L23_MC_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a255d0>, L23_MC_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a25610>, L23_MC_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a25650>, L23_MC_dNA: <netpyne.network.pop.Pop object at 0x7f08d4a25690>, L23_NBC_bAC: <netpyne.network.pop.Pop object at 0x7f08d4a256d0>, L23_NBC_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a25710>, L23_NBC_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a25750>, L23_NBC_cIR: <netpyne.network.pop.Pop object at 0x7f08d4a25790>, L23_NBC_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a257d0>, L23_NBC_dNA: <netpyne.network.pop.Pop object at 0x7f08d4a25810>, L23_NGC_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a25850>, L23_NGC_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a25890>, L23_NGC_cNA: <netpyne.network.pop.Pop object at 0x7f08d4a258d0>, L23_NGC_cST: <netpyne.network.pop.Pop object at 0x7f08d4a25910>, L23_PC_cAD: <netpyne.network.pop.Pop object at 0x7f08d4a25950>, L23_SBC_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a25990>, L23_SBC_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a259d0>, L23_SBC_dNA: <netpyne.network.pop.Pop object at 0x7f08d4a25a10>, L4_BP_bAC: <netpyne.network.pop.Pop object at 0x7f08d4a25a50>, L4_BP_bIR: <netpyne.network.pop.Pop object at 0x7f08d4a25a90>, L4_BP_bNA: <netpyne.network.pop.Pop object at 0x7f08d4a25ad0>, L4_BP_cAC: <netpyne.network.pop.Pop object at 0x7f08d4a25b10>, L4_BP_cNA: <netpyne.network.pop.Pop object at 0x7 ...

# %%
sim.net.createCells();              			# instantiate network cells based on defined populations
# Out:
# Creating network of 207 cell populations on 1 hosts...
# Distributed population of 5 cells on 1 hosts: {0: [0, 1, 2, 3, 4]}, next: 0
# Cell 0/4 (gid=0) of pop L1_DAC_bNA, on node 0,
# Cell 1/4 (gid=1) of pop L1_DAC_bNA, on node 0,
# Cell 2/4 (gid=2) of pop L1_DAC_bNA, on node 0,
# Cell 3/4 (gid=3) of pop L1_DAC_bNA, on node 0,
# Cell 4/4 (gid=4) of pop L1_DAC_bNA, on node 0,
# Instantiated 5 cells of population L1_DAC_bNA
# Distributed population of 5 cells on 1 hosts: {0: [0, 1, 2, 3, 4]}, next: 0
# Cell 0/4 (gid=5) of pop L1_DAC_cNA, on node 0,
# Cell 1/4 (gid=6) of pop L1_DAC_cNA, on node 0,
# Cell 2/4 (gid=7) of pop L1_DAC_cNA, on node 0,
# Cell 3/4 (gid=8) of pop L1_DAC_cNA, on node 0,
# Cell 4/4 (gid=9) of pop L1_DAC_cNA, on node 0,
# Instantiated 5 cells of population L1_DAC_cNA
# Distributed population of 5 cells on 1 hosts: {0: [0, 1, 2, 3, 4]}, next: 0
# Cell 0/4 (gid=10) of pop L1_DLAC_cNA, on node 0,
# Cell 1/4 (gid=11) of pop L1_DLAC_cNA, on node 0,
# Notice: compartCell_L1_DAC_bNA_HH_full_1.axon_0(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.soma(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.axon_1(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.axon_0(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_0(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_1(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_0(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_10(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_2(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_11(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_10(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_12(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_10(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_13(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_1(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_14(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_13(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_15(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_14(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_16(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_15(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_17(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_15(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_18(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_14(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_19(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_13(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_2(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_1(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_20(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_19(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_21(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_19(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_22(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_0(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_23(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_22(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_24(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_23(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_25(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_24(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_26(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_24(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_27(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_23(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_28(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_22(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_29(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_28(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_3(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_2(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_30(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_28(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_31(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_32(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_31(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_33(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_32(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_34(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_32(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_35(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_31(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_36(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_35(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_37(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_36(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_38(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_37(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_39(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_37(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_4(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_3(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_40(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_36(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_41(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_40(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_42(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_40(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_43(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_35(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_5(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_3(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_6(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_5(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_7(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_6(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_8(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_6(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_1.dend_9(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_1.dend_5(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.axon_0(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.soma(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.axon_1(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.axon_0(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_0(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_1(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_0(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_10(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_9(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_11(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_9(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_12(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_6(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_13(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_5(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_14(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_13(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_15(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_13(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_16(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_4(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_17(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_18(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_17(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_19(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_18(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_2(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_0(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_20(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_19(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_21(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_19(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_22(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_21(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_23(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_21(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_24(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_18(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_25(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_17(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_26(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_27(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_26(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_28(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_26(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_29(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_3(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_30(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_29(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_31(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_30(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_32(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_31(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_33(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_31(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_34(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_30(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_35(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_29(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_36(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_35(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_37(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_35(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_38(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_39(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_38(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_4(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_40(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_39(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_41(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_40(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_42(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_40(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_43(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_39(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_5(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_4(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_6(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_5(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_7(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_6(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_8(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_7(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_2.dend_9(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_2.dend_7(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.axon_0(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.soma(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.axon_1(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.axon_0(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_0(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_1(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_0(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_10(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_6(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_11(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_12(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_11(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_13(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_12(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_14(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_12(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_15(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_11(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_16(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_15(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_17(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_15(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_18(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_17(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_19(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_17(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_2(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_0(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_20(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_19(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_21(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_19(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_22(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_23(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_22(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_24(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_23(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_25(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_24(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_26(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_24(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_27(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_26(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_28(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_26(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_29(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_23(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_3(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_2(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_30(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_29(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_31(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_29(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_32(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_22(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_33(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_34(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_33(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_35(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_34(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_36(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_35(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_37(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_35(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_38(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_34(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_39(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_38(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_4(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_2(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_40(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_38(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_5(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_6(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.soma(0.5)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_7(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_6(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_8(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_7(1)
# Notice: compartCell_L1_DAC_bNA_HH_full_4.dend_9(0) had previously been connected to parent compartCell_L1_DAC_bNA_HH_full_4.dend_7(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.axon_0(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.soma(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.axon_1(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.axon_0(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_0(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_1(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_0(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_10(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_8(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_11(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_10(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_12(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_10(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_13(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_14(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_13(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_15(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_14(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_16(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_15(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_17(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_15(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_18(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_17(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_19(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_17(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_2(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_0(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_20(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_14(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_21(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_20(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_22(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_20(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_23(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_13(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_24(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_23(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_25(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_23(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_26(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_25(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_27(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_26(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_28(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_27(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_29(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_27(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_3(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_30(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_26(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_31(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_25(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_32(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_31(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_33(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_31(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_34(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_35(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_34(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_36(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_34(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_37(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_38(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_37(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_39(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_37(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_4(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_5(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_4(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_6(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_4(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_7(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_6(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_8(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_6(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_6.dend_9(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_6.dend_8(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.axon_0(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.soma(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.axon_1(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.axon_0(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_0(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_1(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_0(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_10(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_9(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_11(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_9(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_12(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_6(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_13(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_5(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_14(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_13(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_15(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_13(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_16(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_4(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_17(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_18(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_17(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_19(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_18(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_2(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_0(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_20(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_19(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_21(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_19(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_22(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_21(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_23(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_21(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_24(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_18(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_25(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_17(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_26(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.soma(0.5)
# Notice: compartCell_L
# Cell 2/4 (gid=12) of pop L1_DLAC_cNA, on node 0,
# Cell 3/4 (gid=13) of pop L1_DLAC_cNA, on node 0,
# Cell 4/4 (gid=14) of pop L1_DLAC_cNA, on node 0,
# Instantiated 5 cells of population L1_DLAC_cNA
# Distributed population of 5 cells on 1 hosts: {0: [0, 1, 2, 3, 4]}, next: 0
# Cell 0/4 (gid=15) of pop L1_HAC_bNA, on node 0,
# Cell 1/4 (gid=16) of pop L1_HAC_bNA, on node 0,
# Cell 2/4 (gid=17) of pop L1_HAC_bNA, on node 0,
# Cell 3/4 (gid=18) of pop L1_HAC_bNA, on node 0,
# Cell 4/4 (gid=19) of pop L1_HAC_bNA, on node 0,
# Instantiated 5 cells of population L1_HAC_bNA
# Distributed population of 5 cells on 1 hosts: {0: [0, 1, 2, 3, 4]}, next: 0
# Cell 0/4 (gid=20) of pop L1_HAC_cIR, on node 0,
# Cell 1/4 (gid=21) of pop L1_HAC_cIR, on node 0,
# Cell 2/4 (gid=22) of pop L1_HAC_cIR, on node 0,
# Cell 3/4 (gid=23) of pop L1_HAC_cIR, on node 0,
# Cell 4/4 (gid=24) of pop L1_HAC_cIR, on node 0,
# Instantiated 5 cells of population L1_HAC_cIR
# Distributed population of 5 cells on 1 hosts: {0: [0, 1, 2, 3, 4]}, next: 0
# Cell 0/4 (gid=25) of pop L1_HAC_cNA, on node 0,
# 1_DAC_cNA_HH_full_7.dend_27(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_26(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_28(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_26(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_29(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_3(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_30(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_29(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_31(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_30(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_32(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_31(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_33(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_31(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_34(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_30(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_35(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_29(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_36(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_35(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_37(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_35(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_38(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_39(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_38(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_4(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_40(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_39(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_41(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_40(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_42(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_40(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_43(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_39(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_5(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_4(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_6(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_5(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_7(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_6(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_8(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_7(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_7.dend_9(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_7.dend_7(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.axon_0(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.soma(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.axon_1(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.axon_0(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_0(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.soma(0.5)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_1(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_0(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_10(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_2(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_11(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_10(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_12(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_10(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_13(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_1(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_14(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_13(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_15(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_14(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_16(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_15(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_17(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_15(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_18(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_14(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_19(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_13(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_2(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_1(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_20(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_19(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_21(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_19(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_22(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_0(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_23(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_22(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_24(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_23(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_25(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_24(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_26(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_24(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_3(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_2(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_4(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_3(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_5(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_3(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_6(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_5(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_7(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_6(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_8(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_6(1)
# Notice: compartCell_L1_DAC_cNA_HH_full_9.dend_9(0) had previously been connected to parent compartCell_L1_DAC_cNA_HH_full_9.dend_5(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.axon_0(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.soma(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.axon_1(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.axon_0(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_0(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_1(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_0(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_10(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_8(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_11(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_1(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_12(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_11(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_13(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_11(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_14(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_13(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_15(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_13(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_16(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_0(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_17(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_18(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_17(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_19(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_17(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_2(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_1(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_20(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_21(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_20(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_22(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_20(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_23(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_24(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_23(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_25(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_24(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_26(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_24(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_27(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_26(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_28(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_26(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_29(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_23(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_3(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_2(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_30(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_29(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_31(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_29(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_32(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_31(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_33(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_32(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_34(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_32(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_35(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_31(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_36(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_37(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_36(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_38(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_37(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_39(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_37(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_4(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_3(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_40(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_36(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_41(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_40(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_42(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_40(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_43(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_42(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_44(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_42(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_45(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_44(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_46(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_44(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_47(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_48(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_47(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_49(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_48(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_5(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_4(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_50(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_48(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_51(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_47(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_6(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_4(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_7(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_3(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_8(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_2(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_11.dend_9(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_11.dend_8(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.axon_0(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.soma(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.axon_1(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.axon_0(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_0(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_1(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_0(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_10(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_9(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_11(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_9(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_12(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_4(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_13(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_3(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_14(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_15(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_14(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_16(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_14(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_17(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_16(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_18(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_17(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_19(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_17(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_2(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_0(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_20(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_16(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_21(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_20(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_22(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_20(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_23(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_24(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_23(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_25(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_23(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_26(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_25(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_27(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_25(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_28(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_27(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_29(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_27(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_3(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_30(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.soma(0.5)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_31(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_30(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_32(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_31(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_33(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_32(1)
# Notice: compartCell_L1_DLAC_cNA_HH_full_12.dend_34(0) had previously been connected to parent compartCell_L1_DLAC_cNA_HH_full_12.dend_33(1)
# ...
# Notice: compartCell_L1_HAC_cNA_HH_full_27.dend_9(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_27.dend_7(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.axon_0(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.soma(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.axon_1(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.axon_0(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_0(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.soma(0.5)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_1(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_0(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_10(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_9(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_11(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_9(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_12(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_8(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_13(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_7(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_14(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_6(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_15(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.soma(0.5)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_16(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_15(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_17(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_16(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_18(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_16(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_19(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_18(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_2(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_1(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_20(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_18(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_21(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_20(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_22(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_20(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_23(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_15(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_24(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.soma(0.5)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_25(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.soma(0.5)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_26(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_25(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_27(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_25(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_3(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_1(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_4(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_3(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_5(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_3(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_6(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_0(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_7(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_6(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_8(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_7(1)
# Notice: compartCell_L1_HAC_cNA_HH_full_29.dend_9(0) had previously been connected to parent compartCell_L1_HAC_cNA_HH_full_29.dend_8(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.axon_0(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.soma(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.axon_1(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.axon_0(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_0(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.soma(0.5)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_1(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_0(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_10(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.soma(0.5)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_11(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_10(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_12(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_11(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_13(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_12(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_14(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_12(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_15(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_11(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_16(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_15(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_17(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_15(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_18(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_10(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_19(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_18(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_2(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_1(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_20(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_18(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_21(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_20(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_22(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_20(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_23(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.soma(0.5)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_24(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_23(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_25(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_24(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_26(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_24(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_27(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_26(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_28(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_27(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_29(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_28(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_3(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_1(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_30(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_28(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_31(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_27(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_32(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_26(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_33(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_32(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_34(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_33(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_35(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_33(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_36(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_32(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_4(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_1(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_5(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_0(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_6(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_5(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_7(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_6(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_8(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_6(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_31.dend_9(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_31.dend_5(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.axon_0(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.soma(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.axon_1(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.axon_0(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_0(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.soma(0.5)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_1(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_0(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_10(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_9(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_11(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_10(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_12(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_11(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_13(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_11(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_14(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_10(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_15(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_9(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_16(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.soma(0.5)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_17(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_16(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_18(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_17(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_19(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_18(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_2(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_1(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_20(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_19(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_21(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_20(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_22(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_21(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_23(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_21(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_24(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_20(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_25(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_19(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_26(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_18(1)
# Notice: compartCell_L1_NGC-DA_bNA_HH_full_32.dend_27(0) had previously been connected to parent compartCell_L1_NGC-DA_bNA_HH_full_32.dend_17(1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_63282/3521926917.py in <module>
# ----> 1 sim.net.createCells();                                  # instantiate network cells based on defined populations
#
# ~/anaconda3/envs/p37/lib/python3.7/site-packages/netpyne/network/network.py in createCells(self)
#      84
#      85         for ipop in list(self.pops.values()): # For each pop instantiate the network cells (objects of class 'Cell')
# ---> 86             newCells = ipop.createCells() # create cells for this pop using Pop method
#      87             self.cells.extend(newCells)  # add to list of cells
#      88             sim.pc.barrier()
#
# ~/anaconda3/envs/p37/lib/python3.7/site-packages/netpyne/network/pop.py in createCells(self)
#      77         # create cells based on fixed number of cells
#      78         elif 'numCells' in self.tags:
# ---> 79             cells = self.createCellsFixedNum()
#      80
#      81         # create cells based on density (optional ynorm-dep)
#
# ~/anaconda3/envs/p37/lib/python3.7/site-packages/netpyne/network/pop.py in createCellsFixedNum(self)
#     173                     else:
#     174                         cellTags['params']['rates'] = [self.tags['dynamicRates']['rates'], self.tags['dynamicRates']['times']] # 1D list (same for all)
# --> 175             cells.append(self.cellModelClass(gid, cellTags)) # instantiate Cell object
#     176
#     177             if sim.cfg.verbose: print(('Cell %d/%d (gid=%d) of pop %s, on node %d, '%(i, sim.net.params.scale * self.tags['numCells']-1, gid, self.tags['pop'], sim.rank)))
#
# ~/anaconda3/envs/p37/lib/python3.7/site-packages/netpyne/cell/compartCell.py in __init__(self, gid, tags, create, associateGid)
#      50         self.secLists = Dict()  # dict of sectionLists
#      51
# ---> 52         if create: self.create()  # create cell
#      53         if associateGid: self.associateGid()  # register cell for this node
#      54
#
# ~/anaconda3/envs/p37/lib/python3.7/site-packages/netpyne/cell/compartCell.py in create(self)
#     105                     self.createPyStruct(prop)
#     106                 if sim.cfg.createNEURONObj:
# --> 107                     self.createNEURONObj(prop)  # add sections, mechanisms, synaptic mechanisms, geometry and topolgy specified by this property set
#     108
#     109
#
# ~/anaconda3/envs/p37/lib/python3.7/site-packages/netpyne/cell/compartCell.py in createNEURONObj(self, prop)
#     440             if 'topol' in sectParams:
#     441                 if sectParams['topol']:
# --> 442                     sec['hObj'].connect(self.secs[sectParams['topol']['parentSec']]['hObj'], sectParams['topol']['parentX'], sectParams['topol']['childX'])  # make topol connection
#     443
#     444         # add dipoles
#
# KeyboardInterrupt:

# %%
sim.net.connectCells()            			# create connections between cells based on params
sim.net.addStims() 							# add network stimulation
# sim.setupRecording()              			# setup variables to record for each cell (spikes, V traces, etc)
# sim.runSim()                      			# run parallel Neuron simulation  
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()

# %% [markdown]
# ## Net infos

# %%
# for pre in Ipops:
#     for post in Ipops:
#         print(pre,post,connNumber[pre][post])

# %%
features = ['numConns'] #,'convergence'
groups =['cell']
for feat in features:
   for group in groups:
        sim.analysis.plotConn(includePre=cfg.allpops, includePost = cfg.allpops, feature=feat, groupBy=group, figSize=(15,15), orderBy='gid', graphType='matrix', fontSize=8, saveData=None, 
                               saveFig=False, showFig=False);

# %%
# features = ['numConns','convergence'] includePre=cfg.allpops, includePost = cfg.allpops,
test = sim.analysis.plotConn(includePre=cfg.allpops, includePost = cfg.allpops, feature='numConns', figSize=(24, 24), fontSize=6, saveData=None, 
                               saveFig=True, showFig=False);

# %%
sim.analysis.plot2Dnet()
# Out:
# Plotting 2D representation of network cell locations and connections...
# (<Figure size 864x864 with 1 Axes>,
#  {'include': ['allCells'],
#   'posX': [246.57688623971768,
#    284.53945493280025,
#    33.277606597599956,
#    284.4178417940913,
#    149.8219571161763,
#    339.0671429478858,
#    409.9660825651586,
#    378.62242943380176,
#    97.37443125891758,
#    47.29766988183115,
#    401.068506416251,
#    204.32621804249695,
#    203.3477302281801,
#    99.46362421937529,
#    120.64791860061918,
#    397.07924637364783,
#    304.6639967991156,
#    57.615160288976256,
#    376.6017845489304,
#    298.81943885507,
#    80.09190523906167,
#    14.97762588297038,
#    111.41254904130997,
#    77.42290224027215,
#    215.34633235582282,
#    232.84294871236625,
#    361.052166266592,
#    321.1335911508389,
#    82.2192880658341,
#    93.79257401987827,
#    314.57091510004375,
#    384.4900204596783,
#    275.9971890074939,
#    340.45925189947866,
#    211.6107172648172,
#    323.79527566588587,
#    114.51222075373198,
#    334.9426780520165,
#    224.0674343618848,
#    86.64264113613673,
#    256.79291821240724,
#    109.81528666417915,
#    375.76265083149804,
#    177.89683998290832,
#    150.55941087099788,
#    187.4600279856453,
#    268.93378461148814,
#    211.2884475331519,
#    116.61769268765191,
#    161.64262469532267,
#    188.4294973390923,
#    287.3680390451004,
#    212.33524220383592,
#    313.0116764836955,
#    35.5826787859713,
#    310.377826461641,
#    316.05297673228364,
#    197.22740084372805,
#    147.53076182085812,
#    185.376833070191,
#    271.6963544232281,
#    222.76074541105174,
#    347.37480269038616,
#    356.37423453506597,
#    405.7272179242265,
#    378.63900893574754,
#    292.83165231597036,
#    47.07372927586044,
#    288.2558065671496,
#    221.7839112782261,
#    236.49055920658662,
#    252.01138663248705,
#    241.40152062257607,
#    109.97322095802363,
#    265.0859884701657,
#    239.55915590900526,
#    208.81563277179063,
#    402.42773125394643,
#    346.71194015433366,
#    410.8164698225786,
#    267.98716264421,
#    218.2326503339298,
#    418.98595644593235,
#    331.92631931532486,
#    243.06180976962307,
#    301.4177811397772,
#    27.346632976905692,
#    271.0527134120889,
#    333.48716002654163,
#    286.49469811679484,
#    112.35166501286555,
#    200.23812447600977,
#    305.24632843142837,
#    182.47459176282274,
#    332.9351020793666,
#    310.4458383330333,
#    250.1653821051913,
#    379.6039024375042,
#    217.60984763541344,
#    57.14933204074539,
#    346.12522606393185,
#    50.590583774143674,
#    305.6169439498893,
#    285.60089404738727,
#    284.1940632848837,
#    239.92532903335203,
#    122.60953408029467,
#    328.2752437871738,
#    125.68518865630975,
#    106.47363236382034,
#    208.86701071279103,
#    381.8180353718468,
#    201.20333662680582,
#    302.96060076869907,
#    239.98121600322762,
#    352.62999158552714,
#    279.37583582976566,
#    278.86381042467264,
#    336.2957360645867,
#    68.77172993688002,
#    363.99311577015277,
#    246.99741323668508,
#    227.35281048889414,
#    247.65493994996805,
#    271.30401922336796,
#    160.97055435440373,
#    268.5043664197246,
#    102.07145776728254,
#    191.13791224549007,
#    182.02702325709438,
#    202.75012502223206,
#    197.3040813500092,
#    291.1928958429443,
#    104.8849995927179,
#    334.89089566404584,
#    103.76346214184015,
#    269.48177088244483,
#    318.06542370090153,
#    164.6821881165062,
#    188.10293522196176,
#    416.9082563815933,
#    56.004387464909605,
#    148.29936929886568,
#    50.635341318322176,
#    281.3738194408906,
#    147.8485597179146,
#    157.15517090336212,
#    224.80326105044426,
#    308.29499265998555,
#    228.7669728464024,
#    99.87216551140378,
#    205.45147094120685,
#    139.9537787572771,
#    180.60116805538476,
#    139.08881145916274,
#    4.399097050495834,
#    230.4857678360506,
#    269.14986148043374,
#    40.19738404471432,
#    198.09587166877873,
#    129.34381242602515,
#    233.629449558088,
#    301.5900678701004,
#    347.203076724156,
#    163.6786906644198,
#    160.60748202496342,
#    123.2226996209535,
#    271.0340918263128,
#    321.16196895743104,
#    13.59279840112661,
#    156.5415490408917,
#    363.36784693807436,
#    206.15071115724083,
#    77.82063610981446,
#    371.8270373423051,
#    406.73514709434374,
#    317.51784821408637,
#    394.2267809905753,
#    92.4070830349138,
#    323.4730757587159,
#    168.51701443644336,
#    108.31801354654908,
#    305.24749612403866,
#    60.322159459136124,
#    188.28979416092687,
#    99.61370702862745,
#    229.24024266042287,
#    279.03642256030906,
#    264.7900109162145,
#    367.0193469043865,
#    182.5288231020089,
#    193.06650761734173,
#    149.04912923649525,
#    203.91250271758005,
#    73.79416208402364,
#    261.2304348438179,
#    215.82585090970102,
#    121.57593811575444,
#    247.1096613399958,
#    148.0949368347956,
#    162.11768752866953,
#    142.5209575117538,
#    149.8141604426136,
#    164.4300848938789,
#    16.175094870104072,
#    298.4124314209693,
#    374.20425769029424,
#    346.528588513821,
#    192.34433190804828,
#    256.8774782564583,
#    290.986408493914,
#    265.9764475251705,
#    266.9872711701117,
#    118.80330233207721,
#    132.13424940943943,
#    369.82002496002735,
#    285.6115398513324,
#    126.32109794284304,
#    339.7286678572544,
#    200.4911368491008,
#    379.2228527405725,
#    81.13610825833814,
#    101.36146116248827,
#    59.44814960983755,
#    176.40245270283268,
#    227.56111727718027,
#    27.898979507973525,
#    354.69588382738635,
#    309.5031828126705,
#    110.74379847474769,
#    169.96630416037692,
#    369.1878095336521,
#    254.1837520190947,
#    247.24944995712002,
#    313.4700815762724,
#    265.25270129860087,
#    190.52266382040744,
#    264.41929471585604,
#    385.87261908076727,
#    180.340155082448,
#    56.100900660887774,
#    177.57693245450812,
#    209.0377497085285,
#    249.93476153743805,
#    73.62087442221714,
#    269.9598673123892,
#    248.95203095852247,
#    86.09201581000633,
#    379.9857414448201,
#    313.3817138455321,
#    193.78880403138567,
#    209.3207017262247,
#    77.18660133476065,
#    189.12668958146836,
#    337.28870000051364,
#    51.64527376767914,
#    162.23859428809877,
#    223.72712923861812,
#    202.30351206353612,
#    269.36122470464073,
#    325.2999576887514,
#    116.46798448665524,
#    173.8104660118652,
#    282.7893439220384,
#    339.83280481348584,
#    198.76010582769342,
#    380.5275094127586,
#    137.42940280006377,
#    210.7668934784042,
#    349.7154500218963,
#    214.65885584226888,
#    238.95605751861808,
#    260.4564859657506,
#    409.16019941124074,
#    103.95195500193338,
#    327.58460619407174,
#    108.4759172100812,
#    309.0779108848366,
#    399.9679319651996,
#    258.48899002701114,
#    275.1997919958953,
#    63.45189766690317,
#    378.5203246100206,
#    361.8609436870623,
#    196.63996671023662,
#    312.26803366695725,
#    218.18980264388688,
#    130.89387508844504,
#    66.00210790703322,
#    190.55849761698443,
#    275.9003389773152,
#    326.77680799703415,
#    23.03868260761745,
#    103.91833712341848,
#    186.69594669994623,
#    194.47820282569572,
#    126.10198244912948,
#    321.75452771389064,
#    224.52065274025347,
#    126.97437744613626,
#    222.45450689725644,
#    233.8882752828473,
#    362.8154339354354,
#    136.207022196413,
#    37.039059620370054,
#    327.3065867566289,
#    250.88905280305306,
#    262.54218613757314,
#    67.48839599858708,
#    282.646245204659,
#    122.3619134142642,
#    283.8455212139631,
#    108.09669690019273,
#    112.39277089703624,
#    71.2897278941312,
#    362.29473688942556,
#    35.988292060709895,
#    40.78176326765652,
#    159.85384991118983,
#    323.8491643031964,
#    352.2749990497078,
#    240.29249250406085,
#    271.61026835694867,
#    248.36663526743212,
#    338.9227344807281,
#    183.85966665921924,
#    205.74291964687012,
#    326.7781675493924,
#    300.9168372439088,
#    183.53552172619177,
#    400.9869647108201,
#    33.783508753672685,
#    201.85059964848904,
#    340.1306081368144,
#    408.5458420745417,
#    341.56099841900664,
#    124.29962819093407,
#    197.4780878583176,
#    231.09852020423105,
#    343.7083782668419,
#    244.80975086164705,
#    96.90116065310558,
#    124.39537882783505,
#    396.3477262744266,
#    36.61420039315526,
#    204.33927397031087,
#    313.16522866079964,
#    41.979229350767376,
#    259.89188836802555,
#    242.73560762715732,
#    357.80003119882747,
#    180.36064494507224,
#    176.82571632620272,
#    93.05988508468813,
#    119.35082403621408,
#    335.05500315314146,
#    288.2018757174141,
#    144.61151286043517,
#    239.692568783206,
#    129.20936864819947,
#    314.3581951387064,
#    105.91083575949246,
#    313.4252881816264,
#    68.90891773569352,
#    241.93069726187926,
#    177.4143079381506,
#    181.83825200858908,
#    402.4289703202205,
#    136.6906289715916,
#    172.83532019271232,
#    26.7294334028513,
#    137.6279045245949,
#    107.48508245601676,
#    236.93171396415244,
#    365.1063197795099,
#    252.167394691417,
#    380.6169109659945,
#    317.2493826979717,
#    293.10718107368183,
#    383.07075178875147,
#    289.84884461492277,
#    305.59348000935046,
#    122.43989011268496,
#    62.05659663934089,
#    418.8763971799657,
#    47.019874480574714,
#    153.50598197053327,
#    96.46863509114976,
#    134.4377427573279,
#    284.3511298176253,
#    131.44009361928707,
#    328.0020601721516,
#    315.4922684755395,
#    8.703086651625187,
#    206.42610108477635,
#    229.46121350953223,
#    351.8193517497924,
#    345.3850013326386,
#    195.8418897550452,
#    43.79155703630782,
#    392.93634414085074,
#    281.27336859104014,
#    343.5049773728231,
#    258.10156646958717,
#    347.7975287045216,
#    166.51046410703358,
#    395.97154550199167,
#    189.5242322905125,
#    257.95371842780986,
#    316.68956598122855,
#    7.34141594763366,
#    251.077541978039,
#    22.36069350584124,
#    207.01905060450673,
#    111.30209405990257,
#    161.92300245653715,
#    373.82896511335963,
#    78.4905484275853,
#    303.57603820374317,
#    227.96253234158962,
#    105.40198526976515,
#    104.16701268391058,
#    183.54130033270414,
#    193.97155833692406,
#    9.320371182971956,
#    42.4260593773233,
#    282.73346853254264,
#    297.7024916566708,
#    311.873184101946,
#    188.0498151255334,
#    280.2955614335269,
#    236.64111129180725,
#    311.8357540024434,
#    385.10830887869764,
#    162.3708630799016,
#    99.10215595592568,
#    271.32021360153004,
#    222.9589475408272,
#    378.07105772998125,
#    194.60557544518664,
#    157.5386315335043,
#    133.34751865894083,
#    146.76055264048105,
#    162.706228381822,
#    176.34355849367026,
#    179.0750652483508,
#    190.67993753829734,
#    196.2112105186846,
#    360.2922649683915,
#    29.301211413506042,
#    125.4130111430878,
#    194.24313233158676,
#    237.3253644775799,
#    14.79930566882214,
#    94.07103759557874,
#    331.74371573757185,
#    371.80594848169244,
#    244.06182636588312,
#    318.15697321739015,
#    137.67167639229675,
#    213.73160256112928,
#    277.84607707436345,
#    54.92797121830314,
#    314.26601943246516,
#    178.30153369056052,
#    316.57869915654373,
#    279.6388576733965,
#    193.86630667005875,
#    341.9688820753572,
#    284.0407730866548,
#    137.2692097625211,
#    49.266391497021154,
#    104.32614712051917,
#    227.75691880563326,
#    142.3877911728311,
#    267.1896330634154,
#    193.31102484317094,
#    225.86696537716546,
#    52.930978907206814,
#    100.03370148564198,
#    30.786508797874006,
#    265.8618728694348,
#    45.717108759325285,
#    272.38488416155644,
#    331.11627039419847,
#    276.7629139454531,
#    133.14390122865632,
#    142.25018611945563,
#    221.65104979353262,
#    178.04528574705762,
#    325.86237296187716,
#    408.78001769070664,
#    311.16354694095867,
#    172.4975326089113,
#    221.8150785006723,
#    227.91814589365075,
#    14.984197083541488,
#    40.99268460959844,
#    311.40766124212814,
#    357.56000818021056,
#    40.49594393440219,
#    292.1791950701652,
#    251.74412301661863,
#    181.4975430446033,
#    44.62720349472696,
#    230.76139530576205,
#    83.29275457931428,
#    159.15168086626412,
#    201.60885695236192,
#    158.75321025586032,
#    197.89334107599527,
#    146.48224481310555,
#    359.3396960919908,
#    269.32391802796036,
#    112.18617287690898,
#    201.92680635397514,
#    43.51690649043073,
#    301.51802439189294,
#    297.3523734501115,
#    300.51534477121487,
#    81.73072770021454,
#    220.80736360615353,
#    89.40620555546434,
#    12.037706460859388,
#    41.68781490741906,
#    242.31910548458941,
#    356.2037152341249,
#    388.5097899460344,
#    76.2963598853387,
#    219.94150377448128,
#    379.35985373023607,
#    204.49546311384609,
#    136.10649756920043,
#    3.2112364043907524,
#    257.12274754821357,
#    115.76666014868287,
#    110.8721604451968,
#    264.08887833944493,
#    211.7375045914923,
#    345.34048903661534,
#    207.04766406709902,
#    237.976910997182,
#    348.13331660676624,
#    254.01640805676857,
#    162.21206575858858,
#    196.59463249662846,
#    233.79265656407009,
#    237.75826281583412,
#    218.35251450217092,
#    130.93911064098566,
#    25.6707330995124,
#    326.9309032325172,
#    274.1968463078184,
#    118.60754342120711,
#    117.15084477520121,
#    181.65387093903877,
#    366.9410029267012,
#    130.2683129765436,
#    122.8137595422336,
#    388.318014563776,
#    293.1039245553929,
#    275.8487990329865,
#    313.70667096534385,
#    275.20582679859194,
#    157.29264730622984,
#    157.80177555319705,
#    186.4084280387325,
#    141.09056523784398,
#    400.21657188565723,
#    196.02776415642947,
#    253.04901497454622,
#    335.39718435538305,
#    72.81159205355726,
#    85.20817572968507,
#    236.57172867890085,
#    386.928767032827,
#    195.0479735342871,
#    389.4973564191297,
#    146.64208079839017,
#    31.26399782210165,
#    144.48482413409005,
#    353.61225870853013,
#    114.71785149413917,
#    404.1702326137905,
#    136.58108445348077,
#    250.9450431394284,
#    164.65367912775915,
#    33.13617049829029,
#    320.70572950145726,
#    275.25277300153317,
#    269.61486220822565,
#    136.07578374778373,
#    226.47409304264593,
#    219.24254858192376,
#    385.5718952813834,
#    239.81929181790596,
#    356.99643323078317,
#    322.33184737724406,
#    344.48002850930897,
#    253.21144456371206,
#    258.91021870469564,
#    159.3273902958132,
#    170.45909404882508,
#    109.20195650108491,
#    223.40910502822078,
#    139.1969504556711,
#    254.071079084817,
#    327.1935548273255,
#    261.81264586019154,
#    263.46411738882364,
#    140.16623674322486,
#    103.35995274493106,
#    117.92182378745984,
#    369.436412563347,
#    84.49797506102341,
#    216.2621337436872,
#    34.066534294016364,
#    221.24272082948414,
#    62.02579559553361,
#    228.23246534740292,
#    107.40378883448894,
#    33.23440430993256,
#    245.18917673469656,
#    98.91940796190018,
#    409.48075596251306,
#    60.456157500253944,
#    198.057752962379,
#    80.45512543178816,
#    139.09136180552034,
#    293.2065793552891,
#    333.48596033511944,
#    183.3119898219103,
#    354.14861645374816,
#    274.657849904591,
#    104.71507611279368,
#    357.81139842478865,
#    355.52482792274816,
#    386.66104745306296,
#    267.2351215855942,
#    215.04348270495086,
#    213.8036307983658,
#    375.28379637224646,
#    315.6777760734665,
#    53.5392475599601,
#    65.24025666165586,
#    187.64544147561693,
#    382.2047225273464,
#    191.26752590999612,
#    106.4266656798381,
#    92.41250962381714,
#    362.4803958153522,
#    20.193025747586777,
#    77.54793639119812,
#    384.72798384221073,
#    113.4596756657504,
#    149.6504683892976,
#    381.27431423408063,
#    99.02609536419256,
#    148.05265790557416,
#    168.0229617656079,
#    378.86621762950193,
#    76.20979899452736,
#    318.0246787176829,
#    108.89092666849604,
#    217.58273779811879,
#    134.5744637329381,
#    141.70287264921174,
#    293.5336258619472,
#    205.66022214246547,
#    141.16667915615687,
#    198.80408127707457,
#    269.2398385874565,
#    81.53907708386564,
#    413.7000780787046,
#    228.83833190304998,
#    90.77101826202426,
#    254.1877515105803,
#    61.018875065427615,
#    262.6365917538059,
#    160.04710590457876,
#    182.984517437626,
#    145.9694212107705,
#    196.48009217577683,
#    204.54341245241685,
#    50.83309116354825,
#    239.4655551879804,
#    344.152373820146,
#    110.88683273973494,
#    320.06945882939857,
#    149.2949341744084,
#    298.72417805110365,
#    98.17326303607112,
#    356.88367704701767,
#    145.4248430604716,
#    231.0410695443378,
#    316.34708665688424,
#    360.6023048264559,
#    334.3097500223218,
#    323.4951571919313,
#    327.1645662186554,
#    233.37237540012475,
#    197.85946471139425,
#    363.34554835030207,
#    180.05152127581277,
#    396.08094358067365,
#    36.65379543544308,
#    219.22947873168383,
#    257.05998414117045,
#    210.197987837211,
#    152.58700492906797,
#    238.9001365145085,
#    332.00532198544266,
#    204.15303799819873,
#    332.1971749646372,
#    115.24548830431995,
#    120.17118897213471,
#    34.27826034338763,
#    294.94119600735957,
#    40.88134635308035,
#    89.01504259645169,
#    217.35096150853894,
#    386.3500300774168,
#    193.3621584609147,
#    58.43799265071112,
#    61.896616861515575,
#    401.08125731893006,
#    90.09081118296214,
#    46.21687497305659,
#    103.35813285764083,
#    227.00614499336194,
#    75.43409346876005,
#    348.3748438742801,
#    66.35182414761475,
#    262.3461005237313,
#    186.57899906808143,
#    230.64641484226144,
#    341.8726338606532,
#    108.90631155639662,
#    271.28471268954263,
#    95.9437037118751,
#    138.2896181710066,
#    295.6109314938208,
#    215.2884092272824,
#    408.11332941235025,
#    261.39962854552607,
#    292.60894757143944,
#    227.837871828369,
#    373.5235454697264,
#    12.774918628377618,
#    348.4238121302145,
#    149.2951126851552,
#    95.56973291446185,
#    272.09098467185106,
#    275.29962298253884,
#    261.59549675557895,
#    40.888596261399265,
#    205.36826287292774,
#    6.700190548604726,
#    298.5944699810349,
#    237.67071923990227,
#    214.31890797019395,
#    337.18404873096245,
#    319.13233121121186,
#    202.82985238391618,
#    266.33133218210935,
#    149.62994712847848,
#    89.00171329272452,
#    236.4692946564735,
#    390.3152264313233,
#    242.06401411956236,
#    143.48511201741053,
#    271.29308556079116,
#    238.38396743644907,
#    306.4966951834383,
#    122.3019079005917,
#    315.98210631892255,
#    32.186863059621814,
#    99.63517770310094,
#    138.9055351644752,
#    189.968400881188,
#    330.0488940403479,
#    277.7839410846397,
#    68.00138673426702,
#    92.07064071011865,
#    152.1107188057926,
#    380.10389219941993,
#    85.0885533269305,
#    253.180597995143,
#    33.87104168526698,
#    340.3778605410811,
#    223.9988957594636,
#    290.2261692653952,
#    324.0960898649756,
#    203.42700550563558,
#    134.71067555818183,
#    280.2616564890006,
#    93.97872094973191,
#    254.06903890734435,
#    363.572207385933,
#    19.40412668892774,
#    396.38870380635933,
#    321.7747166225229,
#    92.33040614377225,
#    303.9939862962543,
#    236.00199171712723,
#    250.69110813391035,
#    168.06500371971904,
#    212.81858279476006,
#    256.8512806245765,
#    210.99080806380576,
#    344.382569963507,
#    183.73619090697815,
#    62.628277337467324,
#    254.6582176459783,
#    119.36700915645709,
#    34.52791797382669,
#    309.7324428173606,
#    302.2439809399395,
#    272.9008232346551,
#    252.4312987079469,
#    19.856285166598138,
#    36.70009055859597,
#    274.0285864305441,
#    319.8715264756706,
#    97.5905432430629,
#    97.06964965349535,
#    120.69845135838325,
#    366.27516341081997,
#    282.8976425316729,
#    254.13886120489016,
#    66.44418551180992,
#    236.50454912668323,
#    155.58503863279685,
#    321.17049265143066,
#    79.61258659499903,
#    107.31493292985199,
#    265.62897774519206,
#    90.56643041686503,
#    105.95607374604526,
#    150.79191294078393,
#    398.2255378979788,
#    67.76147891500904,
#    86.20282444372594,
#    175.0847013592552,
#    230.14504149936343,
#    211.9088988233278,
#    315.7613446205692,
#    157.78660082281033,
#    12.192277964568285,
#    383.4502602104956,
#    36.24227220471691,
#    231.57376648421436,
#    189.0113660510384,
#    261.8797955448958,
#    317.6731369854467,
#    134.29681437722405,
#    104.54276955323073,
#    365.908015858414,
#    99.39442134968175,
#    385.5533581703668,
#    199.31484430308018,
#    45.05797582574345,
#    283.8601986889052,
#    263.34264711762296,
#    307.4550242608059,
#    73.74300229782806,
#    146.68450929277472,
#    227.04772284061139,
#    56.10828721688612,
#    58.58446640915368,
#    274.7601839137087,
#    391.82513655493074,
#    75.7585999276379,
#    377.2047194271176,
#    230.3359881617504,
#    191.69547032045864,
#    287.3475580501375,
#    343.7830045648901,
#    262.6561559492572,
#    41.93871795358618,
#    245.64171757940497,
#    203.5018412813203,
#    329.90621803367577,
#    283.0966599551424,
#    383.5376192709637,
#    59.53682629212827,
#    312.0393720074384,
#    88.79484303242515,
#    226.21804780837584,
#    217.81905704959357,
#    366.3143282539674,
#    292.2284338308538,
#    136.2687239888051,
#    332.7915935902022,
#    232.54253746167734,
#    339.1614862367022,
#    327.51657136914207,
#    289.3677378185728,
#    355.7261669961658,
#    187.16716044609893,
#    191.4369220487907,
#    40.524598088334336,
#    315.5290921099113,
#    227.6814681186274,
#    79.8642026302192,
#    299.0485796646441,
#    210.8291482511803,
#    168.20544215933245,
#    180.28999127037883,
#    299.76712514536956,
#    67.59939512880075,
#    349.2704719187326,
#    269.97042885657083,
#    327.58362706120874,
#    216.73725147858772,
#    263.9507812860107,
#    247.4444853663745,
#    286.23226300793004,
#    21.451270035749964,
#    330.1757801499844,
#    69.89417230896873,
#    181.87611403123546,
#    198.3600974000917,
#    271.80604016030827,
#    82.81348660736555,
#    308.8531221882777,
#    214.9781273351503,
#    215.77500134720515,
#    156.26286229709817],
#   'posY': [153.86917511412847,
#    37.4957486305284,
#    42.13136490069763,
#    95.56766642157324,
#    68.0652893085407,
#    71.77641633639988,
#    27.26655376905237,
#    114.07412892782826,
#    135.70718485698728,
#    143.7881916836169,
#    14.963896918170178,
#    148.06652022426005,
#    12.486261536272181,
#    146.30052602218822,
#    87.69143668540535,
#    82.90427815495052,
#    131.63801858834503,
#    142.39577689059317,
#    2.2761877038231613,
#    97.92123565868725,
#    111.80299064131432,
#    59.471666558835274,
#    0.0817163562230495,
#    6.929326931028318,
#    90.3517659703745,
#    123.38255537787673,
#    137.85661470061527,
#    92.37788416752595,
#    98.6481022942066,
#    160.41779273816064,
#    63.878921060459014,
#    63.647801286959606,
#    159.58474576493197,
#    9.570591289905227,
#    53.11346275487742,
#    25.915593913206457,
#    66.84752804468536,
#    125.58895229462792,
#    102.2386249006855,
#    48.469850571902505,
#    42.237013658313316,
#    100.81472962125794,
#    66.96989337060185,
#    75.38264925813287,
#    18.658863122294456,
#    146.85516476668718,
#    104.13632868839373,
#    36.79271199418495,
#    109.66485571623713,
#    58.42212877680265,
#    21.357772882815503,
#    119.79038376636701,
#    126.68807128458934,
#    71.51063191901179,
#    87.335196568086,
#    15.354451351974054,
#    48.19527200991911,
#    84.33645499345697,
#    31.31686056705963,
#    20.874152679714808,
#    110.14740996357766,
#    21.922802312080094,
#    85.69053214281226,
#    163.7520116339042,
#    55.69138207519069,
#    91.03415427581824,
#    121.96354982344585,
#    145.71889111992232,
#    106.32512383593175,
#    17.176378571575885,
#    469.54709528945784,
#    516.8465440681389,
#    358.4500889530866,
#    274.7638492575386,
#    617.1432620343963,
#    617.4347370401856,
#    631.7945232853414,
#    260.37122065783825,
#    165.26142619342556,
#    285.15036681200786,
#    633.9965908733553,
#    473.8616278239233,
#    444.06163669640586,
#    379.92378412938353,
#    628.7283275688201,
#    378.07231182750394,
#    214.53742598572993,
#    401.5748692362828,
#    567.8445262339044,
#    495.90788464851727,
#    660.6027077363867,
#    553.841028652182,
#    519.2123574116802,
#    516.469878922543,
#    602.3386763360163,
#    570.3569770461141,
#    364.2228874282909,
#    293.1737304401976,
#    663.8748798993875,
#    664.4450746616486,
#    346.8119629974277,
#    407.2075310016275,
#    470.9783069984875,
#    313.7187274116555,
#    515.1301905842623,
#    652.8048480654264,
#    442.9703301497832,
#    506.19039415093874,
#    359.479030155523,
#    398.24791499363073,
#    644.2899940096462,
#    625.7606257374714,
#    197.5686905407429,
#    241.57194863713488,
#    505.8087273522404,
#    375.9645843915426,
#    372.7489841927418,
#    570.1415809539743,
#    624.2195467067864,
#    458.111051049446,
#    571.274091645271,
#    499.4690748587575,
#    665.4395245166282,
#    658.1255047171956,
#    538.8181164090796,
#    311.1152361856007,
#    220.19483502826495,
#    369.08612232501616,
#    603.7242395052355,
#    408.4224495149701,
#    584.7704410188136,
#    518.6838539567176,
#    538.8052853399676,
#    181.0011969532107,
#    489.14173377773216,
#    217.81970601382022,
#    392.53797673572456,
#    177.00010485126634,
#    588.1545617509884,
#    503.861524790858,
#    302.02010532092066,
#    342.15908573968545,
#    355.6896121999031,
#    241.1292631425887,
#    212.364371443747,
#    176.0167436120313,
#    337.08717958107144,
#    457.5719184537032,
#    332.35912320021515,
#    469.46610689808006,
#    513.4021544266208,
#    265.7999275263562,
#    560.0636982122293,
#    176.66072318423568,
#    186.96173832415144,
#    391.54355772269525,
#    593.4861653090865,
#    607.368311382031,
#    352.40551915580136,
#    332.447557235607,
#    278.85798065882034,
#    430.5294411492782,
#    332.2088828309865,
#    178.34084812443868,
#    340.3884032257156,
#    580.8274823716298,
#    340.3697809963031,
#    589.6867206821478,
#    553.8282738701668,
#    537.3346903295883,
#    565.4309592706177,
#    490.8931959153742,
#    422.5014415320183,
#    362.73268207783326,
#    354.24240368248184,
#    393.7019688805081,
#    259.00404489863706,
#    653.3639217344346,
#    167.84968313158032,
#    227.17179121361494,
#    604.102415672746,
#    546.7560396570931,
#    491.94621580226715,
#    169.21410437750626,
#    529.8581359053062,
#    259.59206186881147,
#    483.152750287318,
#    544.225261483208,
#    182.3607244928603,
#    295.4764573921383,
#    219.3377857114841,
#    609.1036402590164,
#    639.6825203084953,
#    265.2744016046807,
#    372.6143802250232,
#    640.703917266137,
#    220.7020098726745,
#    512.5945528171671,
#    241.56378626825247,
#    306.9428008108747,
#    242.04731690249795,
#    627.4193886550083,
#    441.8262649423712,
#    179.0479421263803,
#    603.0071504917044,
#    296.052850218158,
#    645.2567302694031,
#    173.1406860658958,
#    277.4522843550997,
#    192.06423397302996,
#    661.7368192884608,
#    547.0182282450189,
#    570.254007106076,
#    183.65497691386682,
#    480.9661590497838,
#    604.7569855996414,
#    599.2099752014512,
#    228.9896301350194,
#    205.75791785520735,
#    570.181554574926,
#    610.2047737052341,
#    566.7542664443836,
#    352.9724619615128,
#    220.2323088156827,
#    436.63096983704924,
#    650.2341858758014,
#    331.218607504078,
#    293.8286397453722,
#    307.2950960258695,
#    211.75014687676492,
#    494.39104610570257,
#    461.2477117437051,
#    649.380608030815,
#    193.95851665433716,
#    439.81518321107444,
#    302.3142383420648,
#    362.23247435990567,
#    183.0746927449562,
#    350.70930418040246,
#    630.6404326916918,
#    268.3293563649149,
#    433.96908405108627,
#    362.67646456241084,
#    322.87292107850055,
#    284.2172198894864,
#    474.5724220421243,
#    651.1133191972671,
#    509.00415247616024,
#    216.1019073976502,
#    652.9814976723954,
#    412.04304073739866,
#    534.4052506245995,
#    583.9423000723538,
#    229.36408435671447,
#    179.34590457286362,
#    417.34579410430933,
#    560.8980604707361,
#    647.0034518590901,
#    283.9703669940549,
#    448.7751090404812,
#    519.8082259947223,
#    286.8761781435059,
#    212.14158882133114,
#    353.00292925223175,
#    358.9745743094155,
#    383.3080336033357,
#    321.5837103817668,
#    370.7619269388374,
#    271.9400695181489,
#    567.4757149208622,
#    380.63854375788645,
#    185.62726099039352,
#    282.9382271075285,
#    290.5749642242969,
#    499.5219591070339,
#    284.6167869355784,
#    227.48927556322067,
#    232.2911709610845,
#    171.25271628788192,
#    812.3188442776521,
#    817.32604240251,
#    843.3599600247034,
#    670.5460462640258,
#    687.35015625307,
#    804.3372171372322,
#    725.1127800363711,
#    800.8259483702439,
#    731.514600798515,
#    849.33262989905,
#    722.859305827818,
#    737.254119979911,
#    716.6034024336516,
#    778.6860593861179,
#    754.0865811496603,
#    668.5934607148856,
#    748.4437316386524,
#    743.3333616443953,
#    787.9236693191408,
#    837.7237076157882,
#    704.4051098931793,
#    688.83095967415,
#    722.7846205365656,
#    813.0249065256098,
#    679.8857760158392,
#    743.7708372003914,
#    769.6226084707774,
#    751.4114851054485,
#    686.9196950516255,
#    688.1059097634903,
#    816.6203665010732,
#    854.7653833871526,
#    846.4565854097473,
#    777.1340022140187,
#    713.2140719960933,
#    785.9123058050553,
#    688.4477737649419,
#    778.2330893857365,
#    833.2697305489039,
#    697.474229960592,
#    786.8620146343359,
#    830.3280315903984,
#    837.4294656060827,
#    699.4932758523772,
#    857.5440057602059,
#    780.7406521904308,
#    742.1764863004926,
#    738.0740339941527,
#    717.7213498535489,
#    776.6087218630834,
#    697.934604720401,
#    728.9636064101823,
#    746.2713876574135,
#    735.9416868007152,
#    704.247690432258,
#    816.8406416822353,
#    788.6238651027809,
#    778.6171728158646,
#    726.3240065267562,
#    778.9238956511402,
#    803.5316309462703,
#    828.9284611488412,
#    743.0977566275294,
#    704.4152428486201,
#    752.1182443202105,
#    686.0844901797315,
#    760.7008370191686,
#    685.8064820824549,
#    821.5801158947451,
#    735.6548953518776,
#    829.7712495707899,
#    833.5527297098447,
#    751.5684989538099,
#    671.4647745888306,
#    780.7349166638238,
#    692.5777202254269,
#    672.5758246775251,
#    779.1603735712094,
#    749.3490831332753,
#    741.2149371968454,
#    675.6491866325026,
#    807.687158425376,
#    776.7606386399677,
#    772.7861417325004,
#    799.2410544643157,
#    731.2679859092468,
#    808.9977736843102,
#    666.860140975927,
#    772.087101643624,
#    776.9877729770327,
#    837.467627571241,
#    805.1119564372674,
#    737.162035805225,
#    746.7403804911421,
#    811.9949990622822,
#    825.1290459774582,
#    782.1503590214219,
#    761.902332777277,
#    704.5799118703204,
#    822.2469020474759,
#    805.6704300775475,
#    757.4871735682302,
#    772.6323204719703,
#    705.9480608737701,
#    749.2947186967938,
#    853.6222743417642,
#    683.8377065492389,
#    856.3329592199779,
#    800.2180502932234,
#    784.6613778948715,
#    721.4921857735692,
#    832.2171505253069,
#    852.9660822806884,
#    738.9651883356223,
#    755.4003182204905,
#    753.7718140294916,
#    719.4377276085434,
#    847.791749393303,
#    710.0439102803664,
#    825.8536693148208,
#    729.6397801634652,
#    813.7717840558504,
#    696.1682465339676,
#    720.0745742918713,
#    821.9010772248829,
#    788.9298035159219,
#    765.3479982727775,
#    826.8206384636842,
#    791.2356636457714,
#    748.6941996019543,
#    766.5299380200296,
#    681.9997148656678,
#    680.6534006619664,
#    814.3169733607757,
#    836.1227043577258,
#    818.2517562274048,
#    717.8076609060932,
#    818.091093783689,
#    738.3993340184634,
#    694.6189082816404,
#    811.5379687441546,
#    699.4497957468625,
#    840.0182727626146,
#    764.0892080793341,
#    778.842042545983,
#    759.5348978512047,
#    701.4805451776533,
#    707.7322746647177,
#    745.4883426876346,
#    819.9742847099885,
#    693.9311990320265,
#    846.0305982999171,
#    816.8989964186821,
#    701.3787538626691,
#    812.538640929648,
#    781.6504083386523,
#    758.1276807989926,
#    734.2678347241441,
#    760.2517135816133,
#    771.6752162486978,
#    682.9741756941214,
#    692.2779564440348,
#    848.1329160265743,
#    683.1100020281324,
#    792.4951922815201,
#    774.9476962412568,
#    1168.8211262157995,
#    1227.4279890642194,
#    868.7495597502669,
#    1305.6385779032396,
#    1213.573086941407,
#    1310.543232222654,
#    1227.0221149430242,
#    1354.998590740178,
#    935.3011270266256,
#    1133.4711293493883,
#    931.0966756787745,
#    1310.091865782642,
#    1004.292923681502,
#    1318.3064852024795,
#    1380.2480243420155,
#    1001.5276658394673,
#    1087.951548441263,
#    989.9458018666297,
#    1315.1440363418683,
#    1286.169987697981,
#    1123.3229747275443,
#    1143.325560901676,
#    1181.9989673179132,
#    1015.4795819452518,
#    1230.879911611181,
#    1060.922300763409,
#    1247.502540997103,
#    1201.01045992515,
#    1086.3746046054962,
#    1106.261769440005,
#    912.192971011005,
#    1099.5257183014905,
#    1221.2972636995275,
#    1169.1843716426565,
#    1260.3560029047087,
#    984.0280050979582,
#    1080.3402671647602,
#    1278.467481010708,
#    971.9206911977509,
#    875.2594761733367,
#    1199.3283367087897,
#    911.9075765419669,
#    1287.1692879518528,
#    1013.2638113985416,
#    1158.226369310358,
#    1095.2008759880864,
#    1209.5607180734721,
#    1158.455030738913,
#    974.510074097835,
#    1207.6584710411685,
#    971.7044986659548,
#    961.920714300513,
#    1167.793324457254,
#    917.7209050109291,
#    1012.102848292094,
#    1073.3161786719754,
#    1072.2332589219714,
#    1370.2349391737966,
#    880.9339812777345,
#    1139.2710255847335,
#    1053.2441176599498,
#    1042.703584916929,
#    985.925150207373,
#    986.8973631780796,
#    1034.7375461079325,
#    1045.3537766543884,
#    1266.0803029719552,
#    1228.282773641716,
#    1312.9689956677703,
#    1192.577994078293,
#    1076.5442050462177,
#    1233.6416669431455,
#    1240.8665884496024,
#    917.8066201250947,
#    1019.3775072250493,
#    1266.6934262039351,
#    1142.937836261896,
#    1167.1384772320237,
#    1089.910933100872,
#    1085.4409130155086,
#    1180.3198769146632,
#    1097.4867677099112,
#    1095.4458288770547,
#    924.5596771031693,
#    881.9913237378412,
#    934.9119650775026,
#    1062.069683458759,
#    953.5275334431382,
#    1186.3333085041033,
#    995.1972542790628,
#    977.1563500651949,
#    1241.6283869551391,
#    952.5791302602992,
#    945.4473840483223,
#    1382.2814833271425,
#    1030.3589948939477,
#    898.1208144381472,
#    1074.2649978023169,
#    1027.8883322064094,
#    955.847995227646,
#    1155.3176749344548,
#    1127.6510304033714,
#    1245.247326167066,
#    1352.5984817887252,
#    1130.3846434969194,
#    1286.1377510946782,
#    1013.6733854369033,
#    1318.2729600781033,
#    965.9319016576568,
#    1118.6843279366633,
#    988.1522755711878,
#    1315.262035823059,
#    1048.1822980959307,
#    925.2633889370114,
#    938.6736331628333,
#    1230.5123082027826,
#    1085.0337424329796,
#    1359.2986423381244,
#    1329.146857092473,
#    1284.6733746245259,
#    1036.796545979916,
#    1328.184369597377,
#    1190.164403785764,
#    1192.6645855529234,
#    1127.113491978809,
#    982.141250980158,
#    1080.6921494677783,
#    1160.0097176574875,
#    922.2945007885418,
#    1008.46274339911,
#    955.7092535866877,
#    868.4984545029992,
#    1304.7064355191917,
#    1277.8877005214244,
#    1181.1329013401835,
#    1115.4617583538839,
#    989.7723810760219,
#    1126.2862741540657,
#    1336.330645971864,
#    1234.1423568166797,
#    1248.21964304226,
#    898.1164603656575,
#    1246.4621378005247,
#    1259.026967567255,
#    912.933831171256,
#    1229.06578400398,
#    1165.052612526332,
#    1135.2662835204296,
#    1144.298052392296,
#    1323.4336266037353,
#    900.4551415058748,
#    937.67705861722,
#    907.0782077432204,
#    866.5517018208876,
#    910.4310133597052,
#    1283.6828938014407,
#    1372.6459196858727,
#    1134.8027511351436,
#    994.4978306746254,
#    918.9129105054715,
#    1092.696968528453,
#    870.2935588336351,
#    1303.100646182227,
#    1231.201197768755,
#    1352.4563183840403,
#    1209.9106399872044,
#    932.7024209167532,
#    1121.7809050053663,
#    1274.4720415115153,
#    954.4466911799557,
#    1199.0431009228073,
#    1198.5365686054565,
#    1065.4444381546366,
#    944.5031205509345,
#    996.745102067867,
#    1009.7780981560234,
#    885.4823786991213,
#    1364.545158718038,
#    1230.540931987471,
#    1103.755417723815,
#    1147.9488846996323,
#    1350.283878572871,
#    890.3368290711825,
#    1224.4055487436995,
#    934.303233909106,
#    1006.7911014490204,
#    1237.3484017396968,
#    1084.1774250186959,
#    1163.228204724693,
#    954.1952454787411,
#    1256.8253874879792,
#    1353.6929682997156,
#    1074.3708124037657,
#    921.4624486887737,
#    956.2035890528272,
#    1294.021019282489,
#    1055.1469652202775,
#    1219.7033382114566,
#    967.4992622095581,
#    1268.398644462543,
#    1070.8698780479754,
#    1098.369228249285,
#    1116.9920286043584,
#    919.9575291253725,
#    1071.2200442774213,
#    949.9358823418935,
#    1100.8690013984133,
#    893.0116227902109,
#    1339.4441480116259,
#    1256.0025468235606,
#    1275.4184347089783,
#    1082.9061476261443,
#    1008.9931016291656,
#    1159.9226815282584,
#    933.3632684137515,
#    1296.0379769400047,
#    986.2090931967568,
#    945.4516276901095,
#    989.2028638012347,
#    1216.105765385946,
#    876.8706975037197,
#    940.7791743231501,
#    928.9797502613096,
#    1350.669451890635,
#    1032.4295140075112,
#    893.0411725314536,
#    962.0002046167701,
#    1096.3090137617316,
#    1249.3523671612681,
#    976.7247796723497,
#    1341.7211801127287,
#    1065.5616355473396,
#    1070.4151974653082,
#    1167.2602748452975,
#    1012.6034514335498,
#    1197.846657189012,
#    1039.483647591648,
#    1067.440170518061,
#    945.3375448341235,
#    1216.7039248912577,
#    1302.58622344459,
#    1151.100866464284,
#    1000.0895009028052,
#    1091.7501576732773,
#    1839.7642346877894,
#    1592.9037379119193,
#    1826.7913431155255,
#    1667.0200267713303,
#    1473.411249747935,
#    1388.269691640154,
#    1942.6712183786708,
#    1950.2634096396996,
#    1819.759277388938,
#    1450.7036394499542,
#    1828.813622946546,
#    1969.4928798714939,
#    1795.270853926549,
#    1880.3680719898566,
#    1548.215416665545,
#    1798.8241060899663,
#    1604.7672428093294,
#    1917.5063492047075,
#    2067.4839734076086,
#    1385.9943745132027,
#    1823.8001996786352,
#    1896.1329238900717,
#    1956.430939130679,
#    1530.107911133048,
#    1824.7054030791555,
#    1710.1658833998952,
#    1924.1184503899499,
#    1644.4167547563798,
#    1542.026627961309,
#    1466.8128590719073,
#    1804.151309403783,
#    1496.4367939475837,
#    1979.145589141631,
#    1525.6156473235415,
#    1423.1502579327603,
#    1674.832122208476,
#    2059.488646560218,
#    1624.0015900713984,
#    1779.3630843376027,
#    1469.8605583389503,
#    1788.6321420366596,
#    1729.3765942568143,
#    1914.122911121176,
#    1479.2719406910633,
#    1517.4129062079442,
#    1751.0450364963067,
#    1459.7457625439201,
#    1446.985782506296,
#    2069.4765933109998,
#    1612.6849090208418,
#    1868.8479601573647,
#    1559.953180571906,
#    1544.5937085421976,
#    1671.730596606433,
#    1860.1462752111997,
#    1925.7269087539282,
#    1707.9474968834008,
#    1852.0837156112184,
#    1601.118676570956,
#    1665.4356006039577,
#    1905.1862537458198,
#    1565.3250768849634,
#    1785.8633228044678,
#    1928.393846216151,
#    2066.576189544521,
#    2068.9190016562625,
#    1564.3483469646246,
#    1815.2579188455545,
#    1887.4979517926588,
#    1535.0561685593054,
#    1950.9800377938104,
#    1861.9480910573648,
#    1749.0661067424878,
#    1640.6053564925833,
#    1489.3071511310238,
#    1634.7592842616161,
#    1908.2074696781415,
#    1648.8429142261384,
#    2060.2070758097693,
#    1830.152974718602,
#    1713.0898405041803,
#    1553.9083695608442,
#    1757.2595290052602,
#    2038.4261880774848,
#    2066.1791724380137,
#    1930.221483301454,
#    1513.215342527252,
#    1620.5711940190843,
#    1805.7625197399589,
#    1483.7893071257554,
#    1717.9764016976708,
#    1843.245772534043,
#    1768.524776060284,
#    2063.624561242515,
#    1893.9633407403837,
#    1752.1904265119774,
#    2058.1441379349567,
#    1598.682337309388,
#    1994.603229505339,
#    1567.6386790986194,
#    1559.2060846195395,
#    1478.474631507346,
#    1451.3175276344332,
#    1727.219095450952,
#    1734.0948237152923,
#    1532.671285770316,
#    1712.9338680496091,
#    1834.7161426943662,
#    1996.5164129233688,
#    1914.937504990121,
#    1579.3828005884795,
#    1655.3146259016537,
#    1793.921318424042,
#    1522.3647426965283,
#    1660.4222110516152,
#    2016.237393272952,
#    1785.000945342505,
#    2001.622637723437,
#    1451.3863847607647,
#    1879.4636831379255,
#    2059.049033660555,
#    1431.1684240645654,
#    1759.6633206903414,
#    1926.7469825621372,
#    1543.4681142886589,
#    1718.818435804549,
#    1595.8341060234063,
#    1708.3715305843941,
#    2067.4420880845482,
#    1710.682355254141,
#    1920.4758397542882,
#    2004.5781035737948,
#    1641.5347150619516,
#    1596.6336979302744,
#    1441.4103928664806,
#    1862.1409390598506,
#    1865.034503777997,
#    2022.8806811961567,
#    1566.0493363218266,
#    1857.1828348959502,
#    2075.939080602433,
#    1935.4507318132046,
#    1404.8513395082796,
#    1845.67308058382,
#    2021.5001029390812,
#    1844.7932022986613,
#    2050.1456053396496,
#    1658.1716097166363,
#    1693.3443891669697,
#    1720.7683082761653,
#    1938.6298369383092,
#    2066.0082152863424,
#    1430.2165619005727,
#    1718.6028035701227,
#    1969.980761738059,
#    1726.033572670273,
#    1589.3523244685625,
#    1670.7125761903578,
#    1969.1885680367527,
#    1479.6550686121307,
#    1400.0725847408119,
#    1586.0383347553893,
#    1963.9966882649035,
#    1966.33158308163,
#    2070.843159084638,
#    1573.4345192044875,
#    1790.4917525565224,
#    1744.031965664942,
#    1793.2471601590553,
#    1499.2927636894779,
#    1524.827068028902,
#    1929.5194018678071,
#    1536.4104512790045,
#    1931.563769956739,
#    1745.4438940257533,
#    1941.445136583502,
#    1611.2835715833373,
#    1861.9163106322185,
#    1889.167670204416,
#    1469.546795883776,
#    1639.4159779213128,
#    1945.388467124284,
#    1689.1229450911685,
#    1419.2993565869883,
#    1583.4831271037956,
#    1895.6352091304204,
#    1671.0318846122307,
#    1600.8003613738977,
#    1480.70552389371,
#    1473.5022542565805,
#    1820.4609226375976,
#    1444.287048819844,
#    1424.6245231221392,
#    1967.4465781051279,
#    1723.0067959494334,
#    1962.6254365158786,
#    1519.2167888021693,
#    1885.7240806149364,
#    2026.6918511061997,
#    1409.5998422897048,
#    1480.8271874183763,
#    1776.0847518513192,
#    1691.7788518618004,
#    1760.9312229834677,
#    1609.2331983770428,
#    2017.8608861744356,
#    1673.1419977339344,
#    1612.7393611298235,
#    1615.252889335065,
#    1576.8407908717338,
#    1456.3598355347756,
#    1789.0941816529357,
#    1677.6343389100837,
#    1801.210124784147,
#    1958.6147800567805,
#    1421.8955894074536,
#    1683.8124309837474,
#    1575.9128025877642,
#    1987.5824866719363,
#    1561.582251364008,
#    2041.6064056534713,
#    1447.7344481056841,
#    1606.554785894384,
#    1467.2279506549062,
#    1942.5396022462185,
#    1743.2824920320504,
#    1436.7654224519847,
#    1474.8493695676286,
#    1766.974554581445,
#    1861.0282358806237,
#    1498.1481957147446,
#    1692.1322591020642,
#    1491.9817350235737,
#    1405.17093817722,
#    2015.9599472084622,
#    2049.1242400785786,
#    1546.002581490695,
#    1830.3571886138382,
#    1414.6029293741597,
#    1932.325053811225],
#   'posXpre': [],
#   'posXpost': [],
#   'posYpre': [],
#   'posYpost': []})

# %%
test[1]['connMatrix'] # total of synapses [AMPA, NMDA] or [GABAA, GABAB]

# %%
sim.analysis.plot2Dnet(include=cfg.allpops, view='xy', showConns=True, 
                               popColors=None, tagsFile=None, figSize=(12, 12), fontSize=8, saveData=None, 
                               saveFig=False, showFig=True, lineWidth=0.1);
# sim.analysis.plot2Dnet(include=subPopLabels,view='xy', showConns=False, 
#                                popColors=None, tagsFile=None, figSize=(8, 8), fontSize=12, saveData=None, 
#                                saveFig=None, showFig=True, lineWidth=0.1);
# sim.analysis.plot2Dnet(include=subPopLabels,view='xz', showConns=False, 
#                                popColors=None, tagsFile=None, figSize=(8, 8), fontSize=12, saveData=None, 
#                                saveFig=None, showFig=True, lineWidth=0.1);

# %% [markdown]
# ## Raster and traces

# %%
# include=cfg.allpops, 
sim.analysis.plotRaster(include=cfg.allpops, timeRange=[0,cfg.duration], orderBy='gid', orderInverse=True, labels='legend', popRates=True, lw=5, marker='.', markerSize=24, figSize=(20, 10), fontSize=20, dpi=300, saveFig=True, showFig=False);

# %%
# cellNumber[metype]
# for metype in cfg.cellParamLabels:
#     if cfg.popLabel[metype] in subPopLabels:
#         print(metype,cfg.cellNumber[metype],cfg.popLabel[metype],cfg.popNumber[cfg.popLabel[metype]])     

# traces = [(mtype, [i for i in range(0,cfg.popNumber[mtype],int(cfg.popNumber[mtype]/4.5))]) for mtype in subPopLabels]
# traces

# %%
# include=traces, 
sim.analysis.plotTraces(timeRange=[0,cfg.duration], overlay=False, oneFigPer='trace', ylim=[-90,50], subtitles= False, axis=False, scaleBarLoc=1, figSize=(24, 15), fontSize=12, saveFig=True);

# %%
for pops in cfg.cellParamLabels:
    print('\n\n',pops,'  N =',cfg.cellNumber[pops])
    sim.analysis.plotTraces(include=[pops], timeRange=[0,cfg.duration], overlay=True, oneFigPer='trace', subtitles=False, legend=False, ylim=[-110,50], axis=False, scaleBarLoc=3, figSize=(18, 4), fontSize=15, saveFig='../info/test/'+cfg.simLabel+'/'+cfg.simLabel +'_'+pops+ '_Vt.png');

# %%
netParams.cellParams.keys()

# %%
 sim.analysis.plotTraces(include=[pops], timeRange=[0,cfg.duration], overlay=True, oneFigPer='trace', subtitles=False, legend=False, ylim=[-75,-74], axis=False, scaleBarLoc=3, figSize=(18, 8), fontSize=15, saveFig='../info/test/'+cfg.simLabel+'/'+cfg.simLabel +'_'+pops+ '_Vt.png');
