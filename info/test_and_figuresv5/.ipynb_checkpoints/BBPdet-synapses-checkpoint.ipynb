# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Synapses properties of a S1 cell

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os
import sys

# %%
rootFolder = '/home/fernando/S1_netpyne/sim/'
os.chdir(rootFolder)

folder = os.listdir('cell_data/')
cellnumber=11
print(folder[cellnumber])

outFolder = rootFolder+'cell_data/'+folder[cellnumber]

durationstim = 200
delaystim = 70
timesimulation = 1000

holding_current = 0  #
step3_current = 0  #
# Out:
# L6_NBC_dSTUT214_1

# %%
# !nrnivmodl mechanisms

# %%
folder = sorted(folder)
cellnumber = 760
cellName = folder[cellnumber]

print ("CellNumber = %d" % cellnumber)
print ("CellName = %s" % cellName)
# Out:
# CellNumber = 760
# CellName = L5_TTPC1_cADpyr232_1

# %%
def loadTemplateName(cellnumber): 
    outFolder = rootFolder+'cell_data/'+folder[cellnumber]
    f = open(outFolder+'/template.hoc', 'r')
    for line in f.readlines():
        if 'begintemplate' in line:
            templatename = str(line)     
    templatename=templatename[:-1]        
    templatename=templatename[14:]
    return templatename

cellName = folder[cellnumber]
cellTemplateName = loadTemplateName(cellnumber)

# %%
os.chdir(rootFolder)

from cellwrapper3 import loadCell
cell=loadCell(cellName, cellTemplateName)

soma = cell.soma[0]
# Out:
# 	1
# 	1
# 	1
# cADpyr232_L5_TTPC1_0fb1ca4724[0]

# %% [markdown]
# ## Activating synapses
# Now let's define an _in vivo_-like stimulus, where input neurons are firing like Poisson processes with presynaptic morphology type (mtype) specific rates.

# %%
with open('/home/fernando/Downloads/hoc_combos_syn.1_0_10.allzips/L5_TTPC1_cADpyr232_1/synapses/mtype_map.tsv') as mtype_map_file:
    mtype_map_content = mtype_map_file.read()
    
mtype_map = {}
for line in mtype_map_content.split('\n')[:-1]:
    n, mtype = line.split()
    mtype_map[mtype] = int(n)
    
print (mtype_map)
# Out:
# {'L1_DAC': 0, 'L1_NGC-DA': 1, 'L1_NGC-SA': 2, 'L1_HAC': 3, 'L1_DLAC': 4, 'L1_SLAC': 5, 'L23_PC': 6, 'L23_MC': 7, 'L23_BTC': 8, 'L23_DBC': 9, 'L23_BP': 10, 'L23_NGC': 11, 'L23_LBC': 12, 'L23_NBC': 13, 'L23_SBC': 14, 'L23_ChC': 15, 'L4_PC': 16, 'L4_SP': 17, 'L4_SS': 18, 'L4_MC': 19, 'L4_BTC': 20, 'L4_DBC': 21, 'L4_BP': 22, 'L4_NGC': 23, 'L4_LBC': 24, 'L4_NBC': 25, 'L4_SBC': 26, 'L4_ChC': 27, 'L5_TTPC1': 28, 'L5_TTPC2': 29, 'L5_UTPC': 30, 'L5_STPC': 31, 'L5_MC': 32, 'L5_BTC': 33, 'L5_DBC': 34, 'L5_BP': 35, 'L5_NGC': 36, 'L5_LBC': 37, 'L5_NBC': 38, 'L5_SBC': 39, 'L5_ChC': 40, 'L6_TPC_L1': 41, 'L6_TPC_L4': 42, 'L6_UTPC': 43, 'L6_IPC': 44, 'L6_BPC': 45, 'L6_MC': 46, 'L6_BTC': 47, 'L6_DBC': 48, 'L6_BP': 49, 'L6_NGC': 50, 'L6_LBC': 51, 'L6_NBC': 52, 'L6_SBC': 53, 'L6_ChC': 54}

# %%
exc_cells = ['L23_PC', 'L4_PC', 'L4_SS', 'L4_SP', 
             'L5_TTPC1', 'L5_TTPC2', 'L5_STPC', 'L5_UTPC',
             'L6_TPC_L1', 'L6_TPC_L4', 'L6_BPC', 'L6_IPC', 'L6_UTPC']
for mtype in mtype_map:
    if mtype in exc_cells:
        freq = 0.0 # [Hz]
    else:
        freq = 0.0 # [Hz]

# %%
parameters_name = {}

parameters_name[0] = 'synapse_id'
parameters_name[1] = 'pre_cell_id'
parameters_name[2] = 'pre_mtype'
parameters_name[3] = 'sectionlist_id'
parameters_name[4] = 'sectionlist_index'
parameters_name[5] = 'seg_x'
parameters_name[6] = 'synapse_type'
parameters_name[7] = 'dep'
parameters_name[8] = 'fac'
parameters_name[9] = 'use'
parameters_name[10] = 'tau_d'
parameters_name[11] = 'delay'
parameters_name[12] = 'weight'

# %%
with open('synapses/synapses.tsv') as mtype_map_file2:
    mtype_map_content2 = mtype_map_file2.read()

n = -1    
parameters_syn = {}
for line in mtype_map_content2.split('\n')[:-1]:
    if n < 0:
        nsynapses, nparameters = [int(x) for x in line.split()]        
        print (nsynapses, nparameters)
    else:
        n2 = 0
        parameters_list = line.split()   
        for parameter in parameters_list:
            if n2 < 7:
                prmtr = float(parameter)
                parameters_syn[n,parameters_name[n2]] = int(prmtr)
            else:
                parameters_syn[n,parameters_name[n2]] = float(parameter)
            n2 = n2 + 1
    n = n + 1
# Out:
# 5863 13

# %%
parameters_syn
# Out:
# {(0, 'synapse_id'): 0,
#  (0, 'pre_cell_id'): 328,
#  (0, 'pre_mtype'): 0,
#  (0, 'sectionlist_id'): 2,
#  (0, 'sectionlist_index'): 81,
#  (0, 'seg_x'): 0,
#  (0, 'synapse_type'): 1,
#  (0, 'dep'): 429.0,
#  (0, 'fac'): 15.0,
#  (0, 'use'): 0.16103968024253845,
#  (0, 'tau_d'): 6.794517517089844,
#  (0, 'delay'): 1.51276,
#  (0, 'weight'): 0.452629446983,
#  (1, 'synapse_id'): 1,
#  (1, 'pre_cell_id'): 328,
#  (1, 'pre_mtype'): 0,
#  (1, 'sectionlist_id'): 2,
#  (1, 'sectionlist_index'): 81,
#  (1, 'seg_x'): 0,
#  (1, 'synapse_type'): 1,
#  (1, 'dep'): 694.0,
#  (1, 'fac'): 21.0,
#  (1, 'use'): 0.24616104364395142,
#  (1, 'tau_d'): 8.23503303527832,
#  (1, 'delay'): 1.52448,
#  (1, 'weight'): 0.812758266926,
#  (2, 'synapse_id'): 2,
#  (2, 'pre_cell_id'): 328,
#  (2, 'pre_mtype'): 0,
#  (2, 'sectionlist_id'): 2,
#  (2, 'sectionlist_index'): 81,
#  (2, 'seg_x'): 0,
#  (2, 'synapse_type'): 1,
#  (2, 'dep'): 440.0,
#  (2, 'fac'): 15.0,
#  (2, 'use'): 0.16474021971225739,
#  (2, 'tau_d'): 6.857142448425293,
#  (2, 'delay'): 1.54868,
#  (2, 'weight'): 0.468285560608,
#  (3, 'synapse_id'): 3,
#  (3, 'pre_cell_id'): 328,
#  (3, 'pre_mtype'): 0,
#  (3, 'sectionlist_id'): 2,
#  (3, 'sectionlist_index'): 81,
#  (3, 'seg_x'): 0,
#  (3, 'synapse_type'): 1,
#  (3, 'dep'): 972.0,
#  (3, 'fac'): 27.0,
#  (3, 'use'): 0.3353729546070099,
#  (3, 'tau_d'): 9.744772911071777,
#  (3, 'delay'): 1.52653,
#  (3, 'weight'): 1.19019329548,
#  (4, 'synapse_id'): 4,
#  (4, 'pre_cell_id'): 328,
#  (4, 'pre_mtype'): 0,
#  (4, 'sectionlist_id'): 2,
#  (4, 'sectionlist_index'): 82,
#  (4, 'seg_x'): 0,
#  (4, 'synapse_type'): 1,
#  (4, 'dep'): 796.0,
#  (4, 'fac'): 23.0,
#  (4, 'use'): 0.27881646156311035,
#  (4, 'tau_d'): 8.787663459777832,
#  (4, 'delay'): 1.17464,
#  (4, 'weight'): 0.950915813446,
#  (5, 'synapse_id'): 5,
#  (5, 'pre_cell_id'): 328,
#  (5, 'pre_mtype'): 0,
#  (5, 'sectionlist_id'): 2,
#  (5, 'sectionlist_index'): 107,
#  (5, 'seg_x'): 0,
#  (5, 'synapse_type'): 1,
#  (5, 'dep'): 688.0,
#  (5, 'fac'): 21.0,
#  (5, 'use'): 0.24416247010231018,
#  (5, 'tau_d'): 8.201210975646973,
#  (5, 'delay'): 3.04875,
#  (5, 'weight'): 0.804302752018,
#  (6, 'synapse_id'): 6,
#  (6, 'pre_cell_id'): 328,
#  (6, 'pre_mtype'): 0,
#  (6, 'sectionlist_id'): 2,
#  (6, 'sectionlist_index'): 71,
#  (6, 'seg_x'): 0,
#  (6, 'synapse_type'): 1,
#  (6, 'dep'): 514.0,
#  (6, 'fac'): 17.0,
#  (6, 'use'): 0.18839240074157715,
#  (6, 'tau_d'): 7.257410049438477,
#  (6, 'delay'): 3.89042,
#  (6, 'weight'): 0.568352460861,
#  (7, 'synapse_id'): 7,
#  (7, 'pre_cell_id'): 328,
#  (7, 'pre_mtype'): 0,
#  (7, 'sectionlist_id'): 2,
#  (7, 'sectionlist_index'): 71,
#  (7, 'seg_x'): 0,
#  (7, 'synapse_type'): 1,
#  (7, 'dep'): 720.0,
#  (7, 'fac'): 21.0,
#  (7, 'use'): 0.2544870376586914,
#  (7, 'tau_d'): 8.375934600830078,
#  (7, 'delay'): 3.91436,
#  (7, 'weight'): 0.847983658314,
#  (8, 'synapse_id'): 8,
#  (8, 'pre_cell_id'): 328,
#  (8, 'pre_mtype'): 0,
#  (8, 'sectionlist_id'): 2,
#  (8, 'sectionlist_index'): 95,
#  (8, 'seg_x'): 0,
#  (8, 'synapse_type'): 1,
#  (8, 'dep'): 630.0,
#  (8, 'fac'): 19.0,
#  (8, 'use'): 0.22556646168231964,
#  (8, 'tau_d'): 7.886509418487549,
#  (8, 'delay'): 3.38664,
#  (8, 'weight'): 0.725627303123,
#  (9, 'synapse_id'): 9,
#  (9, 'pre_cell_id'): 328,
#  (9, 'pre_mtype'): 0,
#  (9, 'sectionlist_id'): 2,
#  (9, 'sectionlist_index'): 82,
#  (9, 'seg_x'): 0,
#  (9, 'synapse_type'): 1,
#  (9, 'dep'): 719.0,
#  (9, 'fac'): 21.0,
#  (9, 'use'): 0.25409045815467834,
#  (9, 'tau_d'): 8.369222640991211,
#  (9, 'delay'): 0.461955,
#  (9, 'weight'): 0.846305727959,
#  (10, 'synapse_id'): 10,
#  (10, 'pre_cell_id'): 328,
#  (10, 'pre_mtype'): 0,
#  (10, 'sectionlist_id'): 2,
#  (10, 'sectionlist_index'): 82,
#  (10, 'seg_x'): 0,
#  (10, 'synapse_type'): 1,
#  (10, 'dep'): 552.0,
#  (10, 'fac'): 18.0,
#  (10, 'use'): 0.20069898664951324,
#  (10, 'tau_d'): 7.465674877166748,
#  (10, 'delay'): 0.479491,
#  (10, 'weight'): 0.620418787003,
#  (11, 'synapse_id'): 11,
#  (11, 'pre_cell_id'): 328,
#  (11, 'pre_mtype'): 0,
#  (11, 'sectionlist_id'): 2,
#  (11, 'sectionlist_index'): 107,
#  (11, 'seg_x'): 0,
#  (11, 'synapse_type'): 1,
#  (11, 'dep'): 896.0,
#  (11, 'fac'): 25.0,
#  (11, 'use'): 0.310922771692276,
#  (11, 'tau_d'): 9.331000328063965,
#  (11, 'delay'): 0.69873,
#  (11, 'weight'): 1.08675014973,
#  (12, 'synapse_id'): 12,
#  (12, 'pre_cell_id'): 328,
#  (12, 'pre_mtype'): 0,
#  (12, 'sectionlist_id'): 2,
#  (12, 'sectionlist_index'): 109,
#  (12, 'seg_x'): 0,
#  (12, 'synapse_type'): 1,
#  (12, 'dep'): 819.0,
#  (12, 'fac'): 24.0,
#  (12, 'use'): 0.2863050699234009,
#  (12, 'tau_d'): 8.914393424987793,
#  (12, 'delay'): 1.26475,
#  (12, 'weight'): 0.982598304749,
#  (13, 'synapse_id'): 13,
#  (13, 'pre_cell_id'): 385,
#  (13, 'pre_mtype'): 6,
#  (13, 'sectionlist_id'): 2,
#  (13, 'sectionlist_index'): 4,
#  (13, 'seg_x'): 0,
#  (13, 'synapse_type'): 116,
#  (13, 'dep'): 667.0,
#  (13, 'fac'): 16.0,
#  (13, 'use'): 0.4956444501876831,
#  (13, 'tau_d'): 1.7007999420166016,
#  (13, 'delay'): 2.2636,
#  (13, 'weight'): 0.677013158798,
#  (14, 'synapse_id'): 14,
#  (14, 'pre_cell_id'): 385,
#  (14, 'pre_mtype'): 6,
#  (14, 'sectionlist_id'): 2,
#  (14, 'sectionlist_index'): 66,
#  (14, 'seg_x'): 0,
#  (14, 'synapse_type'): 116,
#  (14, 'dep'): 658.0,
#  (14, 'fac'): 13.0,
#  (14, 'use'): 0.4851509928703308,
#  (14, 'tau_d'): 1.6063590049743652,
#  (14, 'delay'): 1.33865,
#  (14, 'weight'): 0.399986296892,
#  (15, 'synapse_id'): 15,
#  (15, 'pre_cell_id'): 385,
#  (15, 'pre_mtype'): 6,
#  (15, 'sectionlist_id'): 2,
#  (15, 'sectionlist_index'): 66,
#  (15, 'seg_x'): 0,
#  (15, 'synapse_type'): 116,
#  (15, 'dep'): 678.0,
#  (15, 'fac'): 19.0,
#  (15, 'use'): 0.5077129006385803,
#  (15, 'tau_d'): 1.8094159364700317,
#  (15, 'delay'): 1.3448,
#  (15, 'weight'): 0.995619952679,
#  (16, 'synapse_id'): 16,
#  (16, 'pre_cell_id'): 390,
#  (16, 'pre_mtype'): 6,
#  (16, 'sectionlist_id'): 2,
#  (16, 'sectionlist_index'): 98,
#  (16, 'seg_x'): 0,
#  (16, 'synapse_type'): 116,
#  (16, 'dep'): 668.0,
#  (16, 'fac'): 16.0,
#  (16, 'use'): 0.49697670340538025,
#  (16, 'tau_d'): 1.7127903699874878,
#  (16, 'delay'): 0.271411,
#  (16, 'weight'): 0.712185144424,
#  (17, 'synapse_id'): 17,
#  (17, 'pre_cell_id'): 390,
#  (17, 'pre_mtype'): 6,
#  (17, 'sectionlist_id'): 2,
#  (17, 'sectionlist_index'): 53,
#  (17, 'seg_x'): 0,
#  (17, 'synapse_type'): 116,
#  (17, 'dep'): 683.0,
#  (17, 'fac'): 20.0,
#  (17, 'use'): 0.5136396884918213,
#  (17, 'tau_d'): 1.8627574443817139,
#  (17, 'delay'): 2.17266,
#  (17, 'weight'): 1.15208852291,
#  (18, 'synapse_id'): 18,
#  (18, 'pre_cell_id'): 390,
#  (18, 'pre_mtype'): 6,
#  (18, 'sectionlist_id'): 2,
#  (18, 'sectionlist_index'): 98,
#  (18, 'seg_x'): 0,
#  (18, 'synapse_type'): 116,
#  (18, 'dep'): 682.0,
#  (18, 'fac'): 20.0,
#  (18, 'use'): 0.5130394697189331,
#  (18, 'tau_d'): 1.857354998588562,
#  (18, 'delay'): 0.921772,
#  (18, 'weight'): 1.1362413168,
#  (19, 'synapse_id'): 19,
#  (19, 'pre_cell_id'): 430,
#  (19, 'pre_mtype'): 6,
#  (19, 'sectionlist_id'): 2,
#  (19, 'sectionlist_index'): 71,
#  (19, 'seg_x'): 0,
#  (19, 'synapse_type'): 116,
#  (19, 'dep'): 674.0,
#  (19, 'fac'): 18.0,
#  (19, 'use'): 0.5038175582885742,
#  (19, 'tau_d'): 1.774357795715332,
#  (19, 'delay'): 0.86982,
#  (19, 'weight'): 0.892782866955,
#  (20, 'synapse_id'): 20,
#  (20, 'pre_cell_id'): 430,
#  (20, 'pre_mtype'): 6,
#  (20, 'sectionlist_id'): 2,
#  (20, 'sectionlist_index'): 98,
#  (20, 'seg_x'): 0,
#  (20, 'synapse_type'): 116,
#  (20, 'dep'): 668.0,
#  (20, 'fac'): 16.0,
#  (20, 'use'): 0.496799111366272,
#  (20, 'tau_d'): 1.711192011833191,
#  (20, 'delay'): 0.738055,
#  (20, 'weight'): 0.707496404648,
#  (21, 'synapse_id'): 21,
#  (21, 'pre_cell_id'): 430,
#  (21, 'pre_mtype'): 6,
#  (21, 'sectionlist_id'): 2,
#  (21, 'sectionlist_index'): 98,
#  (21, 'seg_x'): 0,
#  (21, 'synapse_type'): 116,
#  (21, 'dep'): 681.0,
#  (21, 'fac'): 20.0,
#  (21, 'use'): 0.5120148658752441,
#  (21, 'tau_d'): 1.8481336832046509,
#  (21, 'delay'): 0.959035,
#  (21, 'weight'): 1.10919213295,
#  (22, 'synapse_id'): 22,
#  (22, 'pre_cell_id'): 464,
#  (22, 'pre_mtype'): 6,
#  (22, 'sectionlist_id'): 2,
#  (22, 'sectionlist_index'): 73,
#  (22, 'seg_x'): 0,
#  (22, 'synapse_type'): 116,
#  (22, 'dep'): 657.0,
#  (22, 'fac'): 13.0,
#  (22, 'use'): 0.48371621966362,
#  (22, 'tau_d'): 1.5934460163116455,
#  (22, 'delay'): 0.565418,
#  (22, 'weight'): 0.362108409405,
#  (23, 'synapse_id'): 23,
#  (23, 'pre_cell_id'): 464,
#  (23, 'pre_mtype'): 6,
#  (23, 'sectionlist_id'): 2,
#  (23, 'sectionlist_index'): 73,
#  (23, 'seg_x'): 0,
#  (23, 'synapse_type'): 116,
#  (23, 'dep'): 674.0,
#  (23, 'fac'): 18.0,
#  (23, 'use'): 0.5031044483184814,
#  (23, 'tau_d'): 1.767939805984497,
#  (23, 'delay'): 0.378657,
#  (23, 'weight'): 0.873956918716,
#  (24, 'synapse_id'): 24,
#  (24, 'pre_cell_id'): 508,
#  (24, 'pre_mtype'): 6,
#  (24, 'sectionlist_id'): 2,
#  (24, 'sectionlist_index'): 98,
#  (24, 'seg_x'): 0,
#  (24, 'synapse_type'): 116,
#  (24, 'dep'): 681.0,
#  (24, 'fac'): 20.0,
#  (24, 'use'): 0.5116813778877258,
#  (24, 'tau_d'): 1.8451323509216309,
#  (24, 'delay'): 0.529708,
#  (24, 'weight'): 1.1003882885,
#  (25, 'synapse_id'): 25,
#  (25, 'pre_cell_id'): 508,
#  (25, 'pre_mtype'): 6,
#  (25, 'sectionlist_id'): 2,
#  (25, 'sectionlist_index'): 70,
#  (25, 'seg_x'): 0,
#  (25, 'synapse_type'): 116,
#  (25, 'dep'): 678.0,
#  (25, 'fac'): 19.0,
#  (25, 'use'): 0.5088120102882385,
#  (25, 'tau_d'): 1.8193080425262451,
#  (25, 'delay'): 0.573981,
#  (25, 'weight'): 1.02463698387,
#  (26, 'synapse_id'): 26,
#  (26, 'pre_cell_id'): 508,
#  (26, 'pre_mtype'): 6,
#  (26, 'sectionlist_id'): 2,
#  (26, 'sectionlist_index'): 54,
#  (26, 'seg_x'): 0,
#  (26, 'synapse_type'): 116,
#  (26, 'dep'): 669.0,
#  (26, 'fac'): 17.0,
#  (26, 'use'): 0.4981088936328888,
#  (26, 'tau_d'): 1.72298002243042,
#  (26, 'delay'): 1.77931,
#  (26, 'weight'): 0.742074608803,
#  (27, 'synapse_id'): 27,
#  (27, 'pre_cell_id'): 508,
#  (27, 'pre_mtype'): 6,
#  (27, 'sectionlist_id'): 2,
#  (27, 'sectionlist_index'): 42,
#  (27, 'seg_x'): 0,
#  (27, 'synapse_type'): 116,
#  (27, 'dep'): 682.0,
#  (27, 'fac'): 20.0,
#  (27, 'use'): 0.5130712389945984,
#  (27, 'tau_d'): 1.8576411008834839,
#  (27, 'delay'): 1.81291,
#  (27, 'weight'): 1.13708043098,
#  (28, 'synapse_id'): 28,
#  (28, 'pre_cell_id'): 508,
#  (28, 'pre_mtype'): 6,
#  (28, 'sectionlist_id'): 2,
#  (28, 'sectionlist_index'): 113,
#  (28, 'seg_x'): 0,
#  (28, 'synapse_type'): 116,
#  (28, 'dep'): 657.0,
#  (28, 'fac'): 13.0,
#  (28, 'use'): 0.48300737142562866,
#  (28, 'tau_d'): 1.587066411972046,
#  (28, 'delay'): 2.27807,
#  (28, 'weight'): 0.343394637108,
#  (29, 'synapse_id'): 29,
#  (29, 'pre_cell_id'): 573,
#  (29, 'pre_mtype'): 6,
#  (29, 'sectionlist_id'): 2,
#  (29, 'sectionlist_index'): 71,
#  (29, 'seg_x'): 0,
#  (29, 'synapse_type'): 116,
#  (29, 'dep'): 677.0,
#  (29, 'fac'): 19.0,
#  (29, 'use'): 0.507434070110321,
#  (29, 'tau_d'): 1.8069064617156982,
#  (29, 'delay'): 0.77905,
#  (29, 'weight'): 0.988259017467,
#  (30, 'synapse_id'): 30,
#  (30, 'pre_cell_id'): 573,
#  (30, 'pre_mtype'): 6,
#  (30, 'sectionlist_id'): 2,
#  (30, 'sectionlist_index'): 76,
#  (30, 'seg_x'): 0,
#  (30, 'synapse_type'): 116,
#  (30, 'dep'): 670.0,
#  (30, 'fac'): 17.0,
#  (30, 'use'): 0.4985331594944,
#  (30, 'tau_d'): 1.726798415184021,
#  (30, 'delay'): 0.847267,
#  (30, 'weight'): 0.753275215626,
#  (31, 'synapse_id'): 31,
#  (31, 'pre_cell_id'): 573,
#  (31, 'pre_mtype'): 6,
#  (31, 'sectionlist_id'): 2,
#  (31, 'sectionlist_index'): 66,
#  (31, 'seg_x'): 0,
#  (31, 'synapse_type'): 116,
#  (31, 'dep'): 664.0,
#  (31, 'fac'): 15.0,
#  (31, 'use'): 0.49203944206237793,
#  (31, 'tau_d'): 1.668354868888855,
#  (31, 'delay'): 1.75733,
#  (31, 'weight'): 0.581841051579,
#  (32, 'synapse_id'): 32,
#  (32, 'pre_cell_id'): 573,
#  (32, 'pre_mtype'): 6,
#  (32, 'sectionlist_id'): 2,
#  (32, 'sectionlist_index'): 28,
#  (32, 'seg_x'): 0,
#  (32, 'synapse_type'): 116,
#  (32, 'dep'): 675.0,
#  (32, 'fac'): 18.0,
#  (32, 'use'): 0.5052245855331421,
#  (32, 'tau_d'): 1.787021279335022,
#  (32, 'delay'): 2.90344,
#  (32, 'weight'): 0.929928958416,
#  (33, 'synapse_id'): 33,
#  (33, 'pre_cell_id'): 630,
#  (33, 'pre_mtype'): 12,
#  (33, 'sectionlist_id'): 2,
#  (33, 'sectionlist_index'): 73,
#  (33, 'seg_x'): 0,
#  (33, 'synapse_type'): 10,
#  (33, 'dep'): 922.0,
#  (33, 'fac'): 23.0,
#  (33, 'use'): 0.148246631026268,
#  (33, 'tau_d'): 8.745318412780762,
#  (33, 'delay'): 0.343369,
#  (33, 'weight'): 1.01111412048,
#  (34, 'synapse_id'): 34,
#  (34, 'pre_cell_id'): 630,
#  (34, 'pre_mtype'): 12,
#  (34, 'sectionlist_id'): 2,
#  (34, 'sectionlist_index'): 73,
#  (34, 'seg_x'): 0,
#  (34, 'synapse_type'): 10,
#  (34, 'dep'): 762.0,
#  (34, 'fac'): 20.0,
#  (34, 'use'): 0.12013905495405197,
#  (34, 'tau_d'): 7.227509021759033,
#  (34, 'delay'): 0.353909,
#  (34, 'weight'): 0.669888138771,
#  (35, 'synapse_id'): 35,
#  (35, 'pre_cell_id'): 630,
#  (35, 'pre_mtype'): 12,
#  (35, 'sectionlist_id'): 2,
#  (35, 'sectionlist_index'): 73,
#  (35, 'seg_x'): 0,
#  (35, 'synapse_type'): 10,
#  (35, 'dep'): 720.0,
#  (35, 'fac'): 19.0,
#  (35, 'use'): 0.11282923072576523,
#  (35, 'tau_d'): 6.832778453826904,
#  (35, 'delay'): 0.351969,
#  (35, 'weight'): 0.581146836281,
#  (36, 'synapse_id'): 36,
#  (36, 'pre_cell_id'): 630,
#  (36, 'pre_mtype'): 12,
#  (36, 'sectionlist_id'): 2,
#  (36, 'sectionlist_index'): 76,
#  (36, 'seg_x'): 0,
#  (36, 'synapse_type'): 10,
#  (36, 'dep'): 598.0,
#  (36, 'fac'): 17.0,
#  (36, 'use'): 0.09140384942293167,
#  (36, 'tau_d'): 5.675807952880859,
#  (36, 'delay'): 0.932162,
#  (36, 'weight'): 0.321042686701,
#  (37, 'synapse_id'): 37,
#  (37, 'pre_cell_id'): 630,
#  (37, 'pre_mtype'): 12,
#  (37, 'sectionlist_id'): 2,
#  (37, 'sectionlist_index'): 74,
#  (37, 'seg_x'): 0,
#  (37, 'synapse_type'): 10,
#  (37, 'dep'): 875.0,
#  (37, 'fac'): 22.0,
#  (37, 'use'): 0.14001964032649994,
#  (37, 'tau_d'): 8.301060676574707,
#  (37, 'delay'): 0.73518,
#  (37, 'weight'): 0.911238491535,
#  (38, 'synapse_id'): 38,
#  (38, 'pre_cell_id'): 630,
#  (38, 'pre_mtype'): 12,
#  (38, 'sectionlist_id'): 2,
#  (38, 'sectionlist_index'): 75,
#  (38, 'seg_x'): 0,
#  (38, 'synapse_type'): 10,
#  (38, 'dep'): 1146.0,
#  (38, 'fac'): 27.0,
#  (38, 'use'): 0.18759550154209137,
#  (38, 'tau_d'): 10.870157241821289,
#  (38, 'delay'): 0.868764,
#  (38, 'weight'): 1.48880934715,
#  (39, 'synapse_id'): 39,
#  (39, 'pre_cell_id'): 630,
#  (39, 'pre_mtype'): 12,
#  (39, 'sectionlist_id'): 2,
#  (39, 'sectionlist_index'): 71,
#  (39, 'seg_x'): 0,
#  (39, 'synapse_type'): 10,
#  (39, 'dep'): 842.0,
#  (39, 'fac'): 21.0,
#  (39, 'use'): 0.13414369523525238,
#  (39, 'tau_d'): 7.983759880065918,
#  (39, 'delay'): 0.758778,
#  (39, 'weight'): 0.839904487133,
#  (40, 'synapse_id'): 40,
#  (40, 'pre_cell_id'): 630,
#  (40, 'pre_mtype'): 12,
#  (40, 'sectionlist_id'): 2,
#  (40, 'sectionlist_index'): 73,
#  (40, 'seg_x'): 0,
#  (40, 'synapse_type'): 10,
#  (40, 'dep'): 743.0,
#  (40, 'fac'): 20.0,
#  (40, 'use'): 0.11685838550329208,
#  (40, 'tau_d'): 7.050353050231934,
#  (40, 'delay'): 0.391826,
#  (40, 'weight'): 0.630060851574,
#  (41, 'synapse_id'): 41,
#  (41, 'pre_cell_id'): 630,
#  (41, 'pre_mtype'): 12,
#  (41, 'sectionlist_id'): 2,
#  (41, 'sectionlist_index'): 73,
#  (41, 'seg_x'): 0,
#  (41, 'synapse_type'): 10,
#  (41, 'dep'): 823.0,
#  (41, 'fac'): 21.0,
#  (41, 'use'): 0.13085269927978516,
#  (41, 'tau_d'): 7.8060455322265625,
#  (41, 'delay'): 0.519135,
#  (41, 'weight'): 0.799951672554,
#  (42, 'synapse_id'): 42,
#  (42, 'pre_cell_id'): 630,
#  (42, 'pre_mtype'): 12,
#  (42, 'sectionlist_id'): 2,
#  (42, 'sectionlist_index'): 73,
#  (42, 'seg_x'): 0,
#  (42, 'synapse_type'): 10,
#  (42, 'dep'): 881.0,
#  (42, 'fac'): 22.0,
#  (42, 'use'): 0.14101438224315643,
#  (42, 'tau_d'): 8.354776382446289,
#  (42, 'delay'): 0.541391,
#  (42, 'weight'): 0.923314630985,
#  (43, 'synapse_id'): 43,
#  (43, 'pre_cell_id'): 668,
#  (43, 'pre_mtype'): 6,
#  (43, 'sectionlist_id'): 1,
#  (43, 'sectionlist_index'): 53,
#  (43, 'seg_x'): 0,
#  (43, 'synapse_type'): 116,
#  (43, 'dep'): 655.0,
#  (43, 'fac'): 12.0,
#  (43, 'use'): 0.4809797406196594,
#  (43, 'tau_d'): 1.5688176155090332,
#  (43, 'delay'): 2.93257,
#  (43, 'weight'): 0.28986492753,
#  (44, 'synapse_id'): 44,
#  (44, 'pre_cell_id'): 668,
#  (44, 'pre_mtype'): 6,
#  (44, 'sectionlist_id'): 2,
#  (44, 'sectionlist_index'): 98,
#  (44, 'seg_x'): 0,
#  (44, 'synapse_type'): 116,
#  (44, 'dep'): 683.0,
#  (44, 'fac'): 21.0,
#  (44, 'use'): 0.5141687989234924,
#  (44, 'tau_d'): 1.8675190210342407,
#  (44, 'delay'): 1.04812,
#  (44, 'weight'): 1.16605579853,
#  (45, 'synapse_id'): 45,
#  (45, 'pre_cell_id'): 668,
#  (45, 'pre_mtype'): 6,
#  (45, 'sectionlist_id'): 2,
#  (45, 'sectionlist_index'): 106,
#  (45, 'seg_x'): 0,
#  (45, 'synapse_type'): 116,
#  (45, 'dep'): 679.0,
#  (45, 'fac'): 19.0,
#  (45, 'use'): 0.509983241558075,
#  (45, 'tau_d'): 1.8298492431640625,
#  (45, 'delay'): 0.728283,
#  (45, 'weight'): 1.05555784702,
#  (46, 'synapse_id'): 46,
#  (46, 'pre_cell_id'): 812,
#  (46, 'pre_mtype'): 6,
#  (46, 'sectionlist_id'): 2,
#  (46, 'sectionlist_index'): 78,
#  (46, 'seg_x'): 0,
#  (46, 'synapse_type'): 116,
#  (46, 'dep'): 664.0,
#  (46, 'fac'): 15.0,
#  (46, 'use'): 0.4923429489135742,
#  (46, 'tau_d'): 1.6710865497589111,
#  (46, 'delay'): 0.963199,
#  (46, 'weight'): 0.589854001999,
#  (47, 'synapse_id'): 47,
#  (47, 'pre_cell_id'): 812,
#  (47, 'pre_mtype'): 6,
#  (47, 'sectionlist_id'): 2,
#  (47, 'sectionlist_index'): 79,
#  (47, 'seg_x'): 0,
#  (47, 'synapse_type'): 116,
#  (47, 'dep'): 682.0,
#  (47, 'fac'): 20.0,
#  (47, 'use'): 0.5124524235725403,
#  (47, 'tau_d'): 1.852071762084961,
#  (47, 'delay'): 1.16257,
#  (47, 'weight'): 1.12074375153,
#  (48, 'synapse_id'): 48,
#  (48, 'pre_cell_id'): 812,
#  (48, 'pre_mtype'): 6,
#  (48, 'sectionlist_id'): 2,
#  (48, 'sectionlist_index'): 79,
#  (48, 'seg_x'): 0,
#  (48, 'synapse_type'): 116,
#  (48, 'dep'): 664.0,
#  (48, 'fac'): 15.0,
#  (48, 'use'): 0.4915738105773926,
#  (48, 'tau_d'): 1.6641641855239868,
#  (48, 'delay'): 1.18364,
#  (48, 'weight'): 0.569548428059,
#  (49, 'synapse_id'): 49,
#  (49, 'pre_cell_id'): 834,
#  (49, 'pre_mtype'): 6,
#  (49, 'sectionlist_id'): 2,
#  (49, 'sectionlist_index'): 76,
#  (49, 'seg_x'): 0,
#  (49, 'synapse_type'): 116,
#  (49, 'dep'): 671.0,
#  (49, 'fac'): 17.0,
#  (49, 'use'): 0.5004277229309082,
#  (49, 'tau_d'): 1.743849754333496,
#  (49, 'delay'): 0.819187,
#  (49, 'weight'): 0.803292632103,
#  (50, 'synapse_id'): 50,
#  (50, 'pre_cell_id'): 834,
#  (50, 'pre_mtype'): 6,
#  (50, 'sectionlist_id'): 2,
#  (50, 'sectionlist_index'): 98,
#  (50, 'seg_x'): 0,
#  (50, 'synapse_type'): 116,
#  (50, 'dep'): 658.0,
#  (50, 'fac'): 13.0,
#  (50, 'use'): 0.48504310846328735,
#  (50, 'tau_d'): 1.6053879261016846,
#  (50, 'delay'): 0.758348,
#  (50, 'weight'): 0.397137820721,
#  (51, 'synapse_id'): 51,
#  (51, 'pre_cell_id'): 834,
#  (51, 'pre_mtype'): 6,
#  (51, 'sectionlist_id'): 2,
#  (51, 'sectionlist_index'): 82,
#  (51, 'seg_x'): 0,
#  (51, 'synapse_type'): 116,
#  (51, 'dep'): 681.0,
#  (51, 'fac'): 20.0,
#  (51, 'use'): 0.5117111802101135,
#  (51, 'tau_d'): 1.8454004526138306,
#  (51, 'delay'): 1.33888,
#  (51, 'weight'): 1.10117471218,
#  (52, 'synapse_id'): 52,
#  (52, 'pre_cell_id'): 834,
#  (52, 'pre_mtype'): 6,
#  (52, 'sectionlist_id'): 2,
#  (52, 'sectionlist_index'): 92,
#  (52, 'seg_x'): 0,
#  (52, 'synapse_type'): 116,
#  (52, 'dep'): 664.0,
#  (52, 'fac'): 15.0,
#  (52, 'use'): 0.4919201135635376,
#  (52, 'tau_d'): 1.667280912399292,
#  (52, 'delay'): 0.868021,
#  (52, 'weight'): 0.578690826893,
#  (53, 'synapse_id'): 53,
#  (53, 'pre_cell_id'): 841,
#  (53, 'pre_mtype'): 6,
#  (53, 'sectionlist_id'): 2,
#  (53, 'sectionlist_index'): 35,
#  (53, 'seg_x'): 0,
#  (53, 'synapse_type'): 116,
#  (53, 'dep'): 681.0,
#  (53, 'fac'): 20.0,
#  (53, 'use'): 0.5116652846336365,
#  (53, 'tau_d'): 1.8449877500534058,
#  (53, 'delay'): 2.22736,
#  (53, 'weight'): 1.09996414185,
#  (54, 'synapse_id'): 54,
#  (54, 'pre_cell_id'): 841,
#  (54, 'pre_mtype'): 6,
#  (54, 'sectionlist_id'): 2,
#  (54, 'sectionlist_index'): 35,
#  (54, 'seg_x'): 0,
#  (54, 'synapse_type'): 116,
#  (54, 'dep'): 672.0,
#  (54, 'fac'): 17.0,
#  (54, 'use'): 0.5009605884552002,
#  (54, 'tau_d'): 1.7486450672149658,
#  (54, 'delay'): 2.22735,
#  (54, 'weight'): 0.817358732224,
#  (55, 'synapse_id'): 55,
#  (55, 'pre_cell_id'): 841,
#  (55, 'pre_mtype'): 6,
#  (55, 'sectionlist_id'): 2,
#  (55, 'sectionlist_index'): 35,
#  (55, 'seg_x'): 0,
#  (55, 'synapse_type'): 116,
#  (55, 'dep'): 664.0,
#  (55, 'fac'): 15.0,
#  (55, 'use'): 0.4918580651283264,
#  (55, 'tau_d'): 1.6667226552963257,
#  (55, 'delay'): 2.24962,
#  (55, 'weight'): 0.577053010464,
#  (56, 'synapse_id'): 56,
#  (56, 'pre_cell_id'): 841,
#  (56, 'pre_mtype'): 6,
#  (56, 'sectionlist_id'): 2,
#  (56, 'sectionlist_index'): 35,
#  (56, 'seg_x'): 0,
#  (56, 'synapse_type'): 116,
#  (56, 'dep'): 669.0,
#  (56, 'fac'): 17.0,
#  (56, 'use'): 0.4981262981891632,
#  (56, 'tau_d'): 1.7231365442276,
#  (56, 'delay'): 2.27001,
#  (56, 'weight'): 0.742533862591,
#  (57, 'synapse_id'): 57,
#  (57, 'pre_cell_id'): 1008,
#  (57, 'pre_mtype'): 6,
#  (57, 'sectionlist_id'): 2,
#  (57, 'sectionlist_index'): 57,
#  (57, 'seg_x'): 0,
#  (57, 'synapse_type'): 116,
#  (57, 'dep'): 670.0,
#  (57, 'fac'): 17.0,
#  (57, 'use'): 0.498823344707489,
#  (57, 'tau_d'): 1.729410171508789,
#  (57, 'delay'): 1.68872,
#  (57, 'weight'): 0.760936558247,
#  (58, 'synapse_id'): 58,
#  (58, 'pre_cell_id'): 1008,
#  (58, 'pre_mtype'): 6,
#  (58, 'sectionlist_id'): 2,
#  (58, 'sectionlist_index'): 74,
#  (58, 'seg_x'): 0,
#  (58, 'synapse_type'): 116,
#  (58, 'dep'): 666.0,
#  (58, 'fac'): 15.0,
#  (58, 'use'): 0.49387040734291077,
#  (58, 'tau_d'): 1.6848336458206177,
#  (58, 'delay'): 1.68171,
#  (58, 'weight'): 0.630178511143,
#  (59, 'synapse_id'): 59,
#  (59, 'pre_cell_id'): 1008,
#  (59, 'pre_mtype'): 6,
#  (59, 'sectionlist_id'): 2,
#  (59, 'sectionlist_index'): 74,
#  (59, 'seg_x'): 0,
#  (59, 'synapse_type'): 116,
#  (59, 'dep'): 672.0,
#  (59, 'fac'): 17.0,
#  (59, 'use'): 0.5007861852645874,
#  (59, 'tau_d'): 1.7470756769180298,
#  (59, 'delay'): 1.69929,
#  (59, 'weight'): 0.812755405903,
#  (60, 'synapse_id'): 60,
#  (60, 'pre_cell_id'): 1013,
#  (60, 'pre_mtype'): 8,
#  (60, 'sectionlist_id'): 1,
#  (60, 'sectionlist_index'): 71,
#  (60, 'seg_x'): 0,
#  (60, 'synapse_type'): 8,
#  (60, 'dep'): 927.0,
#  (60, 'fac'): 26.0,
#  (60, 'use'): 0.3208264112472534,
#  (60, 'tau_d'): 9.498600959777832,
#  (60, 'delay'): 4.53305,
#  (60, 'weight'): 0.918707489967,
#  (61, 'synapse_id'): 61,
#  (61, 'pre_cell_id'): 1013,
#  (61, 'pre_mtype'): 8,
#  (61, 'sectionlist_id'): 1,
#  (61, 'sectionlist_index'): 71,
#  (61, 'seg_x'): 0,
#  (61, 'synapse_type'): 8,
#  (61, 'dep'): 908.0,
#  (61, 'fac'): 25.0,
#  (61, 'use'): 0.314811110496521,
#  (61, 'tau_d'): 9.396803855895996,
#  (61, 'delay'): 4.55355,
#  (61, 'weight'): 0.904039382935,
#  (62, 'synapse_id'): 62,
#  (62, 'pre_cell_id'): 1013,
#  (62, 'pre_mtype'): 8,
#  (62, 'sectionlist_id'): 2,
#  (62, 'sectionlist_index'): 118,
#  (62, 'seg_x'): 0,
#  (62, 'synapse_type'): 8,
#  (62, 'dep'): 597.0,
#  (62, 'fac'): 19.0,
#  (62, 'use'): 0.2150762677192688,
#  (62, 'tau_d'): 7.708982944488525,
#  (62, 'delay'): 4.98365,
#  (62, 'weight'): 0.660839796066,
#  (63, 'synapse_id'): 63,
#  (63, 'pre_cell_id'): 1013,
#  (63, 'pre_mtype'): 8,
#  (63, 'sectionlist_id'): 2,
#  (63, 'sectionlist_index'): 66,
#  (63, 'seg_x'): 0,
#  (63, 'synapse_type'): 8,
#  (63, 'dep'): 736.0,
#  (63, 'fac'): 22.0,
#  (63, 'use'): 0.2597825825214386,
#  (63, 'tau_d'): 8.465551376342773,
#  (63, 'delay'): 2.48762,
#  (63, 'weight'): 0.769854426384,
#  (64, 'synapse_id'): 64,
#  (64, 'pre_cell_id'): 1013,
#  (64, 'pre_mtype'): 8,
#  (64, 'sectionlist_id'): 2,
#  (64, 'sectionlist_index'): 9,
#  (64, 'seg_x'): 0,
#  (64, 'synapse_type'): 8,
#  (64, 'dep'): 1077.0,
#  (64, 'fac'): 29.0,
#  (64, 'use'): 0.3691517114639282,
#  (64, 'tau_d'): 10.316413879394531,
#  (64, 'delay'): 2.34474,
#  (64, 'weight'): 1.03654694557,
#  (65, 'synapse_id'): 65,
#  (65, 'pre_cell_id'): 1013,
#  (65, 'pre_mtype'): 8,
#  (65, 'sectionlist_id'): 1,
#  (65, 'sectionlist_index'): 27,
#  (65, 'seg_x'): 0,
#  (65, 'synapse_type'): 8,
#  (65, 'dep'): 801.0,
#  (65, 'fac'): 23.0,
#  (65, 'use'): 0.2805594503879547,
#  (65, 'tau_d'): 8.817159652709961,
#  (65, 'delay'): 3.47487,
#  (65, 'weight'): 0.820518016815,
#  (66, 'synapse_id'): 66,
#  (66, 'pre_cell_id'): 1013,
#  (66, 'pre_mtype'): 8,
#  (66, 'sectionlist_id'): 1,
#  (66, 'sectionlist_index'): 81,
#  (66, 'seg_x'): 0,
#  (66, 'synapse_type'): 8,
#  (66, 'dep'): 643.0,
#  (66, 'fac'): 20.0,
#  (66, 'use'): 0.22983500361442566,
#  (66, 'tau_d'): 7.958745956420898,
#  (66, 'delay'): 3.86609,
#  (66, 'weight'): 0.696828424931,
#  (67, 'synapse_id'): 67,
#  (67, 'pre_cell_id'): 1013,
#  (67, 'pre_mtype'): 8,
#  (67, 'sectionlist_id'): 1,
#  (67, 'sectionlist_index'): 28,
#  (67, 'seg_x'): 0,
#  (67, 'synapse_type'): 8,
#  (67, 'dep'): 614.0,
#  (67, 'fac'): 19.0,
#  (67, 'use'): 0.22058716416358948,
#  (67, 'tau_d'): 7.802244663238525,
#  (67, 'delay'): 3.479,
#  (67, 'weight'): 0.674277961254,
#  (68, 'synapse_id'): 68,
#  (68, 'pre_cell_id'): 1013,
#  (68, 'pre_mtype'): 8,
#  (68, 'sectionlist_id'): 1,
#  (68, 'sectionlist_index'): 41,
#  (68, 'seg_x'): 0,
#  (68, 'synapse_type'): 8,
#  (68, 'dep'): 532.0,
#  (68, 'fac'): 17.0,
#  (68, 'use'): 0.19429971277713776,
#  (68, 'tau_d'): 7.357379913330078,
#  (68, 'delay'): 3.2699,
#  (68, 'weight'): 0.610176980495,
#  (69, 'synapse_id'): 69,
#  (69, 'pre_cell_id'): 1013,
#  (69, 'pre_mtype'): 8,
#  (69, 'sectionlist_id'): 2,
#  (69, 'sectionlist_index'): 78,
#  (69, 'seg_x'): 0,
#  (69, 'synapse_type'): 8,
#  (69, 'dep'): 436.0,
#  (69, 'fac'): 15.0,
#  (69, 'use'): 0.16320165991783142,
#  (69, 'tau_d'): 6.8311052322387695,
#  (69, 'delay'): 0.81184,
#  (69, 'weight'): 0.534345567226,
#  (70, 'synapse_id'): 70,
#  (70, 'pre_cell_id'): 1070,
#  (70, 'pre_mtype'): 6,
#  (70, 'sectionlist_id'): 2,
#  (70, 'sectionlist_index'): 106,
#  (70, 'seg_x'): 0,
#  (70, 'synapse_type'): 116,
#  (70, 'dep'): 681.0,
#  (70, 'fac'): 20.0,
#  (70, 'use'): 0.5116464495658875,
#  (70, 'tau_d'): 1.844818115234375,
#  (70, 'delay'): 0.621987,
#  (70, 'weight'): 1.09946632385,
#  (71, 'synapse_id'): 71,
#  (71, 'pre_cell_id'): 1070,
#  (71, 'pre_mtype'): 6,
#  (71, 'sectionlist_id'): 2,
#  (71, 'sectionlist_index'): 106,
#  (71, 'seg_x'): 0,
#  (71, 'synapse_type'): 116,
#  (71, 'dep'): 661.0,
#  (71, 'fac'): 14.0,
#  (71, 'use'): 0.48830464482307434,
#  (71, 'tau_d'): 1.6347419023513794,
#  (71, 'delay'): 0.606546,
#  (71, 'weight'): 0.483242809772,
#  (72, 'synapse_id'): 72,
#  (72, 'pre_cell_id'): 1070,
#  (72, 'pre_mtype'): 6,
#  (72, 'sectionlist_id'): 2,
#  (72, 'sectionlist_index'): 106,
#  (72, 'seg_x'): 0,
#  (72, 'synapse_type'): 116,
#  (72, 'dep'): 664.0,
#  (72, 'fac'): 15.0,
#  (72, 'use'): 0.4916963577270508,
#  (72, 'tau_d'): 1.6652672290802002,
#  (72, 'delay'): 0.649895,
#  (72, 'weight'): 0.572783887386,
#  (73, 'synapse_id'): 73,
#  (73, 'pre_cell_id'): 1070,
#  (73, 'pre_mtype'): 6,
#  (73, 'sectionlist_id'): 2,
#  (73, 'sectionlist_index'): 107,
#  (73, 'seg_x'): 0,
#  (73, 'synapse_type'): 116,
#  (73, 'dep'): 672.0,
#  (73, 'fac'): 17.0,
#  (73, 'use'): 0.5009745955467224,
#  (73, 'tau_d'): 1.7487715482711792,
#  (73, 'delay'): 0.673355,
#  (73, 'weight'): 0.817729830742,
#  (74, 'synapse_id'): 74,
#  (74, 'pre_cell_id'): 1083,
#  (74, 'pre_mtype'): 14,
#  (74, 'sectionlist_id'): 2,
#  (74, 'sectionlist_index'): 71,
#  (74, 'seg_x'): 0,
#  (74, 'synapse_type'): 3,
#  (74, 'dep'): 38.0,
#  (74, 'fac'): 289.0,
#  (74, 'use'): 0.12543027102947235,
#  (74, 'tau_d'): 8.25667667388916,
#  (74, 'delay'): 0.473154,
#  (74, 'weight'): 0.70116174221,
#  (75, 'synapse_id'): 75,
#  (75, 'pre_cell_id'): 1083,
#  (75, 'pre_mtype'): 14,
#  (75, 'sectionlist_id'): 2,
#  (75, 'sectionlist_index'): 83,
#  (75, 'seg_x'): 0,
#  (75, 'synapse_type'): 3,
#  (75, 'dep'): 46.0,
#  (75, 'fac'): 390.0,
#  (75, 'use'): 0.16547468304634094,
#  (75, 'tau_d'): 10.73943042755127,
#  (75, 'delay'): 1.02144,
#  (75, 'weight'): 0.944231331348,
#  (76, 'synapse_id'): 76,
#  (76, 'pre_cell_id'): 1083,
#  (76, 'pre_mtype'): 14,
#  (76, 'sectionlist_id'): 2,
#  (76, 'sectionlist_index'): 78,
#  (76, 'seg_x'): 0,
#  (76, 'synapse_type'): 3,
#  (76, 'dep'): 64.0,
#  (76, 'fac'): 604.0,
#  (76, 'use'): 0.2499772310256958,
#  (76, 'tau_d'): 15.978588104248047,
#  (76, 'delay'): 0.531441,
#  ...}

# %%
hotspot_synapses = []
hotspot_netcons  = []
hotspot_netstims = [] 

pre_mtypes_excinh = [] 

# for isynapse in range(nsynapses):
for isynapse in range(1):
    
#Create sectionref to the section the synapse will be placed on
    if parameters_syn[isynapse,'sectionlist_id'] == 0:
        cell.soma[parameters_syn[isynapse,'sectionlist_index']]      
#             sectionlist_name = "somatic"    
    elif parameters_syn[isynapse,'sectionlist_id'] == 1:
        cell.dend[parameters_syn[isynapse,'sectionlist_index']] 
#             sectionlist_name = "basal" 
    elif parameters_syn[isynapse,'sectionlist_id'] == 2:
        cell.apic[parameters_syn[isynapse,'sectionlist_index']]    
#             sectionlist_name = "apical" 
    elif parameters_syn[isynapse,'sectionlist_id'] == 3:
        cell.axon[parameters_syn[isynapse,'sectionlist_index']]     
#             sectionlist_name = "axonal"         
    else:
        print ("Sectionlist_id %d not support\n" % parameters_syn[isynapse,'sectionlist_index'])   

        
# If synapse_type < 100 the synapse is inhibitory, otherwise excitatory
    if parameters_syn[isynapse,'synapse_type'] < 100:
        #synapse_type_name = "inhibitory"
        hotspot_synapses.append(neuron.h.DetGABAAB(parameters_syn[isynapse,'seg_x']))
        hotspot_netstims.append(neuron.h.NetStim())
        hotspot_netcons.append(neuron.h.NetCon(hotspot_netstims[isynapse],hotspot_synapses[isynapse]))
        
        hotspot_synapses[isynapse].tau_d_GABAA = parameters_syn[isynapse,'tau_d']
        hotspot_synapses[isynapse].tau_r_GABAA = 0.2   #rng.lognormal(0.2, 0.1)   
        hotspot_synapses[isynapse].tau_d_GABAB = 260.9
        hotspot_synapses[isynapse].tau_r_GABAB  = 3.5
        
        hotspot_synapses[isynapse].Use = parameters_syn[isynapse,'use']     
        hotspot_synapses[isynapse].Fac = parameters_syn[isynapse,'fac']     
        hotspot_synapses[isynapse].Dep = parameters_syn[isynapse,'dep']     

        hotspot_netcons[isynapse].weight[0] = parameters_syn[isynapse,'weight'] # strength of the synapse
        hotspot_netcons[isynapse].delay = parameters_syn[isynapse,'delay'] 
        hotspot_netstims[isynapse].number   = 9e9 # number of synaptic activation
        hotspot_netstims[isynapse].noise    = 1   # randomness
        hotspot_netstims[isynapse].interval = 200  # mean time between spikes |200 ms = 5 Hz|
        hotspot_netstims[isynapse].start = 0
        
    else:
        #synapse_type_name = "excitatory"
        hotspot_synapses.append(neuron.h.DetAMPANMDA(parameters_syn[isynapse,'seg_x']))
        hotspot_netstims.append(neuron.h.NetStim())
        hotspot_netcons.append(neuron.h.NetCon(hotspot_netstims[isynapse],hotspot_synapses[isynapse]))
        
        hotspot_synapses[isynapse].tau_d_AMPA = parameters_syn[isynapse,'tau_d']  
        hotspot_synapses[isynapse].tau_r_AMPA = 0.2
        hotspot_synapses[isynapse].tau_r_NMDA = 0.29
        hotspot_synapses[isynapse].tau_d_NMDA = 43        
        
        hotspot_synapses[isynapse].Use = parameters_syn[isynapse,'use']     
        hotspot_synapses[isynapse].Fac = parameters_syn[isynapse,'fac']     
        hotspot_synapses[isynapse].Dep = parameters_syn[isynapse,'dep']          
        
        hotspot_netcons[isynapse].weight[0] = parameters_syn[isynapse,'weight'] # strength of the synapse
        hotspot_netcons[isynapse].delay = parameters_syn[isynapse,'delay'] 
        hotspot_netstims[isynapse].number   = 9e9 # number of synaptic activation
        hotspot_netstims[isynapse].noise    = 1   # randomness
        hotspot_netstims[isynapse].interval = 1000  # mean time between spikes |1000 ms = 1 Hz|
        hotspot_netstims[isynapse].start = 0

# %%
isynapse
# Out:
# 0

# %%
# hotspot_synapses[isynapse].tau_d_AMPA = 1.74
# hotspot_synapses[isynapse].tau_r_AMPA = 0.2
# hotspot_synapses[isynapse].tau_r_NMDA = 0.29
# hotspot_synapses[isynapse].tau_d_NMDA = 43   

# hotspot_synapses[isynapse].Use = 0.09
# hotspot_synapses[isynapse].Dep = 138.0
# hotspot_synapses[isynapse].Fac = 670.0

hotspot_synapses[isynapse].Use = 0.5
hotspot_synapses[isynapse].Dep = 671.0
hotspot_synapses[isynapse].Fac = 17.0

hotspot_netcons[isynapse].weight[0] = 0.43
hotspot_netcons[isynapse].delay = 1.74
hotspot_netstims[isynapse].number   = 9e9 # number of synaptic activation
hotspot_netstims[isynapse].noise    = 0   # randomness
hotspot_netstims[isynapse].interval = 1000  # mean time between spikes |1000 ms = 1 Hz|
hotspot_netstims[isynapse].start = 200
# parameters_syn

# %%
timesimulation = 10300
plotvt(timesimulation)
# Out:
# Changed dt

# %%
hotspot_synapses[isynapse].Dep = 138.0
hotspot_synapses[isynapse].Fac = 670.0
timesimulation = 10300
plotvt(timesimulation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 4>()
#       2 hotspot_synapses[isynapse].Fac = 670.0
#       3 timesimulation = 10300
# ----> 4 plotvt(timesimulation)
#
# NameError: name 'plotvt' is not defined

# %%
def plotvt(timesimulation):
    
    neuron.h.dt = 0.05
    neuron.h.cvode_active(0)
    neuron.h.tstop = timesimulation # ms

    time = neuron.h.Vector()
    voltage = neuron.h.Vector()
    ik = neuron.h.Vector()


    time.record(neuron.h._ref_t)
    voltage.record(soma(.5)._ref_v);
    ik.record(soma(.5)._ref_ik);

    neuron.h.run()
    
    fontsiz=15
    timeRange = [199, timesimulation]
    ylim = [-73, -71]
    figSize = (14,4)
    fig = plt.figure(figsize=figSize)  

    plt.ylabel('V (mV)', fontsize=fontsiz)
    plt.xlabel('Time (ms)', fontsize=fontsiz)
    plt.plot(time,voltage, 'k')
    plt.xlim(timeRange)
    plt.ylim(ylim)
    plt.grid(True)
    plt.ion()
    plt.tight_layout()
    plt.show()
