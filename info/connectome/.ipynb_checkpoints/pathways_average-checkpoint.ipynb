# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import h5py
import json
import numpy as np
import os
import sys
from matplotlib import pyplot as plt

rootFolder = '/home/fernando/S1_netpyne/info/connectome/'
os.chdir(rootFolder)

savedata = False # Save 
plotdata = False # plot 

mtype_map = {}
Epops = ['L23_PC', 'L4_PC', 'L4_SS', 'L4_SP', 
            'L5_TTPC1', 'L5_TTPC2', 'L5_STPC', 'L5_UTPC',
            'L6_TPC_L1', 'L6_TPC_L4', 'L6_BPC', 'L6_IPC', 'L6_UTPC']

# ordered as in the Fig 3 - Cerebral Cortex, September 2017;27: 4570-4585 - doi: 10.1093/cercor/bhx150
mtype_map[1] = 'L1_DAC'
mtype_map[2] = 'L1_NGC-DA'
mtype_map[3] = 'L1_NGC-SA'
mtype_map[4] = 'L1_HAC'
mtype_map[5] = 'L1_DLAC'
mtype_map[6] = 'L1_SLAC'
mtype_map[7] = 'L23_PC'
mtype_map[8] = 'L23_MC'
mtype_map[9] = 'L23_BTC'
mtype_map[10] = 'L23_DBC'
mtype_map[11] = 'L23_BP'
mtype_map[12] = 'L23_NGC'
mtype_map[13] = 'L23_LBC'
mtype_map[14] = 'L23_NBC'
mtype_map[15] = 'L23_SBC'
mtype_map[16] = 'L23_ChC'
mtype_map[17] = 'L4_PC'
mtype_map[18] = 'L4_SP'
mtype_map[19] = 'L4_SS'
mtype_map[20] = 'L4_MC'
mtype_map[21] = 'L4_BTC'
mtype_map[22] = 'L4_DBC'
mtype_map[23] = 'L4_BP'
mtype_map[24] = 'L4_NGC'
mtype_map[25] = 'L4_LBC'
mtype_map[26] = 'L4_NBC'
mtype_map[27] = 'L4_SBC'
mtype_map[28] = 'L4_ChC'
mtype_map[29] = 'L5_TTPC1'
mtype_map[30] = 'L5_TTPC2'
mtype_map[31] = 'L5_UTPC'
mtype_map[32] = 'L5_STPC'
mtype_map[33] = 'L5_MC'
mtype_map[34] = 'L5_BTC'
mtype_map[35] = 'L5_DBC'
mtype_map[36] = 'L5_BP'
mtype_map[37] = 'L5_NGC'
mtype_map[38] = 'L5_LBC'
mtype_map[39] = 'L5_NBC'
mtype_map[40] = 'L5_SBC'
mtype_map[41] = 'L5_ChC'
mtype_map[42] = 'L6_TPC_L1'
mtype_map[43] = 'L6_TPC_L4'
mtype_map[44] = 'L6_UTPC'
mtype_map[45] = 'L6_IPC'
mtype_map[46] = 'L6_BPC'
mtype_map[47] = 'L6_MC'
mtype_map[48] = 'L6_BTC'
mtype_map[49] = 'L6_DBC'
mtype_map[50] = 'L6_BP'
mtype_map[51] = 'L6_NGC'
mtype_map[52] = 'L6_LBC'
mtype_map[53] = 'L6_NBC'
mtype_map[54] = 'L6_SBC'
mtype_map[55] = 'L6_ChC'

from scipy.optimize import curve_fit

Netinfo = {}

def exponential(x, a, b):
    return a*np.exp(-b*x)

def linear(x, a, b):
    return a*x + b

def Gauss(x, a, x0, sigma):
    return a * np.exp(-(x - x0)**2 / (2 * sigma**2))

data = {}
data['BBP_S1_mc0'] = {}
data['BBP_S1_mc1'] = {}
data['BBP_S1_mc2'] = {}
data['BBP_S1_mc3'] = {}
data['BBP_S1_mc4'] = {}
data['BBP_S1_mc5'] = {}
data['BBP_S1_mc6'] = {}

with open('Netconnections_mc0.json', 'r') as f:
    data['BBP_S1_mc0']['connProb'] = json.load(f) 

with open('Netconnections_mc1.json', 'r') as f:
    data['BBP_S1_mc1']['connProb'] = json.load(f) 

with open('Netconnections_mc2.json', 'r') as f:
    data['BBP_S1_mc2']['connProb'] = json.load(f) 
    
with open('Netconnections_mc3.json', 'r') as f:
    data['BBP_S1_mc3']['connProb'] = json.load(f) 

with open('Netconnections_mc4.json', 'r') as f:
    data['BBP_S1_mc4']['connProb'] = json.load(f) 

with open('Netconnections_mc5.json', 'r') as f:
    data['BBP_S1_mc5']['connProb'] = json.load(f) 
    
with open('Netconnections_mc6.json', 'r') as f:
    data['BBP_S1_mc6']['connProb'] = json.load(f)

# %% [markdown]
# ## First test: exp decay and linear saturation

# %%
for n in range(1,56):
    for m in range(1,56):
        
        pre = mtype_map[n]
        post = mtype_map[m]
        proj = '%s:%s' % (mtype_map[n],mtype_map[m])
        
        if pre in mtype_map[n]:                

            prob2D = []
            d2D = []
            prob2Dfulldata = []
            d2Dfulldata = []
            expfit = 0
            nn = 0    
            m0 = 0      
            m1 = 0      
            m2 = 0
            m3 = 0    
            m4 = 0
            m5 = 0    
            m6 = 0
            m7 = 0    
            m8 = 0
            m9 = 0   
            m10 = 0
            m11 = 0    
            m12 = 0
            m13 = 0   
            m14 = 0   
            pmat = 0   
            pmat0 = 0   
            mm = 0   
            for mc in range(7):
                pre = mtype_map[n]
                post = mtype_map[m]
                proj = '%s:%s' % (mtype_map[n],mtype_map[m])
                mcName = 'BBP_S1_mc' + str(mc)

                if proj in data[mcName]['connProb']:

                    pmat = pmat + float(data[mcName]['connProb'][proj]['connection_probability_full'])
                    nn =  nn + int(data[mcName]['connProb'][proj]['connections_total'])
                    pmat0 = pmat0 + float(data[mcName]['connProb'][proj]['connection_probability_less_25um'])

                    m0 = m0 + float(data[mcName]['connProb'][proj]['connection_probability_25um'])
                    m1 = m1 + float(data[mcName]['connProb'][proj]['connection_probability_50um'])
                    m2 = m2 + float(data[mcName]['connProb'][proj]['connection_probability_75um']) 
                    m3 = m3 + float(data[mcName]['connProb'][proj]['connection_probability_100um'])
                    m4 = m4 + float(data[mcName]['connProb'][proj]['connection_probability_125um'])
                    m5 = m5 + float(data[mcName]['connProb'][proj]['connection_probability_150um'])
                    m6 = m6 + float(data[mcName]['connProb'][proj]['connection_probability_175um'])
                    m7 = m7 + float(data[mcName]['connProb'][proj]['connection_probability_200um'])
                    m8 = m8 + float(data[mcName]['connProb'][proj]['connection_probability_225um'])
                    m9 = m9 + float(data[mcName]['connProb'][proj]['connection_probability_250um'])
                    m10 = m10 + float(data[mcName]['connProb'][proj]['connection_probability_275um'])
                    m11 = m11 + float(data[mcName]['connProb'][proj]['connection_probability_300um'])
                    m12 = m12 + float(data[mcName]['connProb'][proj]['connection_probability_325um'])
                    m13 = m13 + float(data[mcName]['connProb'][proj]['connection_probability_350um'])
                    m14 = m14 + float(data[mcName]['connProb'][proj]['connection_probability_375um'])

                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_less_25um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_25um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_50um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_75um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_100um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_125um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_150um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_175um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_200um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_225um']))      
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_250um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_275um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_300um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_325um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_350um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_375um']))   

                    d2Dfulldata.append(12.5)
                    d2Dfulldata.append(25)
                    d2Dfulldata.append(50) 
                    d2Dfulldata.append(75)     
                    d2Dfulldata.append(100)
                    d2Dfulldata.append(125)
                    d2Dfulldata.append(150)
                    d2Dfulldata.append(175)    
                    d2Dfulldata.append(200)      
                    d2Dfulldata.append(225)  
                    d2Dfulldata.append(250)
                    d2Dfulldata.append(275)
                    d2Dfulldata.append(300)
                    d2Dfulldata.append(325)    
                    d2Dfulldata.append(350)      
                    d2Dfulldata.append(375)

                    mm = mm + 1

            if mm == 7:
                prob2D.append(pmat0/mm)   
                prob2D.append(m0/mm)       
                prob2D.append(m1/mm)      
                prob2D.append(m2/mm)      
                prob2D.append(m3/mm)      
                prob2D.append(m4/mm)      
                prob2D.append(m5/mm)       
                prob2D.append(m6/mm)      
                prob2D.append(m7/mm)      
                prob2D.append(m8/mm)          
                prob2D.append(m9/mm)      
                prob2D.append(m10/mm)      
                prob2D.append(m11/mm)       
                prob2D.append(m12/mm)      
                prob2D.append(m13/mm)      
                prob2D.append(m14/mm)    

                d2D.append(12.5)
                d2D.append(25)
                d2D.append(50) 
                d2D.append(75)     
                d2D.append(100)
                d2D.append(125)
                d2D.append(150)
                d2D.append(175)    
                d2D.append(200)      
                d2D.append(225)
                d2D.append(250)
                d2D.append(275)
                d2D.append(300)
                d2D.append(325)    
                d2D.append(350)      
                d2D.append(375)

                x = d2D
                y = prob2D

                if max(y) == y[0]: # 25 um 
                    starts = 0
                elif max(y[1:]) == y[1]:
                    starts = 1 # 50 um 
                elif max(y[2:]) == y[2]:
                    starts = 2 # 75 um 
                elif max(y[3:]) == y[3]:
                    starts = 3 # 100 um 
                elif max(y[4:]) == y[4]:
                    starts = 4 # 125 um 
                elif max(y[5:]) == y[5]:
                    starts = 5 # 150 um 
                elif max(y[6:]) == y[6]:
                    starts = 6 # 175 um 
                else:
                    starts = 7 # 200 um 

                ends = 16
                if y[15] == 0: # 375 um 
                    ends = ends - 1
                    if y[14] == 0: # 375 um 
                        ends = ends - 1
                        if y[13] == 0: # 350 um 
                            ends = ends - 1
                            if y[12] == 0: # 325 um 
                                ends = ends - 1
                                if y[11] == 0: # 300 um 
                                    ends = ends - 1
                                    if y[10] == 0: # 275 um 
                                        ends = ends - 1
                                        if y[9] == 0: # 250 um 
                                            ends = ends - 1
                                            if y[8] == 0: # 225 um 
                                                ends = ends - 1
                                                if y[7] == 0: # 200 um 
                                                    ends = ends - 1
                                                    if y[6] == 0: # 175 um 
                                                        ends = ends - 1
                                                        if y[5] == 0: # 150 um 
                                                            ends = ends - 1
                                                            if y[4] == 0: # 125 um 
                                                                ends = ends - 1

                x = d2D[starts:ends]
                y = prob2D[starts:ends]

                if x[-1] == 375:
                    endsexp = 400
                else:
                    endsexp = x[-1]

                #saturation correction
                if x[0] < 100 and (ends-starts) > 9:

                    if x[0] == 12.5: # tolerance
                        fracx0 = 0.525
                    else:
                        fracx0 = 1.05

                    if (y[4]-y[5]) < 1.05*(y[5]-y[6]):
                        starts = starts + 5 
                    elif (y[3]-y[4]) < 1.05*(y[4]-y[5]):
                        starts = starts + 4 
                    elif (y[2]-y[3]) < 1.05*(y[3]-y[4]):
                        starts = starts + 3 
                    elif (y[1]-y[2]) < 1.05*(y[2]-y[3]):
                        starts = starts + 2 
                    elif (y[0]-y[1]) < fracx0*(y[1]-y[2]):
                        starts = starts + 1 
                   
                x = d2D[starts:ends]
                y = prob2D[starts:ends]

                # print(x,y)
                pars, cov = curve_fit(f=exponential, xdata=x, ydata=y, p0=[0, 0], bounds=(-np.inf, np.inf))

                pars0 = {} #exp saturation x [12.5,25,50, ..., start]
                pars0[0] = 0.0
                pars0[1] = 1.0

                if x[0] == 12.5:
                    xx = np.linspace(0, endsexp, 50)
                    yy = exponential(xx, *pars)
                elif x[0] == 25:
                    xx = np.linspace(25, endsexp, 50)
                    yy = exponential(xx, *pars)
                else:
                    xx = np.linspace(x[0], endsexp, 50)
                    yy = exponential(xx, *pars)   
 

                proj = '%s:%s' % (mtype_map[n],mtype_map[m])
                Netinfo[proj] = {}
                Netinfo[proj]['conn_total'] = '%.1f' % (nn/mm) 
                Netinfo[proj]['conn_prob_full'] = '%.5f' % (pmat/mm) 
                Netinfo[proj]['A0'] = '%.5f' % pars[0]
                Netinfo[proj]['shape'] = '%.2f' % (1.0/pars[1])          
                if x[0] == 12.5:
                    Netinfo[proj]['d_init'] = '%d' % 0
                else:
                    Netinfo[proj]['d_init'] = '%d' % x[0] 
                Netinfo[proj]['d_final'] = '%d' % x[-1]
                Netinfo[proj]['conn_prob_12.5um'] = '%.5f' % prob2D[0]
                Netinfo[proj]['conn_prob_25um'] = '%.5f' % prob2D[1]
                Netinfo[proj]['conn_prob_50um'] = '%.5f' % prob2D[2]
                Netinfo[proj]['conn_prob_75um'] = '%.5f' % prob2D[3]
                Netinfo[proj]['conn_prob_100um'] = '%.5f' % prob2D[4]
                Netinfo[proj]['conn_prob_125um'] = '%.5f' % prob2D[5]
                Netinfo[proj]['conn_prob_150um'] = '%.5f' % prob2D[6]
                Netinfo[proj]['conn_prob_175um'] = '%.5f' % prob2D[7]
                Netinfo[proj]['conn_prob_200um'] = '%.5f' % prob2D[8]
                Netinfo[proj]['conn_prob_225um'] = '%.5f' % prob2D[9]
                Netinfo[proj]['conn_prob_250um'] = '%.5f' % prob2D[10]
                Netinfo[proj]['conn_prob_275um'] = '%.5f' % prob2D[11]
                Netinfo[proj]['conn_prob_300um'] = '%.5f' % prob2D[12]
                Netinfo[proj]['conn_prob_325um'] = '%.5f' % prob2D[13]
                Netinfo[proj]['conn_prob_350um'] = '%.5f' % prob2D[14]
                Netinfo[proj]['conn_prob_375um'] = '%.5f' % prob2D[15]
                
                    
                plotdata = False  
                if plotdata:
                    #################
                    fontsiz=18
                    figSize = (12,5)
                    fig = plt.figure(figsize=figSize)  # Open a new figure                    
                    if x[0] == 12.5:
                        fig.suptitle('%s (%.1f conn) -> Exp(%.4f, %.1f, %.0f<d<%d), Gauss(%.4f, %.1f, %.1f, %.0f<d<%d)' % (proj,nn/mm,pars[0],1.0/pars[1],0.0,x[-1],popt[0],popt[1],popt[2],0.0,x[-1]), fontsize=14)
                    else:
                        fig.suptitle('%s (%.1f conn) -> Exp(%.4f, %.1f, %.0f<d<%d), Gauss(%.4f, %.1f, %.1f, %.0f<d<%d)' % (proj,nn/mm,pars[0],1.0/pars[1],x[0],x[-1],popt[0],popt[1],popt[2],xg0,x[-1]), fontsize=14)
                    xgg = np.linspace(0, endsexp, 50)
                    plt.subplot(1, 1, 1)
                    plt.ylabel('Prob2D', fontsize=fontsiz)
                    plt.plot(d2Dfulldata, prob2Dfulldata, 'c.', label='7mcs')
                    plt.plot(d2D, prob2D, 'ko', label='mean')
                    plt.plot(xx, yy, linewidth=2.0, color='blue', label='fit-e') 
                    plt.xlabel('distance (um)', fontsize=fontsiz)
                    plt.xlim(0, 400)
                    plt.grid(False)
                    plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.0))
                    plt.tight_layout()

#                     plt.savefig(rootFolder+'Figures/27Aug2021b/prob_dist2D_%s.png' % proj, facecolor = 'white' , dpi=300)

                    plt.close(fig)

# %% [markdown]
# ### Errors comparing Netpyne and BBP

# %%
error50p = ['L23_DBC:L1_NGC-DA', 'L23_DBC:L6_BP', 'L23_LBC:L23_BP', 'L4_BP:L23_NBC', 'L4_MC:L6_MC', 'L4_SBC:L4_ChC', 'L5_BP:L5_BTC', 'L5_BP:L5_LBC', 'L5_BTC:L6_DBC', 'L5_MC:L4_BP', 'L5_TTPC2:L1_HAC', 'L5_TTPC2:L1_NGC-SA', 'L5_TTPC2:L1_SLAC', 'L6_BPC:L23_ChC', 'L6_BP:L6_MC', 'L6_BTC:L23_PC', 'L6_IPC:L5_NGC', 'L6_LBC:L23_DBC', 'L6_LBC:L5_NGC', 'L6_MC:L1_NGC-DA', 'L6_NGC:L6_BP', 'L6_NGC:L6_ChC', 'L6_UTPC:L5_NGC']
error40p = ['L1_DAC:L23_BP', 'L1_SLAC:L1_DLAC', 'L23_BP:L23_MC', 'L23_BTC:L1_NGC-SA', 'L23_BTC:L5_SBC', 'L23_BTC:L6_BTC', 'L23_LBC:L4_ChC', 'L23_NBC:L23_BP', 'L23_SBC:L4_ChC', 'L4_DBC:L6_ChC', 'L4_LBC:L6_BP', 'L4_MC:L23_ChC', 'L4_MC:L5_DBC', 'L5_LBC:L4_NGC', 'L5_LBC:L6_BTC', 'L5_NBC:L23_BTC', 'L5_NGC:L4_MC', 'L5_SBC:L4_BTC', 'L5_TTPC2:L1_DAC', 'L5_TTPC2:L1_NGC-DA', 'L5_UTPC:L6_NGC', 'L6_BP:L6_BP', 'L6_IPC:L4_ChC', 'L6_MC:L4_ChC', 'L6_TPC_L1:L23_NGC', 'L6_TPC_L4:L4_DBC', 'L6_TPC_L4:L6_NGC', 'L6_UTPC:L23_NGC']
error30p_le5 = ['L1_DLAC:L1_DLAC', 'L1_HAC:L5_UTPC', 'L1_NGC-SA:L1_SLAC', 'L1_NGC-SA:L23_NGC', 'L1_SLAC:L23_BTC', 'L23_DBC:L1_NGC-SA', 'L23_LBC:L5_SBC', 'L23_LBC:L6_MC', 'L23_MC:L6_MC', 'L23_NGC:L5_BTC', 'L4_BP:L23_LBC', 'L4_BP:L4_SBC', 'L4_BP:L6_IPC', 'L4_DBC:L5_ChC', 'L4_DBC:L5_DBC', 'L4_LBC:L6_SBC', 'L4_MC:L5_BP', 'L4_MC:L6_NBC', 'L4_NBC:L4_ChC', 'L4_NBC:L6_SBC', 'L4_NGC:L4_NBC', 'L5_BP:L23_SBC', 'L5_BTC:L4_DBC', 'L5_LBC:L4_ChC', 'L5_MC:L6_BTC', 'L5_MC:L6_DBC', 'L5_NBC:L6_ChC', 'L5_SBC:L23_LBC', 'L5_STPC:L4_ChC', 'L6_BP:L5_ChC', 'L6_BTC:L5_SBC', 'L6_DBC:L4_SS', 'L6_IPC:L4_DBC', 'L6_TPC_L1:L4_BTC']
error30p_g5 = ['L1_DLAC:L1_DAC', 'L23_BP:L23_PC', 'L23_BP:L4_PC', 'L23_NBC:L4_DBC', 'L4_ChC:L4_PC', 'L4_ChC:L4_SP', 'L4_NBC:L4_BTC', 'L4_SBC:L23_BTC', 'L4_SBC:L23_MC', 'L5_MC:L23_NGC', 'L5_MC:L6_IPC', 'L5_STPC:L6_BP', 'L5_TTPC1:L6_DBC', 'L6_BPC:L23_NBC', 'L6_IPC:L23_BTC', 'L6_MC:L1_HAC', 'L6_SBC:L5_LBC', 'L6_TPC_L4:L4_NBC']
error20p_g5 = ['L1_DAC:L5_UTPC', 'L1_SLAC:L23_NBC', 'L23_DBC:L23_ChC', 'L23_LBC:L4_NBC', 'L23_MC:L6_IPC', 'L23_NBC:L1_NGC-DA', 'L23_NBC:L1_NGC-SA', 'L23_NBC:L1_SLAC', 'L23_NBC:L4_LBC', 'L4_BTC:L5_MC', 'L4_ChC:L4_SS', 'L4_ChC:L5_TTPC1', 'L4_DBC:L23_MC', 'L4_DBC:L4_NBC', 'L4_LBC:L23_DBC', 'L4_NBC:L4_DBC', 'L4_PC:L4_DBC', 'L4_PC:L4_NGC', 'L4_PC:L5_DBC', 'L4_PC:L5_NGC', 'L5_BP:L4_SS', 'L5_ChC:L6_IPC', 'L5_LBC:L5_BP', 'L5_MC:L23_LBC', 'L5_MC:L5_BP', 'L5_NBC:L23_LBC', 'L5_NGC:L6_TPC_L1', 'L5_TTPC1:L5_NGC', 'L5_TTPC2:L23_ChC', 'L5_UTPC:L5_SBC', 'L6_BPC:L6_DBC', 'L6_BPC:L6_NGC', 'L6_IPC:L23_MC', 'L6_TPC_L1:L23_LBC', 'L6_TPC_L1:L23_MC']

# %%
errors20p50p = ['L23_DBC:L1_NGC-DA', 'L23_DBC:L6_BP', 'L23_LBC:L23_BP', 'L4_BP:L23_NBC', 'L4_MC:L6_MC', 'L4_SBC:L4_ChC', 'L5_BP:L5_BTC', 'L5_BP:L5_LBC', 'L5_BTC:L6_DBC', 
                'L5_MC:L4_BP', 'L5_TTPC2:L1_HAC', 'L5_TTPC2:L1_NGC-SA', 'L5_TTPC2:L1_SLAC', 'L6_BPC:L23_ChC', 'L6_BP:L6_MC', 'L6_BTC:L23_PC', 'L6_IPC:L5_NGC', 'L6_LBC:L23_DBC', 
                'L6_LBC:L5_NGC', 'L6_MC:L1_NGC-DA', 'L6_NGC:L6_BP', 'L6_NGC:L6_ChC', 'L6_UTPC:L5_NGC', 'L1_DAC:L23_BP', 'L1_SLAC:L1_DLAC', 'L23_BP:L23_MC', 'L23_BTC:L1_NGC-SA', 
                'L23_BTC:L5_SBC', 'L23_BTC:L6_BTC', 'L23_LBC:L4_ChC', 'L23_NBC:L23_BP', 'L23_SBC:L4_ChC', 'L4_DBC:L6_ChC', 'L4_LBC:L6_BP', 'L4_MC:L23_ChC', 'L4_MC:L5_DBC', 
                'L5_LBC:L4_NGC', 'L5_LBC:L6_BTC', 'L5_NBC:L23_BTC', 'L5_NGC:L4_MC', 'L5_SBC:L4_BTC', 'L5_TTPC2:L1_DAC', 'L5_TTPC2:L1_NGC-DA', 'L5_UTPC:L6_NGC', 'L6_BP:L6_BP', 
                'L6_IPC:L4_ChC', 'L6_MC:L4_ChC', 'L6_TPC_L1:L23_NGC', 'L6_TPC_L4:L4_DBC', 'L6_TPC_L4:L6_NGC', 'L6_UTPC:L23_NGC', 'L1_DLAC:L1_DLAC', 'L1_HAC:L5_UTPC', 
                'L1_NGC-SA:L1_SLAC', 'L1_NGC-SA:L23_NGC', 'L1_SLAC:L23_BTC', 'L23_DBC:L1_NGC-SA', 'L23_LBC:L5_SBC', 'L23_LBC:L6_MC', 'L23_MC:L6_MC', 'L23_NGC:L5_BTC', 
                'L4_BP:L23_LBC', 'L4_BP:L4_SBC', 'L4_BP:L6_IPC', 'L4_DBC:L5_ChC', 'L4_DBC:L5_DBC', 'L4_LBC:L6_SBC', 'L4_MC:L5_BP', 'L4_MC:L6_NBC', 'L4_NBC:L4_ChC', 
                'L4_NBC:L6_SBC', 'L4_NGC:L4_NBC', 'L5_BP:L23_SBC', 'L5_BTC:L4_DBC', 'L5_LBC:L4_ChC', 'L5_MC:L6_BTC', 'L5_MC:L6_DBC', 'L5_NBC:L6_ChC', 'L5_SBC:L23_LBC', 
                'L5_STPC:L4_ChC', 'L6_BP:L5_ChC', 'L6_BTC:L5_SBC', 'L6_DBC:L4_SS', 'L6_IPC:L4_DBC', 'L6_TPC_L1:L4_BTC', 'L1_DLAC:L1_DAC', 'L23_BP:L23_PC', 'L23_BP:L4_PC', 
                'L23_NBC:L4_DBC', 'L4_ChC:L4_PC', 'L4_ChC:L4_SP', 'L4_NBC:L4_BTC', 'L4_SBC:L23_BTC', 'L4_SBC:L23_MC', 'L5_MC:L23_NGC', 'L5_MC:L6_IPC', 'L5_STPC:L6_BP', 
                'L5_TTPC1:L6_DBC', 'L6_BPC:L23_NBC', 'L6_IPC:L23_BTC', 'L6_MC:L1_HAC', 'L6_SBC:L5_LBC', 'L6_TPC_L4:L4_NBC', 'L1_DAC:L5_UTPC', 'L1_SLAC:L23_NBC', 
                'L23_DBC:L23_ChC', 'L23_LBC:L4_NBC', 'L23_MC:L6_IPC', 'L23_NBC:L1_NGC-DA', 'L23_NBC:L1_NGC-SA', 'L23_NBC:L1_SLAC', 'L23_NBC:L4_LBC', 'L4_BTC:L5_MC', 
                'L4_ChC:L4_SS', 'L4_ChC:L5_TTPC1', 'L4_DBC:L23_MC', 'L4_DBC:L4_NBC', 'L4_LBC:L23_DBC', 'L4_NBC:L4_DBC', 'L4_PC:L4_DBC', 'L4_PC:L4_NGC', 'L4_PC:L5_DBC', 
                'L4_PC:L5_NGC', 'L5_BP:L4_SS', 'L5_ChC:L6_IPC', 'L5_LBC:L5_BP', 'L5_MC:L23_LBC', 'L5_MC:L5_BP', 'L5_NBC:L23_LBC', 'L5_NGC:L6_TPC_L1', 'L5_TTPC1:L5_NGC', 
                'L5_TTPC2:L23_ChC', 'L5_UTPC:L5_SBC', 'L6_BPC:L6_DBC', 'L6_BPC:L6_NGC', 'L6_IPC:L23_MC', 'L6_TPC_L1:L23_LBC', 'L6_TPC_L1:L23_MC']

# %% [markdown]
# ## Fit exp [0:end] or [25:end] (p[12.5] in [0:25])

# %%
expexpfit = ['L23_DBC:L1_NGC-DA','L23_LBC:L23_BP','L4_BP:L23_NBC','L5_MC:L4_BP','L5_BTC:L6_DBC','L5_BP:L5_BTC',
             'L5_BP:L5_LBC','L6_UTPC:L5_NGC','L6_IPC:L5_NGC','L6_MC:L1_NGC-DA','L6_BP:L6_MC',
             'L6_NGC:L6_BP','L1_SLAC:L1_DLAC','L23_LBC:L4_ChC','L4_MC:L23_ChC','L4_MC:L5_DBC',
             'L4_LBC:L6_BP','L5_LBC:L6_BTC','L6_TPC_L4:L4_DBC','L6_TPC_L4:L6_NGC','L6_BP:L6_BP','L23_NBC:L4_DBC',
             'L4_ChC:L4_PC','L4_ChC:L4_SP','L5_MC:L6_IPC','L6_TPC_L4:L4_NBC','L6_BPC:L23_NBC','L23_LBC:L6_MC',
             'L4_MC:L5_BP','L4_NGC:L4_NBC','L23_LBC:L4_NBC','L4_BTC:L5_MC','L4_LBC:L23_DBC',
             'L5_UTPC:L5_SBC','L5_MC:L5_BP','L5_ChC:L6_IPC','L6_TPC_L1:L23_LBC']

gaussgaussfit = ['L4_NBC:L4_ChC']
            
expgaussfit = ['L6_BTC:L23_PC','L23_SBC:L4_ChC']

for n in range(1,56):
    for m in range(1,56):
        
        pre = mtype_map[n]
        post = mtype_map[m]
        proj = '%s:%s' % (mtype_map[n],mtype_map[m])
        
#         if proj in expexpfit:    
        if pre in mtype_map[n]:                  

            prob2D = []
            d2D = []
            prob2Dfulldata = []
            d2Dfulldata = []
            expfit = 0
            nn = 0    
            m0 = 0      
            m1 = 0      
            m2 = 0
            m3 = 0    
            m4 = 0
            m5 = 0    
            m6 = 0
            m7 = 0    
            m8 = 0
            m9 = 0   
            m10 = 0
            m11 = 0    
            m12 = 0
            m13 = 0   
            m14 = 0   
            pmat = 0   
            pmat0 = 0   
            mm = 0   
            for mc in range(7):
                pre = mtype_map[n]
                post = mtype_map[m]
                proj = '%s:%s' % (mtype_map[n],mtype_map[m])
                mcName = 'BBP_S1_mc' + str(mc)

                if proj in data[mcName]['connProb']:

                    pmat = pmat + float(data[mcName]['connProb'][proj]['connection_probability_full'])
                    nn =  nn + int(data[mcName]['connProb'][proj]['connections_total'])
                    pmat0 = pmat0 + float(data[mcName]['connProb'][proj]['connection_probability_less_25um'])

                    m0 = m0 + float(data[mcName]['connProb'][proj]['connection_probability_25um'])
                    m1 = m1 + float(data[mcName]['connProb'][proj]['connection_probability_50um'])
                    m2 = m2 + float(data[mcName]['connProb'][proj]['connection_probability_75um']) 
                    m3 = m3 + float(data[mcName]['connProb'][proj]['connection_probability_100um'])
                    m4 = m4 + float(data[mcName]['connProb'][proj]['connection_probability_125um'])
                    m5 = m5 + float(data[mcName]['connProb'][proj]['connection_probability_150um'])
                    m6 = m6 + float(data[mcName]['connProb'][proj]['connection_probability_175um'])
                    m7 = m7 + float(data[mcName]['connProb'][proj]['connection_probability_200um'])
                    m8 = m8 + float(data[mcName]['connProb'][proj]['connection_probability_225um'])
                    m9 = m9 + float(data[mcName]['connProb'][proj]['connection_probability_250um'])
                    m10 = m10 + float(data[mcName]['connProb'][proj]['connection_probability_275um'])
                    m11 = m11 + float(data[mcName]['connProb'][proj]['connection_probability_300um'])
                    m12 = m12 + float(data[mcName]['connProb'][proj]['connection_probability_325um'])
                    m13 = m13 + float(data[mcName]['connProb'][proj]['connection_probability_350um'])
                    m14 = m14 + float(data[mcName]['connProb'][proj]['connection_probability_375um'])

                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_less_25um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_25um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_50um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_75um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_100um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_125um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_150um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_175um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_200um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_225um']))      
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_250um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_275um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_300um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_325um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_350um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_375um']))   

                    d2Dfulldata.append(12.5)
                    d2Dfulldata.append(25)
                    d2Dfulldata.append(50) 
                    d2Dfulldata.append(75)     
                    d2Dfulldata.append(100)
                    d2Dfulldata.append(125)
                    d2Dfulldata.append(150)
                    d2Dfulldata.append(175)    
                    d2Dfulldata.append(200)      
                    d2Dfulldata.append(225)  
                    d2Dfulldata.append(250)
                    d2Dfulldata.append(275)
                    d2Dfulldata.append(300)
                    d2Dfulldata.append(325)    
                    d2Dfulldata.append(350)      
                    d2Dfulldata.append(375)

                    mm = mm + 1

            if mm == 7:
                prob2D.append(pmat0/mm)   
                prob2D.append(m0/mm)       
                prob2D.append(m1/mm)      
                prob2D.append(m2/mm)      
                prob2D.append(m3/mm)      
                prob2D.append(m4/mm)      
                prob2D.append(m5/mm)       
                prob2D.append(m6/mm)      
                prob2D.append(m7/mm)      
                prob2D.append(m8/mm)          
                prob2D.append(m9/mm)      
                prob2D.append(m10/mm)      
                prob2D.append(m11/mm)       
                prob2D.append(m12/mm)      
                prob2D.append(m13/mm)      
                prob2D.append(m14/mm)    

                d2D.append(12.5)
                d2D.append(25)
                d2D.append(50) 
                d2D.append(75)     
                d2D.append(100)
                d2D.append(125)
                d2D.append(150)
                d2D.append(175)    
                d2D.append(200)      
                d2D.append(225)
                d2D.append(250)
                d2D.append(275)
                d2D.append(300)
                d2D.append(325)    
                d2D.append(350)      
                d2D.append(375)

                x = d2D
                y = prob2D

                ends = 16
                if y[15] == 0: # 375 um 
                    ends = ends - 1
                    if y[14] == 0: # 375 um 
                        ends = ends - 1
                        if y[13] == 0: # 350 um 
                            ends = ends - 1
                            if y[12] == 0: # 325 um 
                                ends = ends - 1
                                if y[11] == 0: # 300 um 
                                    ends = ends - 1
                                    if y[10] == 0: # 275 um 
                                        ends = ends - 1
                                        if y[9] == 0: # 250 um 
                                            ends = ends - 1
                                            if y[8] == 0: # 225 um 
                                                ends = ends - 1
                                                if y[7] == 0: # 200 um 
                                                    ends = ends - 1
                                                    if y[6] == 0: # 175 um 
                                                        ends = ends - 1
                                                        if y[5] == 0: # 150 um 
                                                            ends = ends - 1
                                                            if y[4] == 0: # 125 um 
                                                                ends = ends - 1

                if x[-1] == 375:
                    endsexp = 400
                else:
                    endsexp = x[-1]

                #saturation correction
                if prob2D[0] > prob2D[1]: #ajusts by hand
                    starts = 0
                else:
                    starts = 1
                
                x = d2D[starts:ends]
                y = prob2D[starts:ends]
    
                pars, cov = curve_fit(f=exponential, xdata=x, ydata=y, p0=[0, 0], bounds=(-np.inf, np.inf))

                if x[0] == 12.5:
                    xx = np.linspace(0, endsexp, 50)
                    yy = exponential(xx, *pars)
                else:
                    xx = np.linspace(25, endsexp, 50)
                    yy = exponential(xx, *pars)

                    
                plotdata = False

                proj = '%s:%s' % (mtype_map[n],mtype_map[m])
                Netinfo[proj]['singleexp_A0'] = '%.5f' % pars[0]
                Netinfo[proj]['singleexp_shape'] = '%.2f' % (1.0/pars[1])                
                if x[0] == 12.5:
                    Netinfo[proj]['singleexp_d_init'] = '%d' % 0
                else:
                    Netinfo[proj]['singleexp_d_init'] = '%d' % x[0] 
                
                # plot probs
                if plotdata:
                    print(proj)
                    
                    fontsiz=18
                    figSize = (8,5)
                    fig = plt.figure(figsize=figSize)
                    
                    if x[0] == 12.5:
                        fig.suptitle('%s (%.1f conn) -> Exp(%.4f, %.1f, %.0f<d<%d)' % (proj,nn/mm,pars[0],1.0/pars[1],0.0,x[-1]), fontsize=14)
                    else:
                        fig.suptitle('%s (%.1f conn) -> Exp(%.4f, %.1f, %.0f<d<%d)' % (proj,nn/mm,pars[0],1.0/pars[1],x[0],x[-1]), fontsize=14)
                        
                    xgg = np.linspace(0, endsexp, 50)
                    plt.subplot(1, 1, 1)
                    plt.ylabel('Prob2D', fontsize=fontsiz)
                    plt.plot(d2Dfulldata, prob2Dfulldata, 'c.', label='7mcs')
                    plt.plot(d2D, prob2D, 'ko', label='mean')
                    plt.plot(xx, yy, linewidth=2.0, color='blue', label='fit-e') 
                    if x[0] == 25:
                        plt.plot([0.0,25.0],[prob2D[0],prob2D[0]], linewidth=2.0, linestyle='--', color='blue', label='fit-ls') 
                    plt.xlabel('distance (um)', fontsize=fontsiz)
                    plt.xlim(0, 300)
                    # ~ plt.ylim(ylim)
                    plt.grid(False)
                    plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.0))
                    # plt.ion()
                    plt.tight_layout()

                    plt.savefig(rootFolder+'Figures/allEXP/prob_dist2D_%s.png' % proj, facecolor = 'white' , dpi=300)
                    plt.close(fig)

# %%
# print(Netinfo)
# with open(rootFolder+'Netconnections_mean_single_exp.json', 'w') as outfile:
#     json.dump(Netinfo, outfile)

# %% [markdown]
# ## Single Gaussian

# %%
plotdata = False

for n in range(1,56):
    for m in range(1,56):
        
        pre = mtype_map[n]
        post = mtype_map[m]
        proj = '%s:%s' % (mtype_map[n],mtype_map[m])
        
        if pre in mtype_map[n]:                

            prob2D = []
            d2D = []
            prob2Dfulldata = []
            d2Dfulldata = []
            expfit = 0
            nn = 0    
            m0 = 0      
            m1 = 0      
            m2 = 0
            m3 = 0    
            m4 = 0
            m5 = 0    
            m6 = 0
            m7 = 0    
            m8 = 0
            m9 = 0   
            m10 = 0
            m11 = 0    
            m12 = 0
            m13 = 0   
            m14 = 0   
            pmat = 0   
            pmat0 = 0   
            mm = 0   
            for mc in range(7):
                pre = mtype_map[n]
                post = mtype_map[m]
                proj = '%s:%s' % (mtype_map[n],mtype_map[m])
                mcName = 'BBP_S1_mc' + str(mc)

                if proj in data[mcName]['connProb']:

                    pmat = pmat + float(data[mcName]['connProb'][proj]['connection_probability_full'])
                    nn =  nn + int(data[mcName]['connProb'][proj]['connections_total'])
                    pmat0 = pmat0 + float(data[mcName]['connProb'][proj]['connection_probability_less_25um'])

                    m0 = m0 + float(data[mcName]['connProb'][proj]['connection_probability_25um'])
                    m1 = m1 + float(data[mcName]['connProb'][proj]['connection_probability_50um'])
                    m2 = m2 + float(data[mcName]['connProb'][proj]['connection_probability_75um']) 
                    m3 = m3 + float(data[mcName]['connProb'][proj]['connection_probability_100um'])
                    m4 = m4 + float(data[mcName]['connProb'][proj]['connection_probability_125um'])
                    m5 = m5 + float(data[mcName]['connProb'][proj]['connection_probability_150um'])
                    m6 = m6 + float(data[mcName]['connProb'][proj]['connection_probability_175um'])
                    m7 = m7 + float(data[mcName]['connProb'][proj]['connection_probability_200um'])
                    m8 = m8 + float(data[mcName]['connProb'][proj]['connection_probability_225um'])
                    m9 = m9 + float(data[mcName]['connProb'][proj]['connection_probability_250um'])
                    m10 = m10 + float(data[mcName]['connProb'][proj]['connection_probability_275um'])
                    m11 = m11 + float(data[mcName]['connProb'][proj]['connection_probability_300um'])
                    m12 = m12 + float(data[mcName]['connProb'][proj]['connection_probability_325um'])
                    m13 = m13 + float(data[mcName]['connProb'][proj]['connection_probability_350um'])
                    m14 = m14 + float(data[mcName]['connProb'][proj]['connection_probability_375um'])

                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_less_25um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_25um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_50um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_75um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_100um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_125um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_150um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_175um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_200um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_225um']))      
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_250um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_275um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_300um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_325um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_350um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_375um']))   

                    d2Dfulldata.append(12.5)
                    d2Dfulldata.append(25)
                    d2Dfulldata.append(50) 
                    d2Dfulldata.append(75)     
                    d2Dfulldata.append(100)
                    d2Dfulldata.append(125)
                    d2Dfulldata.append(150)
                    d2Dfulldata.append(175)    
                    d2Dfulldata.append(200)      
                    d2Dfulldata.append(225)  
                    d2Dfulldata.append(250)
                    d2Dfulldata.append(275)
                    d2Dfulldata.append(300)
                    d2Dfulldata.append(325)    
                    d2Dfulldata.append(350)      
                    d2Dfulldata.append(375)

                    mm = mm + 1

            if mm == 7:
                prob2D.append(pmat0/mm)   
                prob2D.append(m0/mm)       
                prob2D.append(m1/mm)      
                prob2D.append(m2/mm)      
                prob2D.append(m3/mm)      
                prob2D.append(m4/mm)      
                prob2D.append(m5/mm)       
                prob2D.append(m6/mm)      
                prob2D.append(m7/mm)      
                prob2D.append(m8/mm)          
                prob2D.append(m9/mm)      
                prob2D.append(m10/mm)      
                prob2D.append(m11/mm)       
                prob2D.append(m12/mm)      
                prob2D.append(m13/mm)      
                prob2D.append(m14/mm)    

                d2D.append(12.5)
                d2D.append(25)
                d2D.append(50) 
                d2D.append(75)     
                d2D.append(100)
                d2D.append(125)
                d2D.append(150)
                d2D.append(175)    
                d2D.append(200)      
                d2D.append(225)
                d2D.append(250)
                d2D.append(275)
                d2D.append(300)
                d2D.append(325)    
                d2D.append(350)      
                d2D.append(375)

                x = d2D
                y = prob2D

                starts = 0
                
                ends = 16
                if y[15] == 0: # 375 um 
                    ends = ends - 1
                    if y[14] == 0: # 375 um 
                        ends = ends - 1
                        if y[13] == 0: # 350 um 
                            ends = ends - 1
                            if y[12] == 0: # 325 um 
                                ends = ends - 1
                                if y[11] == 0: # 300 um 
                                    ends = ends - 1
                                    if y[10] == 0: # 275 um 
                                        ends = ends - 1
                                        if y[9] == 0: # 250 um 
                                            ends = ends - 1
                                            if y[8] == 0: # 225 um 
                                                ends = ends - 1
                                                if y[7] == 0: # 200 um 
                                                    ends = ends - 1
                                                    if y[6] == 0: # 175 um 
                                                        ends = ends - 1
                                                        if y[5] == 0: # 150 um 
                                                            ends = ends - 1
                                                            if y[4] == 0: # 125 um 
                                                                ends = ends - 1

                x = d2D[starts:ends]
                y = prob2D[starts:ends]

                if x[-1] == 375:
                    endsexp = 400
                else:
                    endsexp = x[-1]

                xg0 = 0
                xg = np.array(d2D[0:ends])
                yg = np.array(prob2D[0:ends])
                # weighted arithmetic mean 
                meang = sum(xg * yg) / sum(yg)
                sigmag = np.sqrt(sum(yg * (xg - meang)**2) / sum(yg))                
                popt = [0, 0, 1]            
                pcov = np.zeros((3,3))
                try:  
                    popt,pcov = curve_fit(Gauss, xg, yg, p0=[max(yg), meang, sigmag])
                except:
                    try:  
                        xg0 = 0
                        xg = np.array(d2D[1:ends])
                        yg = np.array(prob2D[1:ends])
                        # weighted arithmetic mean 
                        meang = sum(xg * yg) / sum(yg)
                        sigmag = np.sqrt(sum(yg * (xg - meang)**2) / sum(yg))                
                        popt = [0, 0, 1]            
                        pcov = np.zeros((3,3))
                        popt,pcov = curve_fit(Gauss, xg, yg, p0=[max(yg), meang, sigmag])
                    except:
                        try:                      
                            xg0 = 50
                            xg = np.array(d2D[2:ends])
                            yg = np.array(prob2D[2:ends])
                            # weighted arithmetic mean 
                            meang = sum(xg * yg) / sum(yg)
                            sigmag = np.sqrt(sum(yg * (xg - meang)**2) / sum(yg))                
                            popt = [0, 0, 1]            
                            pcov = np.zeros((3,3))
                            popt,pcov = curve_fit(Gauss, xg, yg, p0=[max(yg), meang, sigmag])
                        except:
                            try:  
                                xg0 = 75
                                xg = np.array(d2D[3:ends])
                                yg = np.array(prob2D[3:ends])
                                # weighted arithmetic mean 
                                meang = sum(xg * yg) / sum(yg)
                                sigmag = np.sqrt(sum(yg * (xg - meang)**2) / sum(yg))                
                                popt = [0, 0, 1]            
                                pcov = np.zeros((3,3))
                                popt,pcov = curve_fit(Gauss, xg, yg, p0=[max(yg), meang, sigmag])
                            except:
                                try:  
                                    xg0 = 100
                                    xg = np.array(d2D[4:ends])
                                    yg = np.array(prob2D[4:ends])
                                    # weighted arithmetic mean 
                                    meang = sum(xg * yg) / sum(yg)
                                    sigmag = np.sqrt(sum(yg * (xg - meang)**2) / sum(yg))                
                                    popt = [0, 0, 1]            
                                    pcov = np.zeros((3,3))
                                    popt,pcov = curve_fit(Gauss, xg, yg, p0=[max(yg), meang, sigmag])
                                except:
                                    try:   
                                        xg0 = 0
                                        xg = np.array(d2D[1:7])
                                        yg = np.array(prob2D[1:7])
                                        # weighted arithmetic mean 
                                        meang = sum(xg * yg) / sum(yg)
                                        sigmag = np.sqrt(sum(yg * (xg - meang)**2) / sum(yg))                
                                        popt = [0, 0, 1]            
                                        pcov = np.zeros((3,3))
                                        popt,pcov = curve_fit(Gauss, xg, yg, p0=[max(yg), meang, sigmag])
                                    except:
                                        try:   
                                            xg0 = 50
                                            xg = np.array(d2D[2:7])
                                            yg = np.array(prob2D[2:7])
                                            # weighted arithmetic mean 
                                            meang = sum(xg * yg) / sum(yg)
                                            sigmag = np.sqrt(sum(yg * (xg - meang)**2) / sum(yg))                
                                            popt = [0, 0, 1]            
                                            pcov = np.zeros((3,3))
                                            popt,pcov = curve_fit(Gauss, xg, yg, p0=[max(yg), meang, sigmag])
                                        except:
                                            try:   
                                                xg0 = 0
                                                xg = np.array(d2D[1:6])
                                                yg = np.array(prob2D[1:6])
                                                # weighted arithmetic mean 
                                                meang = sum(xg * yg) / sum(yg)
                                                sigmag = np.sqrt(sum(yg * (xg - meang)**2) / sum(yg))                
                                                popt = [0, 0, 1]            
                                                pcov = np.zeros((3,3))
                                                popt,pcov = curve_fit(Gauss, xg, yg, p0=[max(yg), meang, sigmag])
                                            except:
                                                try:   
                                                    xg0 = 50
                                                    xg = np.array(d2D[2:6])
                                                    yg = np.array(prob2D[2:6])
                                                    # weighted arithmetic mean 
                                                    meang = sum(xg * yg) / sum(yg)
                                                    sigmag = np.sqrt(sum(yg * (xg - meang)**2) / sum(yg))                
                                                    popt = [0, 0, 1]            
                                                    pcov = np.zeros((3,3))
                                                    popt,pcov = curve_fit(Gauss, xg, yg, p0=[max(yg), meang, sigmag])
                                                except:                                        
                                                    xg0 = x[-1]
                                                    Optimalparameters = 'not found'
#                                                     print('Optimal parameters not found for %s (%d:%d)' % (proj,n,m))   

                proj = '%s:%s' % (mtype_map[n],mtype_map[m])
                Netinfo[proj]['singlegauss_A0g'] = '%.5f' % popt[0]
                Netinfo[proj]['singlegauss_x0g'] = '%.2f' % popt[1]
                Netinfo[proj]['singlegauss_shapeg'] = '%.2f' % popt[2]
                Netinfo[proj]['singlegauss_d_init'] = '%d' % xg0 

                # plot probs
                if plotdata:
                    print(proj)
                    fontsiz=18
                    figSize = (8,5)
                    fig = plt.figure(figsize=figSize)  # Open a new figure
                    if x[0] == 12.5:
                        fig.suptitle('%s (%.1f conn) -> Gauss(%.4f, %.1f, %.1f, %.0f<d<%d)' % (proj,nn/mm,popt[0],popt[1],popt[2],0.0,x[-1]), fontsize=14)
                    else:
                        fig.suptitle('%s (%.1f conn) -> Gauss(%.4f, %.1f, %.1f, %.0f<d<%d)' % (proj,nn/mm,popt[0],popt[1],popt[2],xg0,x[-1]), fontsize=14)
                    xgg = np.linspace(0, endsexp, 50)
                    plt.subplot(1, 1, 1)
                    plt.ylabel('Prob2D', fontsize=fontsiz)
                    plt.plot(d2Dfulldata, prob2Dfulldata, 'c.', label='7mcs')
                    plt.plot(d2D, prob2D, 'ko', label='mean')
                    plt.plot(xgg, Gauss(xgg, *popt), linewidth=1.5, color='red', label='fit-g')
                    plt.xlabel('distance (um)', fontsize=fontsiz)
                    plt.xlim(0, 300)
                    # ~ plt.ylim(ylim)
                    plt.grid(False)
                    plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.0))
                    # plt.ion()
                    plt.tight_layout()

                    plt.savefig(rootFolder+'Figures/allGauss/prob_dist2D_%s.png' % proj, facecolor = 'white' , dpi=300)

                    plt.close(fig)
# Out:
# /home/fernando/anaconda3/envs/p3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
for n in range(1,11):
    for m in range(1,13):
        proj = '%s:%s' % (mtype_map[n],mtype_map[m])
        if proj in Netinfo.keys() and Netinfo[proj]['singlegauss_d_init'] != '0':
            print(proj,'\n',Netinfo[proj],'\n')
# Out:
# L1_DAC:L23_NGC
#  {'conn_total': '11.7', 'conn_prob_full': '0.00359', 'A0': '0.06740', 'shape': '47.96', 'd_init': '100', 'd_final': '350', 'conn_prob_12.5um': '0.03983', 'conn_prob_25um': '0.02231', 'conn_prob_50um': '0.00894', 'conn_prob_75um': '0.00747', 'conn_prob_100um': '0.00871', 'conn_prob_125um': '0.00486', 'conn_prob_150um': '0.00165', 'conn_prob_175um': '0.00147', 'conn_prob_200um': '0.00234', 'conn_prob_225um': '0.00158', 'conn_prob_250um': '0.00050', 'conn_prob_275um': '0.00032', 'conn_prob_300um': '0.00041', 'conn_prob_325um': '0.00054', 'conn_prob_350um': '0.00079', 'conn_prob_375um': '0.00000', 'singleexp_A0': '0.05313', 'singleexp_shape': '34.64', 'singleexp_d_init': '0', 'singlegauss_A0g': '0.00893', 'singlegauss_x0g': '47.22', 'singlegauss_shapeg': '73.26', 'singlegauss_d_init': '50'}
#
# L23_PC:L23_DBC
#  {'conn_total': '2082.4', 'conn_prob_full': '0.00203', 'A0': '0.03968', 'shape': '36.83', 'd_init': '0', 'd_final': '375', 'conn_prob_12.5um': '0.02896', 'conn_prob_25um': '0.01891', 'conn_prob_50um': '0.01045', 'conn_prob_75um': '0.00523', 'conn_prob_100um': '0.00291', 'conn_prob_125um': '0.00182', 'conn_prob_150um': '0.00105', 'conn_prob_175um': '0.00058', 'conn_prob_200um': '0.00038', 'conn_prob_225um': '0.00024', 'conn_prob_250um': '0.00015', 'conn_prob_275um': '0.00011', 'conn_prob_300um': '0.00008', 'conn_prob_325um': '0.00006', 'conn_prob_350um': '0.00004', 'conn_prob_375um': '0.00004', 'singleexp_A0': '0.03968', 'singleexp_shape': '36.83', 'singleexp_d_init': '0', 'singlegauss_A0g': '0.00000', 'singlegauss_x0g': '0.00', 'singlegauss_shapeg': '1.00', 'singlegauss_d_init': '375'}
#
# L23_PC:L23_BP
#  {'conn_total': '117.6', 'conn_prob_full': '0.00072', 'A0': '0.01171', 'shape': '41.32', 'd_init': '0', 'd_final': '375', 'conn_prob_12.5um': '0.00893', 'conn_prob_25um': '0.00597', 'conn_prob_50um': '0.00353', 'conn_prob_75um': '0.00188', 'conn_prob_100um': '0.00112', 'conn_prob_125um': '0.00074', 'conn_prob_150um': '0.00049', 'conn_prob_175um': '0.00032', 'conn_prob_200um': '0.00018', 'conn_prob_225um': '0.00012', 'conn_prob_250um': '0.00006', 'conn_prob_275um': '0.00004', 'conn_prob_300um': '0.00002', 'conn_prob_325um': '0.00003', 'conn_prob_350um': '0.00002', 'conn_prob_375um': '0.00003', 'singleexp_A0': '0.01171', 'singleexp_shape': '41.32', 'singleexp_d_init': '0', 'singlegauss_A0g': '0.07389', 'singlegauss_x0g': '-423.33', 'singlegauss_shapeg': '180.82', 'singlegauss_d_init': '100'}
#
# L23_DBC:L23_BP
#  {'conn_total': '6.0', 'conn_prob_full': '0.00122', 'A0': '0.06246', 'shape': '20.31', 'd_init': '0', 'd_final': '200', 'conn_prob_12.5um': '0.03427', 'conn_prob_25um': '0.01693', 'conn_prob_50um': '0.00615', 'conn_prob_75um': '0.00256', 'conn_prob_100um': '0.00106', 'conn_prob_125um': '0.00072', 'conn_prob_150um': '0.00049', 'conn_prob_175um': '0.00017', 'conn_prob_200um': '0.00017', 'conn_prob_225um': '0.00000', 'conn_prob_250um': '0.00000', 'conn_prob_275um': '0.00000', 'conn_prob_300um': '0.00000', 'conn_prob_325um': '0.00000', 'conn_prob_350um': '0.00000', 'conn_prob_375um': '0.00000', 'singleexp_A0': '0.06246', 'singleexp_shape': '20.31', 'singleexp_d_init': '0', 'singlegauss_A0g': '0.00161', 'singlegauss_x0g': '33.21', 'singlegauss_shapeg': '72.89', 'singlegauss_d_init': '100'}

# %%
Netinfo[proj]
# Out:
# {'conn_total': '32.0',
#  'conn_prob_full': '0.00329',
#  'A0': '0.11918',
#  'shape': '26.01',
#  'd_init': '0',
#  'd_final': '200',
#  'conn_prob_12.5um': '0.07526',
#  'conn_prob_25um': '0.04192',
#  'conn_prob_50um': '0.01992',
#  'conn_prob_75um': '0.00789',
#  'conn_prob_100um': '0.00236',
#  'conn_prob_125um': '0.00067',
#  'conn_prob_150um': '0.00046',
#  'conn_prob_175um': '0.00045',
#  'conn_prob_200um': '0.00008',
#  'conn_prob_225um': '0.00000',
#  'conn_prob_250um': '0.00000',
#  'conn_prob_275um': '0.00000',
#  'conn_prob_300um': '0.00000',
#  'conn_prob_325um': '0.00000',
#  'conn_prob_350um': '0.00000',
#  'conn_prob_375um': '0.00000',
#  'singleexp_A0': '0.11918',
#  'singleexp_shape': '26.01',
#  'singleexp_d_init': '0',
#  'singlegauss_A0g': '0.12317',
#  'singlegauss_x0g': '-58.38',
#  'singlegauss_shapeg': '56.79',
#  'singlegauss_d_init': '0'}

# %%
# print(Netinfo)
# with open(rootFolder+'Netconnections_mean_single_gauss.json', 'w') as outfile:
#     json.dump(Netinfo, outfile)

# %%
Netinfo['L6_ChC:L6_UTPC']
# Out:
# {'conn_total': '52.1',
#  'conn_prob_full': '0.00188',
#  'A0': '0.01062',
#  'shape': '86.20',
#  'd_init': '0',
#  'd_final': '375',
#  'conn_prob_12.5um': '0.00969',
#  'conn_prob_25um': '0.00756',
#  'conn_prob_50um': '0.00566',
#  'conn_prob_75um': '0.00422',
#  'conn_prob_100um': '0.00316',
#  'conn_prob_125um': '0.00275',
#  'conn_prob_150um': '0.00241',
#  'conn_prob_175um': '0.00161',
#  'conn_prob_200um': '0.00110',
#  'conn_prob_225um': '0.00069',
#  'conn_prob_250um': '0.00037',
#  'conn_prob_275um': '0.00044',
#  'conn_prob_300um': '0.00029',
#  'conn_prob_325um': '0.00006',
#  'conn_prob_350um': '0.00016',
#  'conn_prob_375um': '0.00024',
#  'singleexp_A0': '0.01062',
#  'singleexp_shape': '86.20',
#  'singleexp_d_init': '0',
#  'singlegauss_A0g': '4.11195',
#  'singlegauss_x0g': '-1217.17',
#  'singlegauss_shapeg': '349.50',
#  'singlegauss_d_init': '0'}

# %%
for n in range(1,56):
    for m in range(1,56):
        
        pre = mtype_map[n]
        post = mtype_map[m]
        proj = '%s:%s' % (mtype_map[n],mtype_map[m])
        
        if pre in mtype_map[n]:                

            prob2D = []
            d2D = []
            prob2Dfulldata = []
            d2Dfulldata = []
            expfit = 0
            nn = 0    
            m0 = 0      
            m1 = 0      
            m2 = 0
            m3 = 0    
            m4 = 0
            m5 = 0    
            m6 = 0
            m7 = 0    
            m8 = 0
            m9 = 0   
            m10 = 0
            m11 = 0    
            m12 = 0
            m13 = 0   
            m14 = 0   
            pmat = 0   
            pmat0 = 0   
            mm = 0   
            for mc in range(7):
                pre = mtype_map[n]
                post = mtype_map[m]
                proj = '%s:%s' % (mtype_map[n],mtype_map[m])
                mcName = 'BBP_S1_mc' + str(mc)

                if proj in data[mcName]['connProb']:

                    pmat = pmat + float(data[mcName]['connProb'][proj]['connection_probability_full'])
                    nn =  nn + int(data[mcName]['connProb'][proj]['connections_total'])
                    pmat0 = pmat0 + float(data[mcName]['connProb'][proj]['connection_probability_less_25um'])

                    m0 = m0 + float(data[mcName]['connProb'][proj]['connection_probability_25um'])
                    m1 = m1 + float(data[mcName]['connProb'][proj]['connection_probability_50um'])
                    m2 = m2 + float(data[mcName]['connProb'][proj]['connection_probability_75um']) 
                    m3 = m3 + float(data[mcName]['connProb'][proj]['connection_probability_100um'])
                    m4 = m4 + float(data[mcName]['connProb'][proj]['connection_probability_125um'])
                    m5 = m5 + float(data[mcName]['connProb'][proj]['connection_probability_150um'])
                    m6 = m6 + float(data[mcName]['connProb'][proj]['connection_probability_175um'])
                    m7 = m7 + float(data[mcName]['connProb'][proj]['connection_probability_200um'])
                    m8 = m8 + float(data[mcName]['connProb'][proj]['connection_probability_225um'])
                    m9 = m9 + float(data[mcName]['connProb'][proj]['connection_probability_250um'])
                    m10 = m10 + float(data[mcName]['connProb'][proj]['connection_probability_275um'])
                    m11 = m11 + float(data[mcName]['connProb'][proj]['connection_probability_300um'])
                    m12 = m12 + float(data[mcName]['connProb'][proj]['connection_probability_325um'])
                    m13 = m13 + float(data[mcName]['connProb'][proj]['connection_probability_350um'])
                    m14 = m14 + float(data[mcName]['connProb'][proj]['connection_probability_375um'])

                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_less_25um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_25um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_50um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_75um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_100um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_125um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_150um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_175um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_200um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_225um']))      
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_250um']))   
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_275um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_300um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_325um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_350um']))    
                    prob2Dfulldata.append(float(data[mcName]['connProb'][proj]['connection_probability_375um']))   

                    d2Dfulldata.append(12.5)
                    d2Dfulldata.append(25)
                    d2Dfulldata.append(50) 
                    d2Dfulldata.append(75)     
                    d2Dfulldata.append(100)
                    d2Dfulldata.append(125)
                    d2Dfulldata.append(150)
                    d2Dfulldata.append(175)    
                    d2Dfulldata.append(200)      
                    d2Dfulldata.append(225)  
                    d2Dfulldata.append(250)
                    d2Dfulldata.append(275)
                    d2Dfulldata.append(300)
                    d2Dfulldata.append(325)    
                    d2Dfulldata.append(350)      
                    d2Dfulldata.append(375)

                    mm = mm + 1

            if mm == 7:
                prob2D.append(pmat0/mm)   
                prob2D.append(m0/mm)       
                prob2D.append(m1/mm)      
                prob2D.append(m2/mm)      
                prob2D.append(m3/mm)      
                prob2D.append(m4/mm)      
                prob2D.append(m5/mm)       
                prob2D.append(m6/mm)      
                prob2D.append(m7/mm)      
                prob2D.append(m8/mm)          
                prob2D.append(m9/mm)      
                prob2D.append(m10/mm)      
                prob2D.append(m11/mm)       
                prob2D.append(m12/mm)      
                prob2D.append(m13/mm)      
                prob2D.append(m14/mm)    

                d2D.append(12.5)
                d2D.append(25)
                d2D.append(50) 
                d2D.append(75)     
                d2D.append(100)
                d2D.append(125)
                d2D.append(150)
                d2D.append(175)    
                d2D.append(200)      
                d2D.append(225)
                d2D.append(250)
                d2D.append(275)
                d2D.append(300)
                d2D.append(325)    
                d2D.append(350)      
                d2D.append(375)
                
                
                conn_total = float(Netinfo[proj]['conn_total'])                           #           = '%.1f' % (nn/mm) 
                conn_prob_full = float(Netinfo[proj]['conn_prob_full'] )                  #           = '%.5f' % (pmat/mm) 
                A0 = float(Netinfo[proj]['A0'] )                                          #           = '%.5f' % pars[0]
                shape = float(Netinfo[proj]['shape'])                                     #           = '%.2f' % (1.0/pars[1])          
                d_init = float(Netinfo[proj]['d_init'])                                   #           = '%d' % x[0] 
                d_final = float(Netinfo[proj]['d_final'])                                 #           = '%d' % x[-1]
                singleexp_A0 = float(Netinfo[proj]['singleexp_A0'])                       #           = '%.5f' % pars[0]
                singleexp_shape = float(Netinfo[proj]['singleexp_shape'])                 #           = '%.2f' % (1.0/pars[1])                
                singleexp_d_init = float(Netinfo[proj]['singleexp_d_init'])               #           = '%d' % x[0]                 
                singlegauss_A0g = float(Netinfo[proj]['singlegauss_A0g']  )               #           = '%.5f' % popt[0]
                singlegauss_x0g = float(Netinfo[proj]['singlegauss_x0g']    )             #           = '%.2f' % popt[1]
                singlegauss_shapeg = float(Netinfo[proj]['singlegauss_shapeg'])           #           = '%.2f' % popt[2]
                singlegauss_d_init = float(Netinfo[proj]['singlegauss_d_init'] )          #           = '%d' % xg0 

                if d_final > 370:
                    endsexp = 400
                else:
                    endsexp = d_final
                    
                # ------------------  fit exp + linear saturation ------------------ #
                x = []
                y = []
                for starts,starts2 in enumerate(d2D):
                    if d2D[starts] >= d_init and d2D[starts] <= d_final:      
                        x.append(d2D[starts])
                        y.append(prob2D[starts])
                        
                pars[0] = A0
                pars[1] = 1.0/shape
                
                if x[0] == 12.5:
                    xx = np.linspace(0, endsexp, 50)
                    yy = exponential(xx, *pars)
                    xi = -1
                    yi = 0
                elif x[0] == 25:
                    xx = np.linspace(25, endsexp, 50)
                    yy = exponential(xx, *pars)
                    xi = [0, 25]
                    yi = [prob2D[0], prob2D[0]] 
                else:
                    xx = np.linspace(x[0], endsexp, 50)
                    yy = exponential(xx, *pars)                    
                    y1 = prob2D[1]
                    x1 = 25
                    y2 = y[0]
                    x2 = x[0] 
                    a = (y2 - y1)/(x2 - x1)
                    b = y2 - x2*a    
                    xi = np.linspace(0, x[0], 11)
                    yi = linear(xi,a, b)

                
                # ------------------  fit exp + saturation by hand in [0:25] ------------------ #
                pars[0] = singleexp_A0
                pars[1] = 1.0/singleexp_shape
                
                if prob2D[0] > prob2D[1]: 
                    xx2 = np.linspace(0, endsexp, 50)
                    yy2 = exponential(xx2, *pars)
                    xi2 = -1
                    yi2 = 0
                else: 
                    xx2 = np.linspace(25, endsexp, 50)
                    yy2 = exponential(xx2, *pars)
                    xi2 = [0, 25]
                    yi2 = [prob2D[0], prob2D[0]] 
                    
                # ------------------  fit exp + saturation by hand in [0:25] ------------------ #                    
                popt[0] = singlegauss_A0g
                popt[1] = singlegauss_x0g
                popt[2] = singlegauss_shapeg 
                xgg = np.linspace(0, endsexp, 50)
                
                # ----------------------------------------------------------------------------- #       
                
                exp = netNetpyne['exp']['mean'][proj]
                expl = netNetpyne['expl']['mean'][proj]
                gauss = netNetpyne['gauss']['mean'][proj]

                dexp = conn_total - netNetpyne['exp']['mean'][proj]
                dexpl = conn_total - netNetpyne['expl']['mean'][proj]
                dgauss = conn_total - netNetpyne['gauss']['mean'][proj]
                
                pexp = 100.0*(conn_total - netNetpyne['exp']['mean'][proj])/conn_total
                pexpl = 100.0*(conn_total - netNetpyne['expl']['mean'][proj])/conn_total
                pgauss = 100.0*(conn_total - netNetpyne['gauss']['mean'][proj])/conn_total
                     
                if d_init == 0:
                    if abs(dexpl) <= abs(dgauss):                       
                        Netinfo[proj]['best_fit'] = 'exp'
                        connMean['BBP']['exp'].append(conn_total)
                        connMean['NetPyNE']['exp'].append(exp)
#                         print('%.2f %.2f' % (conn_total,exp))
                        if pre in Epops and post in Epops:     
                            connMean['BBP']['EE'].append(conn_total)
                            connMean['NetPyNE']['EE'].append(exp) 
                        elif pre in Epops and post not in Epops:     
                            connMean['BBP']['EI'].append(conn_total)
                            connMean['NetPyNE']['EI'].append(exp) 
                        elif pre not in Epops and post not in Epops:     
                            connMean['BBP']['II'].append(conn_total)
                            connMean['NetPyNE']['II'].append(exp) 
                        else:     
                            connMean['BBP']['IE'].append(conn_total)
                            connMean['NetPyNE']['IE'].append(exp) 

                    else:             
                        Netinfo[proj]['best_fit'] = 'gauss'   
                        connMean['BBP']['gauss'].append(conn_total)
                        connMean['NetPyNE']['gauss'].append(gauss) 
#                         print('%.2f %.2f' % (conn_total,gauss))
                        if pre in Epops and post in Epops:     
                            connMean['BBP']['EE'].append(conn_total)
                            connMean['NetPyNE']['EE'].append(gauss) 
                        elif pre in Epops and post not in Epops:     
                            connMean['BBP']['EI'].append(conn_total)
                            connMean['NetPyNE']['EI'].append(gauss) 
                        elif pre not in Epops and post not in Epops:     
                            connMean['BBP']['II'].append(conn_total)
                            connMean['NetPyNE']['II'].append(gauss) 
                        else:     
                            connMean['BBP']['IE'].append(conn_total)
                            connMean['NetPyNE']['IE'].append(gauss) 
                        
                         
                        
                else:
                    if abs(dgauss) <= abs(dexp) and abs(dgauss) <= abs(dexp):                     
                        Netinfo[proj]['best_fit'] = 'gauss'  
                        connMean['BBP']['gauss'].append(conn_total)
                        connMean['NetPyNE']['gauss'].append(gauss)    
#                         print('%.2f %.2f' % (conn_total,gauss))    
                        if pre in Epops and post in Epops:     
                            connMean['BBP']['EE'].append(conn_total)
                            connMean['NetPyNE']['EE'].append(gauss) 
                        elif pre in Epops and post not in Epops:     
                            connMean['BBP']['EI'].append(conn_total)
                            connMean['NetPyNE']['EI'].append(gauss) 
                        elif pre not in Epops and post not in Epops:     
                            connMean['BBP']['II'].append(conn_total)
                            connMean['NetPyNE']['II'].append(gauss) 
                        else:     
                            connMean['BBP']['IE'].append(conn_total)
                            connMean['NetPyNE']['IE'].append(gauss)    
                    else:
                        if abs(dexpl) <= abs(dexp):              
                            Netinfo[proj]['best_fit'] = 'expl' 
                            connMean['BBP']['exp'].append(conn_total)
                            connMean['NetPyNE']['exp'].append(expl)
#                             print('%.2f %.2f' % (conn_total,expl))
                            if pre in Epops and post in Epops:     
                                connMean['BBP']['EE'].append(conn_total)
                                connMean['NetPyNE']['EE'].append(expl) 
                            elif pre in Epops and post not in Epops:     
                                connMean['BBP']['EI'].append(conn_total)
                                connMean['NetPyNE']['EI'].append(expl) 
                            elif pre not in Epops and post not in Epops:     
                                connMean['BBP']['II'].append(conn_total)
                                connMean['NetPyNE']['II'].append(expl) 
                            else:     
                                connMean['BBP']['IE'].append(conn_total)
                                connMean['NetPyNE']['IE'].append(expl) 
                        else:                   
                            Netinfo[proj]['best_fit'] = 'exp'
                            connMean['BBP']['exp'].append(conn_total)
                            connMean['NetPyNE']['exp'].append(exp)
#                             print('%.2f %.2f' % (conn_total,exp))
                            if pre in Epops and post in Epops:     
                                connMean['BBP']['EE'].append(conn_total)
                                connMean['NetPyNE']['EE'].append(exp) 
                            elif pre in Epops and post not in Epops:     
                                connMean['BBP']['EI'].append(conn_total)
                                connMean['NetPyNE']['EI'].append(exp) 
                            elif pre not in Epops and post not in Epops:     
                                connMean['BBP']['II'].append(conn_total)
                                connMean['NetPyNE']['II'].append(exp) 
                            else:     
                                connMean['BBP']['IE'].append(conn_total)
                                connMean['NetPyNE']['IE'].append(exp) 
                
#                 fontsiz=15
#                 figSize = (6,4.5)
#                 fig = plt.figure(figsize=figSize)  # Open a new figure    
#                 xgg = np.linspace(0, endsexp, 50)
#                 plt.subplot(1, 1, 1)
#                 plt.ylabel('Prob2D', fontsize=fontsiz)
#                 plt.plot(d2Dfulldata, prob2Dfulldata, 'c.', label='7mcs')
#                 plt.plot(d2D, prob2D,'gD', markersize=8, label='mean')
#                 fig.suptitle('%s -> %s conns\n Expoen (%s, %s, %d<d<%d) -> %.1f conns \n Expoen (%s, %s, %d<d<%d) -> %.1f conns \n Gaussian (%s, %s, %s, 0<d<%d) -> %.1f conns' % 
#                              (proj,conn_total,A0,shape,d_init,d_final,netNetpyne['expl']['mean'][proj],singleexp_A0,singleexp_shape,singleexp_d_init,d_final,
#                               netNetpyne['exp']['mean'][proj],popt[0],popt[1],popt[2],d_final,netNetpyne['gauss']['mean'][proj]), fontsize=12)
                                       
#                 if d_init == 0:
#                     plt.plot(xx, yy, linewidth=2.0, color='red', label='fit-e')                        
#                     plt.plot(xgg, Gauss(xgg, *popt), linewidth=2.0, linestyle='dashed', color='black', label='fit-g')        
#                     plt.xlabel('distance (um)', fontsize=fontsiz)
#                     plt.xlim(0, 400)
#                     maxxy = max(max(prob2D), max(yy), max(yy2), max(Gauss(xgg, *popt)))
#                     plt.ylim(-0.1*maxxy, (maxxy+0.1*maxxy))
#                     plt.grid(False)
#                     plt.legend(loc='upper right', bbox_to_anchor=(0.99, 1.0))

#                     plt.tight_layout()

#                     if abs(dexpl) <= abs(dgauss):
#                         plt.savefig(rootFolder+'Figures/16Sep2021/exp/prob_dist2D_%s.png' % proj, facecolor = 'white' , dpi=300)                        
#                         Netinfo[proj]['best_fit'] = 'exp'
#                     else:
#                         plt.savefig(rootFolder+'Figures/16Sep2021/gauss/prob_dist2D_%s.png' % proj, facecolor = 'white' , dpi=300)                
#                         Netinfo[proj]['best_fit'] = 'gauss'                             
                        
#                 else:
#                     if abs(dexpl) <= abs(dexp):
#                         plt.plot(xx, yy, linewidth=2.0, color='red', label='fit-e')
#                         plt.plot(xi, yi, linewidth=2.0, color='red') 
#                     else:
#                         plt.plot(xx2, yy2, linewidth=2.0, color='red', label='fit-e') 
#                         plt.plot(xi2, yi2, linewidth=2.0, color='red')

#                     plt.plot(xgg, Gauss(xgg, *popt), linewidth=2.0, linestyle='dashed', color='black', label='fit-g')
#                     plt.xlabel('distance (um)', fontsize=fontsiz)
#                     plt.xlim(0, 400)
#                     maxxy = max(max(prob2D), max(yy), max(yy2), max(Gauss(xgg, *popt)))
#                     plt.ylim(-0.1*maxxy, (maxxy+0.1*maxxy))
#                     plt.grid(False)
#                     plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))

#                     plt.tight_layout()
                                  
#                     if abs(dgauss) <= abs(dexp) and abs(dgauss) <= abs(dexp):    

#                         plt.savefig(rootFolder+'Figures/16Sep2021/gauss/prob_dist2D_%s.png' % proj, facecolor = 'white' , dpi=300)                   
#                         Netinfo[proj]['best_fit'] = 'gauss'                              
#                     else:
#                         if abs(dexpl) <= abs(dexp):
#                             plt.savefig(rootFolder+'Figures/16Sep2021/expl/prob_dist2D_%s.png' % proj, facecolor = 'white' , dpi=300)                  
#                             Netinfo[proj]['best_fit'] = 'expl' 
#                         else:
#                             plt.savefig(rootFolder+'Figures/16Sep2021/exp/prob_dist2D_%s.png' % proj, facecolor = 'white' , dpi=300)                       
#                             Netinfo[proj]['best_fit'] = 'exp'
#                 plt.close(fig)

# %%
# with open(rootFolder+'Netconnections_mean_final.json', 'w') as outfile:
#     json.dump(Netinfo, outfile, indent=4)

# %%
with open('Netconnections_Netpyne_final.json', 'r') as f:
    netNetpyne = json.load(f) 
    
connMean = {}    
connMean['BBP'] = {}
connMean['NetPyNE'] = {}
connMean['BBP']['gauss'] = []
connMean['BBP']['exp'] = []
connMean['NetPyNE']['gauss'] = []
connMean['NetPyNE']['exp'] = []

connMean['BBP']['EE'] = []
connMean['BBP']['EI'] = []
connMean['BBP']['IE'] = []
connMean['BBP']['II'] = []
connMean['NetPyNE']['EE'] = []
connMean['NetPyNE']['EI'] = []
connMean['NetPyNE']['IE'] = []
connMean['NetPyNE']['II'] = []

# %%
print(np.size(connMean['NetPyNE']['gauss']) + np.size(connMean['NetPyNE']['exp']))
print(np.size(connMean['BBP']['gauss']) + np.size(connMean['BBP']['exp']))
print(np.size(connMean['BBP']['EE']) + np.size(connMean['BBP']['EI']) + np.size(connMean['BBP']['II']) + np.size(connMean['BBP']['IE']))
print(np.size(connMean['NetPyNE']['EE']) + np.size(connMean['NetPyNE']['EI']) + np.size(connMean['NetPyNE']['II']) + np.size(connMean['NetPyNE']['IE']))
# Out:
# 1941
# 1941
# 1941
# 1941

# %%
fontsiz=24
figSize = (18,6)
fig = plt.figure(figsize=figSize)  # Open a new figure    
plt.subplot(1, 3, 1)
plt.ylabel('BBP', fontsize=fontsiz)            
plt.xlabel('Netpyne', fontsize=fontsiz)
plt.plot(connMean['NetPyNE']['exp'], connMean['BBP']['exp'], 'rs', markersize=4, label='fit-e')
plt.plot(connMean['NetPyNE']['gauss'], connMean['BBP']['gauss'],'ko', markersize=7, label='fit-g')    
plt.plot(connMean['NetPyNE']['exp'], connMean['BBP']['exp'], 'rs', markersize=4)
plt.xticks([0,100000,200000,300000], fontsize=18)
plt.yticks([0,100000,200000,300000], fontsize=18)
plt.loglog()
plt.xlim(0.75, 1300000)
plt.ylim(0.75, 1300000)
plt.grid(True)
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 0.21), fontsize=18)

plt.subplot(1, 3, 2)
plt.ylabel('conn #', fontsize=fontsiz)            
plt.xlabel('projection type', fontsize=fontsiz)
X = np.arange(2)
plt.bar(X + 0.00, data[0], color = 'b', width = 0.35, label='BBP')
plt.bar(X + 0.35, data[1], color = 'r', width = 0.35, label='NetPyNE')
plt.xticks([0,1],['EI','EI'], fontsize=18)
plt.yticks([0,500,1000,1500], fontsize=18)
# plt.loglog()
# plt.xlim(0.75, 1300000)
# plt.ylim(0.75, 1300000)

plt.subplot(1, 3, 3)
plt.ylabel('conn #', fontsize=fontsiz)            
plt.xlabel('projection type', fontsize=fontsiz)
X = np.arange(3)
plt.bar(X + 0.00, data2[0], color = 'b', width = 0.35, label='BBP')
plt.bar(X + 0.35, data2[1], color = 'r', width = 0.35, label='NetPyNE')
plt.xticks([0,1,2],['EI','EI','EI'], fontsize=18)
plt.yticks([0,500,1000,1500], fontsize=18)
# plt.loglog()
# plt.xlim(0.75, 1300000)
# plt.ylim(0.75, 1300000)
plt.grid(False)
plt.grid(False)
# plt.legend(loc='upper right', bbox_to_anchor=(1.0, 0.81), fontsize=18)
plt.tight_layout()
# plt.close(fig)

# %%
np.mean(connMean['NetPyNE']['EE'])
# Out:
# 40343.508030431105

# %%
data2 = [[np.mean(connMean['BBP']['EI']), np.mean(connMean['BBP']['IE']), np.mean(connMean['BBP']['II'])],
[np.mean(connMean['NetPyNE']['EI']), np.mean(connMean['NetPyNE']['IE']), np.mean(connMean['NetPyNE']['II'])]]
X = np.arange(3)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, data2[0], color = 'b', width = 0.35)
ax.bar(X + 0.35, data2[1], color = 'r', width = 0.35)
# Out:
# <BarContainer object of 3 artists>

# %%
data = [[np.mean(connMean['BBP']['EE'])+np.mean(connMean['BBP']['EI'])+np.mean(connMean['BBP']['IE'])+np.mean(connMean['BBP']['II']),np.mean(connMean['BBP']['EE'])],
[np.mean(connMean['NetPyNE']['EE'])+ np.mean(connMean['NetPyNE']['EI'])+ np.mean(connMean['NetPyNE']['IE'])+np.mean(connMean['NetPyNE']['II']) ,np.mean(connMean['NetPyNE']['EE'])]]
X = np.arange(2)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, data[0], color = 'b', width = 0.35)
ax.bar(X + 0.35, data[1], color = 'r', width = 0.35)
# Out:
# <BarContainer object of 2 artists>
