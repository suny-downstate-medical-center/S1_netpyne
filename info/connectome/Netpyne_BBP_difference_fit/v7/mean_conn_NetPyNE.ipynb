# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle, json

## load data from conn pre-processing file
with open('../../../../sim/conn/conn.pkl', 'rb') as fileObj: connData = pickle.load(fileObj)

pmatfull = connData['pmat']
lmat = connData['lmat']
a0mat = connData['a0mat']
d0 = connData['d0']
connNumber = connData['connNumber']
synperconnNumber = connData['synperconnNumber']

# %% [markdown]
# # NetPyNE conn data with exp fit + linear saturation

# %%
Matrix_full = {}
Matrix_full_min = {}
Matrix_full_max = {}

errors = {}
errors['expl'] = {}
errors['expl']['abs'] = {}
errors['expl']['pcent'] = {}
errors['expl']['pcent'] = {}
errors['exp'] = {}
errors['exp']['abs'] = {}
errors['exp']['pcent'] = {}
errors['exp']['pcent'] = {}
errors['gauss'] = {}
errors['gauss']['abs'] = {}
errors['gauss']['pcent'] = {}
errors['gauss']['pcent'] = {}

connmatrixNetPyNe = {}
connmatrixNetPyNe['expl'] = {}
connmatrixNetPyNe['expl']['mean'] = {}
connmatrixNetPyNe['expl']['min'] = {}
connmatrixNetPyNe['expl']['max'] = {}
connmatrixNetPyNe['exp'] = {}
connmatrixNetPyNe['exp']['mean'] = {}
connmatrixNetPyNe['exp']['min'] = {}
connmatrixNetPyNe['exp']['max'] = {}
connmatrixNetPyNe['gauss'] = {}
connmatrixNetPyNe['gauss']['mean'] = {}
connmatrixNetPyNe['gauss']['min'] = {}
connmatrixNetPyNe['gauss']['max'] = {}

# %%
## Pre from 0 to 13

data = {}

for gid in range(7):
	data[gid] = {}

	with open('../v6/v6_batch0/v6_batch0_{s}_pop_numConns_matrix.json'.format(s=gid), 'r') as f:
		data[gid] = json.load(f) 
	
	includePre = data[gid]['includePre']

	if gid == 0:
		connMatrix = np.matrix(data[gid]['connMatrix'])
		connMatrixmax = np.matrix(data[gid]['connMatrix'])
		connMatrixmin = np.matrix(data[gid]['connMatrix'])
	else:
		connMatrix = connMatrix + np.matrix(data[gid]['connMatrix'])

		connMatrix0 = np.matrix(data[gid]['connMatrix'])
		for preN in range(14):
			for postN in range(55):
				pre = includePre[preN]
				post = includePre[postN]
				if connMatrix0[preN,postN] > connMatrixmax[preN,postN]:
					connMatrixmax[preN,postN] = connMatrix0[preN,postN]
				if connMatrix0[preN,postN] < connMatrixmin[preN,postN]:
					connMatrixmin[preN,postN] = connMatrix0[preN,postN]

connMatrix = connMatrix/14
connMatrixmin = connMatrixmin/2
connMatrixmax = connMatrixmax/2 

Matrix_full = connMatrix
Matrix_full_min = connMatrixmin
Matrix_full_max = connMatrixmax

## Pre 14 and 15 (L1, L23,  and L4)

data = {}

for gid in range(7):
	data[gid] = {}

	with open('../v6/v6_batch1/v6_batch1_{s}_pop_numConns_matrix.json'.format(s=gid), 'r') as f:
		data[gid] = json.load(f) 
	
	includePre = data[gid]['includePre']

	if gid == 0:
		connMatrix = np.matrix(data[gid]['connMatrix'])
		connMatrixmax = np.matrix(data[gid]['connMatrix'])
		connMatrixmin = np.matrix(data[gid]['connMatrix'])
	else:
		connMatrix = connMatrix + np.matrix(data[gid]['connMatrix'])

		connMatrix0 = np.matrix(data[gid]['connMatrix'])
		for preN in range(14,16):
			for postN in range(55):
				pre = includePre[preN]
				post = includePre[postN]
				if connMatrix0[preN,postN] > connMatrixmax[preN,postN]:
					connMatrixmax[preN,postN] = connMatrix0[preN,postN]
				if connMatrix0[preN,postN] < connMatrixmin[preN,postN]:
					connMatrixmin[preN,postN] = connMatrix0[preN,postN]

connMatrix = connMatrix/14
connMatrixmin = connMatrixmin/2
connMatrixmax = connMatrixmax/2     

Matrix_full = Matrix_full + connMatrix
Matrix_full_min = Matrix_full_min + connMatrixmin
Matrix_full_max = Matrix_full_max + connMatrixmax

## Pre 14 and 15 (L5  and L6)

data = {}

for gid in range(7):
	data[gid] = {}

	with open('../v6/v6_batchb/v6_batchb_{s}_pop_numConns_matrix.json'.format(s=gid), 'r') as f:
		data[gid] = json.load(f) 
	
	includePre = data[gid]['includePre']

	if gid == 0:
		connMatrix = np.matrix(data[gid]['connMatrix'])
		connMatrixmax = np.matrix(data[gid]['connMatrix'])
		connMatrixmin = np.matrix(data[gid]['connMatrix'])
	else:
		connMatrix = connMatrix + np.matrix(data[gid]['connMatrix'])

		connMatrix0 = np.matrix(data[gid]['connMatrix'])
		for preN in range(14,16):
			for postN in range(55):
				pre = includePre[preN]
				post = includePre[postN]
				if connMatrix0[preN,postN] > connMatrixmax[preN,postN]:
					connMatrixmax[preN,postN] = connMatrix0[preN,postN]
				if connMatrix0[preN,postN] < connMatrixmin[preN,postN]:
					connMatrixmin[preN,postN] = connMatrix0[preN,postN]

connMatrix = connMatrix/14
connMatrixmin = connMatrixmin/2
connMatrixmax = connMatrixmax/2     

Matrix_full = Matrix_full + connMatrix
Matrix_full_min = Matrix_full_min + connMatrixmin
Matrix_full_max = Matrix_full_max + connMatrixmax

## pop from 16 to 54

for preN in range(55):
    for postN in range(55):
        connMatrix[preN,postN] = 0
        connMatrixmax[preN,postN] = 0
        connMatrixmin[preN,postN] = 0
        connMatrix0[preN,postN] = 0

data = {}
gid2 = 4321
for gid in range(7):  
    
    data[gid] = {}
    for preN in range(16,55):
        data[gid][preN] = {}
        pre = includePre[preN]
        
        with open('../v6/pop_16_54/Netconnections_Netpyne_{s2}_{s}.json'.format(s2=pre,s=gid2), 'r') as f:
            data[gid][preN] = json.load(f) 
            
        if gid2 == 4321:
            connMatrix[preN] = np.matrix(data[gid][preN]['connMatrix'])
            connMatrixmax[preN] = np.matrix(data[gid][preN]['connMatrix'])
            connMatrixmin[preN] = np.matrix(data[gid][preN]['connMatrix'])
        else:
            connMatrix[preN] = connMatrix[preN] + np.matrix(data[gid][preN]['connMatrix'])

        connMatrix0[preN] = np.matrix(data[gid][preN]['connMatrix'])
        for postN in range(55):
            post = includePre[postN]
            if connMatrix0[preN,postN] > connMatrixmax[preN,postN]:
                connMatrixmax[preN,postN] = connMatrix0[preN,postN]
            if connMatrix0[preN,postN] < connMatrixmin[preN,postN]:
                connMatrixmin[preN,postN] = connMatrix0[preN,postN]                  

    gid2 += 1
    
connMatrix = connMatrix/14
connMatrixmin = connMatrixmin/2
connMatrixmax = connMatrixmax/2     

Matrix_full = Matrix_full + connMatrix
Matrix_full_min = Matrix_full_min + connMatrixmin
Matrix_full_max = Matrix_full_max + connMatrixmax

# %%
## Full
number = 0
for preN in range(55):
    for postN in range(55):
        pre = includePre[preN]
        post = includePre[postN]
        proj = '%s:%s' % (pre,post)
        if float(connNumber[pre][post]) > 0:

            connMatrix2 = Matrix_full[preN,postN]/int(synperconnNumber[pre][post]+0.5)
            connMatrix2_min = Matrix_full_min[preN,postN]/int(synperconnNumber[pre][post]+0.5)
            connMatrix2_max = Matrix_full_max[preN,postN]/int(synperconnNumber[pre][post]+0.5)
            
            connmatrixNetPyNe['expl']['mean'][proj] = connMatrix2
            connmatrixNetPyNe['expl']['min'][proj] = connMatrix2_min
            connmatrixNetPyNe['expl']['max'][proj] = connMatrix2_max

            error = 100*(connMatrix2-float(connNumber[pre][post]))/float(connNumber[pre][post])
            error2 = connMatrix2-float(connNumber[pre][post])
            
            errors['expl']['abs'][proj] = error2
            errors['expl']['pcent'][proj] = error
            
            if abs(error) > 50 and abs(error2) > 0:
                print('%d %d %s:%s %.1f %.1f %d %.2f %.2f %.1f %.0f %s' % (preN,postN,includePre[preN],includePre[postN],float(connNumber[pre][post]),connMatrix2,
                                                                           int(synperconnNumber[pre][post]+0.5),Matrix_full_min[preN,postN]/int(synperconnNumber[pre][post]+0.5),Matrix_full_max[preN,postN]/int(synperconnNumber[pre][post]+0.5),
                                                                           error,error2,d0[pre][post]))   
#                 print('*%s:%s*,' % (pre,post))   
                number+=1
                
print('\n----------------\n',number,'bad fits\n----------------\n')
# Out:
# 9 3 L23_DBC:L1_NGC-DA 10.6 17.6 9 13.00 21.00 65.8 7 100
# 9 42 L23_DBC:L6_BP 2.6 4.3 2 1.00 8.00 64.8 2 50
# 10 6 L23_LBC:L23_BP 14.9 22.9 7 19.00 27.00 53.4 8 125
# 16 12 L4_BP:L23_NBC 7.4 11.6 8 8.00 14.00 56.4 4 125
# 21 48 L4_MC:L6_MC 8.6 14.7 5 9.00 22.00 71.1 6 150
# 25 18 L4_SBC:L4_ChC 6.1 9.4 18 6.00 13.00 54.6 3 125
# 28 29 L5_BP:L5_BTC 4.3 9.0 13 7.00 11.00 109.3 5 125
# 28 32 L5_BP:L5_LBC 12.1 21.3 14 16.00 24.00 75.9 9 125
# 29 45 L5_BTC:L6_DBC 2.0 3.1 5 2.00 4.00 57.1 1 125
# 33 16 L5_MC:L4_BP 3.9 6.6 3 2.00 10.00 68.5 3 125
# 39 2 L5_TTPC2:L1_HAC 5.4 9.7 5 4.00 16.00 79.9 4 150
# 39 4 L5_TTPC2:L1_NGC-SA 3.9 6.6 3 5.00 10.00 68.5 3 150
# 39 5 L5_TTPC2:L1_SLAC 3.1 4.9 3 2.00 9.00 56.7 2 175
# 41 8 L6_BPC:L23_ChC 3.3 1.6 9 1.00 3.00 -52.4 -2 0
# 42 48 L6_BP:L6_MC 62.3 126.6 9 114.00 148.00 103.2 64 125
# 43 14 L6_BTC:L23_PC 5.3 8.9 2 6.00 12.00 67.1 4 125
# 46 35 L6_IPC:L5_NGC 6.4 10.0 4 7.00 14.00 56.2 4 175
# 47 9 L6_LBC:L23_DBC 8.4 2.9 2 1.00 4.00 -66.0 -6 200
# ...

# %% [markdown]
# # NetPyNE with single exp fit

# %%
Matrix_full = np.zeros((55, 55))
Matrix_full_min = np.zeros((55, 55))
Matrix_full_max = np.zeros((55, 55))

# %%
data = {}
gid2 = 4321
for gid in range(7):  
    data[gid] = {}
    for preN in range(55):
        data[gid][preN] = {}
        pre = includePre[preN]
        
        if preN == 14:            
            data[gid][preN]['connMatrix'] = {}
            data[gid][preN]['connMatrix'][0] = []

            with open('Netconnections_Netpyne_{s2}_{s}_1.json'.format(s2=pre,s=gid2), 'r') as f:
                data_L23_PC_1 = json.load(f)             
            with open('Netconnections_Netpyne_{s2}_{s}_2.json'.format(s2=pre,s=gid2), 'r') as f:
                data_L23_PC_2 = json.load(f)         
            with open('Netconnections_Netpyne_{s2}_{s}_3.json'.format(s2=pre,s=gid2), 'r') as f:
                data_L23_PC_3 = json.load(f)             
            with open('Netconnections_Netpyne_{s2}_{s}_4.json'.format(s2=pre,s=gid2), 'r') as f:
                data_L23_PC_4 = json.load(f)      
            for i in range(14):
                data[gid][preN]['connMatrix'][0].append(data_L23_PC_1['connMatrix'][0][i])         
            data[gid][preN]['connMatrix'][0].append(data_L23_PC_2['connMatrix'][0][14])      
            for i in range(15,35):
                data[gid][preN]['connMatrix'][0].append(data_L23_PC_3['connMatrix'][0][i])   
            for i in range(35,55):
                data[gid][preN]['connMatrix'][0].append(data_L23_PC_4['connMatrix'][0][i])
                
            if gid2 == 4321:
                connMatrix[preN] = np.matrix(data[gid][preN]['connMatrix'][0])
                connMatrixmax[preN] = np.matrix(data[gid][preN]['connMatrix'][0])
                connMatrixmin[preN] = np.matrix(data[gid][preN]['connMatrix'][0])
            else:
                connMatrix[preN] = connMatrix[preN] + np.matrix(data[gid][preN]['connMatrix'][0])

            connMatrix0[preN] = np.matrix(data[gid][preN]['connMatrix'][0])
            for postN in range(55):
                post = includePre[postN]
                if connMatrix0[preN,postN] > connMatrixmax[preN,postN]:
                    connMatrixmax[preN,postN] = connMatrix0[preN,postN]
                if connMatrix0[preN,postN] < connMatrixmin[preN,postN]:
                    connMatrixmin[preN,postN] = connMatrix0[preN,postN]     

        else:      
            with open('Netconnections_Netpyne_{s2}_{s}.json'.format(s2=pre,s=gid2), 'r') as f:
                data[gid][preN] = json.load(f) 
                
            if gid2 == 4321:
                connMatrix[preN] = np.matrix(data[gid][preN]['connMatrix'])
                connMatrixmax[preN] = np.matrix(data[gid][preN]['connMatrix'])
                connMatrixmin[preN] = np.matrix(data[gid][preN]['connMatrix'])
            else:
                connMatrix[preN] = connMatrix[preN] + np.matrix(data[gid][preN]['connMatrix'])

            connMatrix0[preN] = np.matrix(data[gid][preN]['connMatrix'])
            for postN in range(55):
                post = includePre[postN]
                if connMatrix0[preN,postN] > connMatrixmax[preN,postN]:
                    connMatrixmax[preN,postN] = connMatrix0[preN,postN]
                if connMatrix0[preN,postN] < connMatrixmin[preN,postN]:
                    connMatrixmin[preN,postN] = connMatrix0[preN,postN]               
                

    gid2 += 1
    
connMatrix = connMatrix/14
connMatrixmin = connMatrixmin/2
connMatrixmax = connMatrixmax/2     

Matrix_full = Matrix_full + connMatrix
Matrix_full_min = Matrix_full_min + connMatrixmin
Matrix_full_max = Matrix_full_max + connMatrixmax

# %%
connNumberBBP = {}

number = 0
for preN in range(55):
    for postN in range(55):
        pre = includePre[preN]
        post = includePre[postN]
        proj = '%s:%s' % (pre,post)
        if float(connNumber[pre][post]) > 0:

            connMatrix2 = Matrix_full[preN,postN]/int(synperconnNumber[pre][post]+0.5)
            connMatrix2_min = Matrix_full_min[preN,postN]/int(synperconnNumber[pre][post]+0.5)
            connMatrix2_max = Matrix_full_max[preN,postN]/int(synperconnNumber[pre][post]+0.5)
            
            connmatrixNetPyNe['exp']['mean'][proj] = connMatrix2
            connmatrixNetPyNe['exp']['min'][proj] = connMatrix2_min
            connmatrixNetPyNe['exp']['max'][proj] = connMatrix2_max

            error = 100*(connMatrix2-float(connNumber[pre][post]))/float(connNumber[pre][post])
            error2 = connMatrix2-float(connNumber[pre][post])
            
            errors['exp']['abs'][proj] = error2
            errors['exp']['pcent'][proj] = error
            
            connNumberBBP[proj] = float(connNumber[pre][post])
                  
            if abs(error) > 50 and abs(error2) > 0:
                print('%d %d %s:%s %.1f %.1f %d %.2f %.2f %.1f %.0f %s' % (preN,postN,includePre[preN],includePre[postN],float(connNumber[pre][post]),connMatrix2,
                                                                           int(synperconnNumber[pre][post]+0.5),Matrix_full_min[preN,postN]/int(synperconnNumber[pre][post]+0.5),Matrix_full_max[preN,postN]/int(synperconnNumber[pre][post]+0.5),
                                                                           error,error2,d0[pre][post]))   
#                 print('*%s:%s*,' % (includePre[preN],includePre[postN]))   
                number+=1
                
print('\n----------------\n',number,'bad fits\n----------------\n')
# Out:
# 1 40 L1_DLAC:L5_UTPC 2.6 0.4 4 0.00 2.00 -83.5 -2 75
# 15 18 L23_SBC:L4_ChC 3.1 1.1 11 0.00 2.00 -63.1 -2 125
# 21 6 L4_MC:L23_BP 4.0 1.4 3 1.00 3.00 -64.3 -3 100
# 29 45 L5_BTC:L6_DBC 2.0 0.6 5 0.00 2.00 -71.4 -1 125
# 31 28 L5_DBC:L5_BP 4.6 1.3 3 0.00 2.00 -72.0 -3 100
# 34 23 L5_NBC:L4_NGC 3.1 4.7 9 1.00 9.00 52.1 2 125
# 36 25 L5_SBC:L4_SBC 6.1 9.9 12 5.00 16.00 61.6 4 50
# 38 2 L5_TTPC1:L1_HAC 4.6 0.0 5 0.00 0.00 -100.0 -5 175
# 43 14 L6_BTC:L23_PC 5.3 1.6 2 0.00 5.00 -70.4 -4 125
# 43 36 L6_BTC:L5_SBC 5.3 8.0 9 4.00 13.00 50.9 3 0
# 53 13 L6_TPC_L4:L23_NGC 7.4 2.9 4 0.00 6.00 -61.4 -5 75
#
# ----------------
#  11 bad fits
# ----------------

# %% [markdown]
# # NetPyNE with single gaussian fit

# %%
Matrix_full = np.zeros((55, 55))
Matrix_full_min = np.zeros((55, 55))
Matrix_full_max = np.zeros((55, 55))

# %%
data = {}
gid2 = 4321
for gid in range(7):  
    data[gid] = {}
    for preN in range(55):
        data[gid][preN] = {}
        pre = includePre[preN]
        
        if preN == 14:            
            data[gid][preN]['connMatrix'] = {}
            data[gid][preN]['connMatrix'][0] = []

            with open('Netconnections_Netpyne_{s2}_{s}_gauss_1.json'.format(s2=pre,s=gid2), 'r') as f:
                data_L23_PC_1 = json.load(f)             
            with open('Netconnections_Netpyne_{s2}_{s}_gauss_2.json'.format(s2=pre,s=gid2), 'r') as f:
                data_L23_PC_2 = json.load(f)         
            with open('Netconnections_Netpyne_{s2}_{s}_gauss_3.json'.format(s2=pre,s=gid2), 'r') as f:
                data_L23_PC_3 = json.load(f)             
            with open('Netconnections_Netpyne_{s2}_{s}_gauss_4.json'.format(s2=pre,s=gid2), 'r') as f:
                data_L23_PC_4 = json.load(f)      
            for i in range(14):
                data[gid][preN]['connMatrix'][0].append(data_L23_PC_1['connMatrix'][0][i])         
            data[gid][preN]['connMatrix'][0].append(data_L23_PC_2['connMatrix'][0][14])      
            for i in range(15,35):
                data[gid][preN]['connMatrix'][0].append(data_L23_PC_3['connMatrix'][0][i])   
            for i in range(35,55):
                data[gid][preN]['connMatrix'][0].append(data_L23_PC_4['connMatrix'][0][i])
                
            if gid2 == 4321:
                connMatrix[preN] = np.matrix(data[gid][preN]['connMatrix'][0])
                connMatrixmax[preN] = np.matrix(data[gid][preN]['connMatrix'][0])
                connMatrixmin[preN] = np.matrix(data[gid][preN]['connMatrix'][0])
            else:
                connMatrix[preN] = connMatrix[preN] + np.matrix(data[gid][preN]['connMatrix'][0])

            connMatrix0[preN] = np.matrix(data[gid][preN]['connMatrix'][0])
            for postN in range(55):
                post = includePre[postN]
                if connMatrix0[preN,postN] > connMatrixmax[preN,postN]:
                    connMatrixmax[preN,postN] = connMatrix0[preN,postN]
                if connMatrix0[preN,postN] < connMatrixmin[preN,postN]:
                    connMatrixmin[preN,postN] = connMatrix0[preN,postN]     

        else:      
            with open('Netconnections_Netpyne_{s2}_{s}_gauss.json'.format(s2=pre,s=gid2), 'r') as f:
                data[gid][preN] = json.load(f) 
                
            if gid2 == 4321:
                connMatrix[preN] = np.matrix(data[gid][preN]['connMatrix'])
                connMatrixmax[preN] = np.matrix(data[gid][preN]['connMatrix'])
                connMatrixmin[preN] = np.matrix(data[gid][preN]['connMatrix'])
            else:
                connMatrix[preN] = connMatrix[preN] + np.matrix(data[gid][preN]['connMatrix'])

            connMatrix0[preN] = np.matrix(data[gid][preN]['connMatrix'])
            for postN in range(55):
                post = includePre[postN]
                if connMatrix0[preN,postN] > connMatrixmax[preN,postN]:
                    connMatrixmax[preN,postN] = connMatrix0[preN,postN]
                if connMatrix0[preN,postN] < connMatrixmin[preN,postN]:
                    connMatrixmin[preN,postN] = connMatrix0[preN,postN]               
                

    gid2 += 1
    
connMatrix = connMatrix/14
connMatrixmin = connMatrixmin/2
connMatrixmax = connMatrixmax/2     

Matrix_full = Matrix_full + connMatrix
Matrix_full_min = Matrix_full_min + connMatrixmin
Matrix_full_max = Matrix_full_max + connMatrixmax

# %%
connNumberBBP = {}

number = 0
for preN in range(55):
    for postN in range(55):
        pre = includePre[preN]
        post = includePre[postN]
        proj = '%s:%s' % (pre,post)
        if float(connNumber[pre][post]) > 0:

            connMatrix2 = Matrix_full[preN,postN]/int(synperconnNumber[pre][post]+0.5)
            connMatrix2_min = Matrix_full_min[preN,postN]/int(synperconnNumber[pre][post]+0.5)
            connMatrix2_max = Matrix_full_max[preN,postN]/int(synperconnNumber[pre][post]+0.5)
            
            connmatrixNetPyNe['gauss']['mean'][proj] = connMatrix2
            connmatrixNetPyNe['gauss']['min'][proj] = connMatrix2_min
            connmatrixNetPyNe['gauss']['max'][proj] = connMatrix2_max

            error = 100*(connMatrix2-float(connNumber[pre][post]))/float(connNumber[pre][post])
            error2 = connMatrix2-float(connNumber[pre][post])
            
            errors['gauss']['abs'][proj] = error2
            errors['gauss']['pcent'][proj] = error
            
            connNumberBBP[proj] = float(connNumber[pre][post])
                  
            if abs(error) > 50 and abs(error2) > 0:
                print('%d %d %s:%s %.1f %.1f %d %.2f %.2f %.1f %.0f %s' % (preN,postN,includePre[preN],includePre[postN],float(connNumber[pre][post]),connMatrix2,
                                                                           int(synperconnNumber[pre][post]+0.5),Matrix_full_min[preN,postN]/int(synperconnNumber[pre][post]+0.5),Matrix_full_max[preN,postN]/int(synperconnNumber[pre][post]+0.5),
                                                                           error,error2,d0[pre][post]))   
#                 print('*%s:%s*,' % (includePre[preN],includePre[postN]))   
                number+=1
                
print('\n----------------\n',number,'bad fits\n----------------\n')
# Out:
# 7 31 L23_BTC:L5_DBC 28.6 0.0 4 0.00 0.00 -100.0 -29 0
# 9 6 L23_DBC:L23_BP 6.0 2.7 6 2.00 5.00 -54.8 -3 0
# 10 21 L23_LBC:L4_MC 146.4 0.0 12 0.00 0.00 -100.0 -146 0
# 10 32 L23_LBC:L5_LBC 91.7 0.0 7 0.00 0.00 -100.0 -92 0
# 12 23 L23_NBC:L4_NGC 1.9 4.3 8 2.00 8.00 125.6 2 25
# 14 9 L23_PC:L23_DBC 2082.4 0.0 4 0.00 0.00 -100.0 -2082 0
# 21 32 L4_MC:L5_LBC 104.0 0.0 10 0.00 0.00 -100.0 -104 0
# 21 49 L4_MC:L6_NBC 4.1 0.0 7 0.00 0.00 -100.0 -4 25
# 24 18 L4_PC:L4_ChC 298.3 0.0 4 0.00 0.00 -100.0 -298 0
# 24 19 L4_PC:L4_DBC 279.9 0.0 6 0.00 0.00 -100.0 -280 0
# 24 20 L4_PC:L4_LBC 2386.0 0.0 8 0.00 0.00 -100.0 -2386 0
# 24 21 L4_PC:L4_MC 2573.4 0.0 10 0.00 0.00 -100.0 -2573 0
# 24 25 L4_PC:L4_SBC 2232.4 0.0 4 0.00 0.00 -100.0 -2232 0
# 24 28 L4_PC:L5_BP 304.6 0.0 3 0.00 0.00 -100.0 -305 0
# 24 29 L4_PC:L5_BTC 1277.9 0.0 8 0.00 0.00 -100.0 -1278 0
# 24 30 L4_PC:L5_ChC 318.6 0.0 7 0.00 0.00 -100.0 -319 0
# 24 31 L4_PC:L5_DBC 795.1 0.0 5 0.00 0.00 -100.0 -795 0
# ...

# %% [markdown]
# # Resume all 3

# %%
number = 0
numberl = 0
numbere = 0
numberg = 0

print('proj                  abs          pcent')
for proj in errors['expl']['abs'].keys():
    if connNumberBBP[proj] > 0: # and abs(errors['exp']['pcent'][proj]) > 25 and abs(errors['gauss']['pcent'][proj]) > 25:

        if abs(errors['exp']['abs'][proj])<=abs(errors['expl']['abs'][proj]) and abs(errors['exp']['abs'][proj])<=abs(errors['gauss']['abs'][proj]):
#             print('%s        %3.3f        %3.3f   (exp, BBP = %.1f conn)' % (proj,errors['exp']['abs'][proj],errors['exp']['pcent'][proj],connNumberBBP[proj]))
#             print('%s, BBP = %.0f, conn %.1f (linear) %.1f (exp) %.1f (gauss)' % (proj,connNumberBBP[proj],errors['expl']['abs'][proj],errors['exp']['abs'][proj],errors['gauss']['abs'][proj]))
            numbere+=1
         
        elif abs(errors['gauss']['abs'][proj])<=abs(errors['expl']['abs'][proj]) and abs(errors['gauss']['abs'][proj])<=abs(errors['exp']['abs'][proj]):
#             print('%s        %3.3f        %3.3f   (gauss, BBP = %.1f conn)' % (proj,errors['gauss']['abs'][proj],errors['gauss']['pcent'][proj],connNumberBBP[proj]))
#             print('%s, BBP = %.0f, conn %.1f (linear) %.1f (exp) %.1f (gauss)' % (proj,connNumberBBP[proj],errors['expl']['abs'][proj],errors['exp']['abs'][proj],errors['gauss']['abs'][proj]))
            numberg+=1
         
        else:  
#             print('%s        %3.3f        %3.3f   (linear, BBP = %.1f conn)' % (proj,errors['expl']['abs'][proj],errors['expl']['pcent'][proj],connNumberBBP[proj]))
#             print('%s, BBP = %.0f, conn %.1f (linear) %.1f (exp) %.1f (gauss)' % (proj,connNumberBBP[proj],errors['expl']['abs'][proj],errors['exp']['abs'][proj],errors['gauss']['abs'][proj]))
            numberl+=1   
    
            if abs(errors['exp']['pcent'][proj])<=abs(errors['gauss']['pcent'][proj]):
#                 print('%s, BBP = %.0f, conn %.1f (linear) %.1f (exp) %.1f (gauss)' % (proj,connNumberBBP[proj],errors['expl']['pcent'][proj],errors['exp']['pcent'][proj],errors['gauss']['pcent'][proj]))
                numbere+=1
            else:
#                 print('%s, BBP = %.0f, conn %.1f (linear) %.1f (exp) %.1f (gauss)' % (proj,connNumberBBP[proj],errors['expl']['pcent'][proj],errors['exp']['pcent'][proj],errors['gauss']['pcent'][proj]))
                numberg+=1
                
                
        number+=1
print('\n----------------\n',number,'bad fits\n----------------\n','explinearsat',numberl,'  fullexp',numbere,'  fullgauss',numberg)
# Out:
# proj                  abs          pcent
#
# ----------------
#  1941 bad fits
# ----------------
#  explinearsat 588   fullexp 671   fullgauss 1270

# %%
number = 0
numberl = 0
numbere = 0
numberg = 0

print('mean \t [min:\tmax] \t(exp-ls)   \tmean \t[min:\tmax] \t(exp)    \tmean \t[min:\tmax] \t(gauss) \t projection ')
for proj in errors['expl']['abs'].keys():
    if connNumberBBP[proj] > 0 and errors['exp']['pcent'][proj]>20 and errors['gauss']['pcent'][proj]>20:
        print('%.0f \t [%.0f:\t%.0f] \t(exp-ls) \t%.0f \t [%.0f:\t%.0f] \t(exp) \t\t%.0f \t [%.0f:\t%.0f] \t(gauss) \t %s' % (connmatrixNetPyNe['expl']['mean'][proj],connmatrixNetPyNe['expl']['min'][proj],connmatrixNetPyNe['expl']['max'][proj],connmatrixNetPyNe['exp']['mean'][proj],connmatrixNetPyNe['exp']['min'][proj],connmatrixNetPyNe['exp']['max'][proj],connmatrixNetPyNe['gauss']['mean'][proj],connmatrixNetPyNe['gauss']['min'][proj],connmatrixNetPyNe['gauss']['max'][proj],proj))
# Out:
# mean 	 [min:	max] 	(exp-ls)   	mean 	[min:	max] 	(exp)    	mean 	[min:	max] 	(gauss) 	 projection
# 3 	 [1:	4] 	(exp-ls) 	4 	 [1:	7] 	(exp) 		4 	 [1:	6] 	(gauss) 	 L1_HAC:L4_DBC
# 9 	 [3:	16] 	(exp-ls) 	9 	 [3:	15] 	(exp) 		9 	 [4:	16] 	(gauss) 	 L1_HAC:L5_UTPC
# 24 	 [18:	29] 	(exp-ls) 	27 	 [18:	36] 	(exp) 		26 	 [17:	36] 	(gauss) 	 L1_NGC-DA:L1_SLAC
# 94 	 [86:	105] 	(exp-ls) 	102 	 [88:	112] 	(exp) 		98 	 [86:	105] 	(gauss) 	 L1_NGC-SA:L23_MC
# 24 	 [15:	34] 	(exp-ls) 	30 	 [24:	35] 	(exp) 		27 	 [20:	32] 	(gauss) 	 L23_BTC:L1_HAC
# 3 	 [1:	5] 	(exp-ls) 	4 	 [2:	6] 	(exp) 		4 	 [2:	6] 	(gauss) 	 L23_BTC:L4_NGC
# 8 	 [5:	10] 	(exp-ls) 	8 	 [7:	10] 	(exp) 		8 	 [6:	12] 	(gauss) 	 L23_NBC:L4_ChC
# 11 	 [5:	18] 	(exp-ls) 	11 	 [8:	18] 	(exp) 		11 	 [8:	17] 	(gauss) 	 L4_BTC:L5_BTC
# 22 	 [18:	24] 	(exp-ls) 	23 	 [14:	30] 	(exp) 		23 	 [13:	32] 	(gauss) 	 L4_DBC:L23_BTC
# 15 	 [13:	17] 	(exp-ls) 	17 	 [11:	23] 	(exp) 		16 	 [12:	19] 	(gauss) 	 L4_LBC:L4_ChC
# ...

# %%
connNumberBBP['errors'] = errors

# %%
connmatrixNetPyNe
# Out:
# {'expl': {'mean': {'L1_DAC:L1_DAC': 33.14285714285714,
#    'L1_DAC:L1_DLAC': 14.142857142857142,
#    'L1_DAC:L1_HAC': 37.0,
#    'L1_DAC:L1_NGC-DA': 24.857142857142858,
#    'L1_DAC:L1_NGC-SA': 25.428571428571427,
#    'L1_DAC:L1_SLAC': 16.42857142857143,
#    'L1_DAC:L23_BP': 2.4285714285714284,
#    'L1_DAC:L23_BTC': 48.57142857142858,
#    'L1_DAC:L23_ChC': 25.57142857142857,
#    'L1_DAC:L23_DBC': 31.428571428571427,
#    'L1_DAC:L23_LBC': 140.0,
#    'L1_DAC:L23_MC': 225.57142857142858,
#    'L1_DAC:L23_NBC': 100.85714285714285,
#    'L1_DAC:L23_NGC': 14.714285714285715,
#    'L1_DAC:L23_PC': 3338.8571428571427,
#    'L1_DAC:L23_SBC': 58.714285714285715,
#    'L1_DAC:L4_LBC': 6.285714285714286,
#    'L1_DAC:L4_MC': 4.142857142857143,
#    'L1_DAC:L4_NBC': 7.285714285714286,
#    'L1_DAC:L4_PC': 895.7142857142858,
#    'L1_DAC:L4_SBC': 1.857142857142857,
#    'L1_DAC:L4_SP': 141.14285714285714,
#    'L1_DAC:L4_SS': 30.57142857142857,
#    'L1_DAC:L5_DBC': 3.0,
# ...

# %%
import json

with open('Netconnections_Netpyne_final.json', 'w') as outfile:
    json.dump(connmatrixNetPyNe, outfile, indent=4)

# %%
for proj in errors['expl']['abs'].keys():
#     if connNumberBBP[proj] > 100000:
    if abs(errors['exp']['pcent'][proj])<=abs(errors['gauss']['pcent'][proj]):
        print('%.2f %.1f %.1f %.1f %.1f %.1f 1 %s exp' % (connNumberBBP[proj],connmatrixNetPyNe['exp']['mean'][proj],connmatrixNetPyNe['exp']['min'][proj],connmatrixNetPyNe['exp']['max'][proj],errors['exp']['abs'][proj],errors['exp']['pcent'][proj],proj))
    else:
        print('%.2f %.1f %.1f %.1f %.1f %.1f 2 %s gauss' % (connNumberBBP[proj],connmatrixNetPyNe['gauss']['mean'][proj],connmatrixNetPyNe['gauss']['min'][proj],connmatrixNetPyNe['gauss']['max'][proj],errors['gauss']['abs'][proj],errors['gauss']['pcent'][proj],proj))

# %%
number = 0
numberl = 0
numbere = 0
numberg = 0
for proj in errors['expl']['pcent'].keys():
    if connNumberBBP[proj] > 0:

        if abs(errors['exp']['pcent'][proj])<=abs(errors['expl']['pcent'][proj]) and abs(errors['exp']['pcent'][proj])<=abs(errors['gauss']['pcent'][proj]):
            print('%.2f %.1f %.1f %.1f %.1f %.1f 1 %s exp' % (connNumberBBP[proj],connmatrixNetPyNe['exp']['mean'][proj],connmatrixNetPyNe['exp']['min'][proj],connmatrixNetPyNe['exp']['max'][proj],errors['exp']['abs'][proj],errors['exp']['pcent'][proj],proj))
            numbere+=1
         
        elif abs(errors['gauss']['pcent'][proj])<=abs(errors['expl']['pcent'][proj]) and abs(errors['gauss']['pcent'][proj])<=abs(errors['exp']['pcent'][proj]):
            print('%.2f %.1f %.1f %.1f %.1f %.1f 2 %s gauss' % (connNumberBBP[proj],connmatrixNetPyNe['gauss']['mean'][proj],connmatrixNetPyNe['gauss']['min'][proj],connmatrixNetPyNe['gauss']['max'][proj],errors['gauss']['abs'][proj],errors['gauss']['pcent'][proj],proj))
            numberg+=1
         
        else:  
            print('%.2f %.1f %.1f %.1f %.1f %.1f 0 %s lsat' % (connNumberBBP[proj],connmatrixNetPyNe['expl']['mean'][proj],connmatrixNetPyNe['expl']['min'][proj],connmatrixNetPyNe['expl']['max'][proj],errors['expl']['abs'][proj],errors['expl']['pcent'][proj],proj))
            numberl+=1   
                
        number+=1
print('\n----------------\n',number,'fits\n----------------\n','explinearsat',numberl,'  fullexp',numbere,'  fullgauss',numberg)
# Out:
# 32.70 33.1 27.0 38.0 0.4 1.4 0 L1_DAC:L1_DAC lsat
# 13.70 14.1 8.0 22.0 0.4 3.2 0 L1_DAC:L1_DLAC lsat
# 39.10 37.0 30.0 46.0 -2.1 -5.4 0 L1_DAC:L1_HAC lsat
# 24.40 24.9 14.0 35.0 0.5 1.9 0 L1_DAC:L1_NGC-DA lsat
# 20.90 22.3 20.0 29.0 1.4 6.6 2 L1_DAC:L1_NGC-SA gauss
# 17.00 17.4 14.0 23.0 0.4 2.5 1 L1_DAC:L1_SLAC exp
# 1.70 1.3 0.0 4.0 -0.4 -24.4 2 L1_DAC:L23_BP gauss
# 44.70 48.1 39.0 56.0 3.4 7.7 2 L1_DAC:L23_BTC gauss
# 23.90 24.6 18.0 35.0 0.7 2.8 2 L1_DAC:L23_ChC gauss
# 32.60 32.1 26.0 37.0 -0.5 -1.4 1 L1_DAC:L23_DBC exp
# 137.70 140.0 123.0 154.0 2.3 1.7 0 L1_DAC:L23_LBC lsat
# 212.70 225.0 199.0 261.0 12.3 5.8 1 L1_DAC:L23_MC exp
# 95.40 96.4 89.0 107.0 1.0 1.1 2 L1_DAC:L23_NBC gauss
# 11.70 9.3 5.0 14.0 -2.4 -20.6 2 L1_DAC:L23_NGC gauss
# 3208.30 3300.6 3155.0 3469.0 92.3 2.9 2 L1_DAC:L23_PC gauss
# 50.30 50.6 35.0 64.0 0.3 0.5 1 L1_DAC:L23_SBC exp
# 6.00 6.3 4.0 9.0 0.3 4.8 0 L1_DAC:L4_LBC lsat
# 5.70 5.1 2.0 10.0 -0.6 -9.8 1 L1_DAC:L4_MC exp
# ...

# %%
for proj in errors['expl']['abs'].keys():
    if connNumberBBP[proj] > 100000:
        print('%.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.2f %.1f %.1f %.1f %.1f %.1f %.1f %s' % (connmatrixNetPyNe['expl']['mean'][proj],connmatrixNetPyNe['expl']['min'][proj],connmatrixNetPyNe['expl']['max'][proj],connmatrixNetPyNe['exp']['mean'][proj],connmatrixNetPyNe['exp']['min'][proj],connmatrixNetPyNe['exp']['max'][proj],connmatrixNetPyNe['gauss']['mean'][proj],connmatrixNetPyNe['gauss']['min'][proj],connmatrixNetPyNe['gauss']['max'][proj],connNumberBBP[proj],errors['expl']['abs'][proj],errors['expl']['pcent'][proj],errors['exp']['abs'][proj],errors['exp']['pcent'][proj],errors['gauss']['abs'][proj],errors['gauss']['pcent'][proj],proj))
for proj in errors['expl']['abs'].keys():
    if connNumberBBP[proj] > 10000 and connNumberBBP[proj] <= 100000:
        print('%.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.2f %.1f %.1f %.1f %.1f %.1f %.1f %s' % (connmatrixNetPyNe['expl']['mean'][proj],connmatrixNetPyNe['expl']['min'][proj],connmatrixNetPyNe['expl']['max'][proj],connmatrixNetPyNe['exp']['mean'][proj],connmatrixNetPyNe['exp']['min'][proj],connmatrixNetPyNe['exp']['max'][proj],connmatrixNetPyNe['gauss']['mean'][proj],connmatrixNetPyNe['gauss']['min'][proj],connmatrixNetPyNe['gauss']['max'][proj],connNumberBBP[proj],errors['expl']['abs'][proj],errors['expl']['pcent'][proj],errors['exp']['abs'][proj],errors['exp']['pcent'][proj],errors['gauss']['abs'][proj],errors['gauss']['pcent'][proj],proj))
for proj in errors['expl']['abs'].keys():
    if connNumberBBP[proj] > 1000 and connNumberBBP[proj] <= 10000:
        print('%.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.2f %.1f %.1f %.1f %.1f %.1f %.1f %s' % (connmatrixNetPyNe['expl']['mean'][proj],connmatrixNetPyNe['expl']['min'][proj],connmatrixNetPyNe['expl']['max'][proj],connmatrixNetPyNe['exp']['mean'][proj],connmatrixNetPyNe['exp']['min'][proj],connmatrixNetPyNe['exp']['max'][proj],connmatrixNetPyNe['gauss']['mean'][proj],connmatrixNetPyNe['gauss']['min'][proj],connmatrixNetPyNe['gauss']['max'][proj],connNumberBBP[proj],errors['expl']['abs'][proj],errors['expl']['pcent'][proj],errors['exp']['abs'][proj],errors['exp']['pcent'][proj],errors['gauss']['abs'][proj],errors['gauss']['pcent'][proj],proj))
for proj in errors['expl']['abs'].keys():
    if connNumberBBP[proj] > 100 and connNumberBBP[proj] <= 1000:
        print('%.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.2f %.1f %.1f %.1f %.1f %.1f %.1f %s' % (connmatrixNetPyNe['expl']['mean'][proj],connmatrixNetPyNe['expl']['min'][proj],connmatrixNetPyNe['expl']['max'][proj],connmatrixNetPyNe['exp']['mean'][proj],connmatrixNetPyNe['exp']['min'][proj],connmatrixNetPyNe['exp']['max'][proj],connmatrixNetPyNe['gauss']['mean'][proj],connmatrixNetPyNe['gauss']['min'][proj],connmatrixNetPyNe['gauss']['max'][proj],connNumberBBP[proj],errors['expl']['abs'][proj],errors['expl']['pcent'][proj],errors['exp']['abs'][proj],errors['exp']['pcent'][proj],errors['gauss']['abs'][proj],errors['gauss']['pcent'][proj],proj))
for proj in errors['expl']['abs'].keys():
    if connNumberBBP[proj] > 10 and connNumberBBP[proj] <= 100:
        print('%.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.2f %.1f %.1f %.1f %.1f %.1f %.1f %s' % (connmatrixNetPyNe['expl']['mean'][proj],connmatrixNetPyNe['expl']['min'][proj],connmatrixNetPyNe['expl']['max'][proj],connmatrixNetPyNe['exp']['mean'][proj],connmatrixNetPyNe['exp']['min'][proj],connmatrixNetPyNe['exp']['max'][proj],connmatrixNetPyNe['gauss']['mean'][proj],connmatrixNetPyNe['gauss']['min'][proj],connmatrixNetPyNe['gauss']['max'][proj],connNumberBBP[proj],errors['expl']['abs'][proj],errors['expl']['pcent'][proj],errors['exp']['abs'][proj],errors['exp']['pcent'][proj],errors['gauss']['abs'][proj],errors['gauss']['pcent'][proj],proj))
for proj in errors['expl']['abs'].keys():
    if connNumberBBP[proj] <= 10:
        print('%.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.2f %.1f %.1f %.1f %.1f %.1f %.1f %s' % (connmatrixNetPyNe['expl']['mean'][proj],connmatrixNetPyNe['expl']['min'][proj],connmatrixNetPyNe['expl']['max'][proj],connmatrixNetPyNe['exp']['mean'][proj],connmatrixNetPyNe['exp']['min'][proj],connmatrixNetPyNe['exp']['max'][proj],connmatrixNetPyNe['gauss']['mean'][proj],connmatrixNetPyNe['gauss']['min'][proj],connmatrixNetPyNe['gauss']['max'][proj],connNumberBBP[proj],errors['expl']['abs'][proj],errors['expl']['pcent'][proj],errors['exp']['abs'][proj],errors['exp']['pcent'][proj],errors['gauss']['abs'][proj],errors['gauss']['pcent'][proj],proj))

# %%
number
# Out:
# 7

# %%
number = 0
for proj in errors['expl']['abs'].keys():
    if int(connNumberBBP[proj]) > 10 and errors['exp']['pcent'][proj]>20 and errors['gauss']['pcent'][proj]>20:    
        print('%.1f %.1f %.1f %s' % (errors['expl']['pcent'][proj], errors['exp']['pcent'][proj], errors['gauss']['pcent'][proj],proj))
        print('%.1f %.1f %.1f %s' % (errors['expl']['abs'][proj], errors['exp']['abs'][proj], errors['gauss']['abs'][proj],proj))
#         print('%.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.1f %.2f %.1f %.1f %.1f %.1f %.1f %.1f %s' % (connmatrixNetPyNe['expl']['mean'][proj],connmatrixNetPyNe['expl']['min'][proj],connmatrixNetPyNe['expl']['max'][proj],connmatrixNetPyNe['exp']['mean'][proj],connmatrixNetPyNe['exp']['min'][proj],connmatrixNetPyNe['exp']['max'][proj],connmatrixNetPyNe['gauss']['mean'][proj],connmatrixNetPyNe['gauss']['min'][proj],connmatrixNetPyNe['gauss']['max'][proj],connNumberBBP[proj],errors['expl']['abs'][proj],errors['expl']['pcent'][proj],errors['exp']['abs'][proj],errors['exp']['pcent'][proj],errors['gauss']['abs'][proj],errors['gauss']['pcent'][proj],proj))
        print(connNumberBBP[proj])
        number+=1
# Out:
# 9.3 25.7 21.8 L1_NGC-DA:L1_SLAC
# 2.0 5.6 4.7 L1_NGC-DA:L1_SLAC
# 21.7
# 16.4 26.3 21.4 L1_NGC-SA:L23_MC
# 13.3 21.3 17.3 L1_NGC-SA:L23_MC
# 81.1
# 5.9 32.0 21.2 L23_BTC:L1_HAC
# 1.3 7.2 4.7 L23_BTC:L1_HAC
# 22.4
# 24.7 33.8 35.4 L4_DBC:L23_BTC
# 4.3 5.8 6.1 L4_DBC:L23_BTC
# 17.3
# 17.0 31.6 23.7 L4_LBC:L4_ChC
# 2.2 4.0 3.0 L4_LBC:L4_ChC
# 12.7
# 7.7 20.5 20.5 L4_LBC:L4_DBC
# 2.0 5.3 5.3 L4_LBC:L4_DBC
# 25.6
# 15.7 31.4 29.8 L5_SBC:L6_IPC
# 4.3 8.6 8.2 L5_SBC:L6_IPC
# 27.4
