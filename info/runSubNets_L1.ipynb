# %%
## collab user
# !pip install neuron
# !pip install netpyne
# !git clone https://github.com/suny-downstate-medical-center/S1_netpyne.git
# import os
# os.chdir('S1_netpyne/info')

# %%
import matplotlib
import os
os.chdir('../sim')

# %%
# !nrnivmodl mod/

# %%
"""
cfg.py 

Simulation configuration for S1 model (using NetPyNE)
This file has sim configs as well as specification for parameterized values in netParams.py 

Contributors: salvadordura@gmail.com, fernandodasilvaborges@gmail.com
"""

from netpyne import specs, sim
import pickle, json
import numpy as np

# %matplotlib inline

cfg = specs.SimConfig()  

#------------------------------------------------------------------------------
#
# SIMULATION CONFIGURATION
#
#------------------------------------------------------------------------------

#------------------------------------------------------------------------------
# Run parameters
#------------------------------------------------------------------------------
cfg.duration = 5.0*1e2 ## Duration of the sim, in ms  
cfg.dt = 0.025
cfg.seeds = {'conn': 4321, 'stim': 4321, 'loc': 4321} 
cfg.hParams = {'celsius': 34, 'v_init': -65}  
cfg.verbose = False
cfg.createNEURONObj = True
cfg.createPyStruct = True  
cfg.cvode_active = False
cfg.cvode_atol = 1e-6
cfg.cache_efficient = True
cfg.printRunTime = 0.1

cfg.includeParamsLabel = False
cfg.printPopAvgRates = True

cfg.checkErrors = False

cfg.poptypeNumber = 55
cfg.celltypeNumber = 207

# %%
#------------------------------------------------------------------------------  
# S1 Cells
# Load 55 Morphological Names and Cell pop numbers -> L1:6 L23:10 L4:12 L5:13 L6:14
# Load 207 Morpho-electrical Names used to import the cells from 'cell_data/' -> L1:14 L23:43 L4:46 L5:52 L6:52
# Create [Morphological,Electrical] = number of cell metype in the sub-pop
with open('../info/anatomy/S1-cells-distributions-Rat.txt') as mtype_file:
	mtype_content = mtype_file.read()       

cfg.popNumber = {}
cfg.cellNumber = {} 
cfg.popLabel = {} 
popParam = []
cellParam = []
cfg.meParamLabels = {} 
for line in mtype_content.split('\n')[:-1]:
	metype, mtype, etype, n, m = line.split()
	cfg.cellNumber[metype] = int(n)
	cfg.popLabel[metype] = mtype
	cfg.popNumber[mtype] = int(m)

	if mtype not in popParam:
		popParam.append(mtype)
	cellParam.append(metype)

cfg.S1pops = popParam[0:55]
cfg.S1cells = cellParam[0:207]

#------------------------------------------------------------------------------  
cfg.popParamLabels = popParam[0:cfg.poptypeNumber] # to debug
cfg.cellParamLabels = cellParam[0:cfg.celltypeNumber] # to debug

# %%
#------------------------------------------------------------------------------
# Cells
#------------------------------------------------------------------------------

# TO DEBUG - import and simulate only the Cell soma (to study only the Net)
cfg.reducedtest = False    

# TO DEBUG - Create only 5 Cells for each MEtype in S1
cfg.oneCellperMEtypeS1 = False

# %%
#------------------------------------------------------------------------------  
# TO DEBUG - Create only one Cell per MEtype in S1 cells
if cfg.oneCellperMEtypeS1:
	cfg.popNumber = {}
	cfg.cellNumber = {} 
	for mtype in cfg.S1pops:
		cfg.popNumber[mtype] = 0

	for line in mtype_content.split('\n')[:-1]:
		metype, mtype, etype, n, m = line.split()
		if int(n) < 5:
			cfg.cellNumber[metype] = int(n)
			cfg.popNumber[mtype] = cfg.popNumber[mtype] + int(n)
		else:
			cfg.cellNumber[metype] = 5
			cfg.popNumber[mtype] = cfg.popNumber[mtype] + 5

# %%
cfg.addConnEE = True # too much 'L23_PC' -> 'L23_PC' conn
subPopLabels = ['L1_DAC', 'L1_DLAC', 'L1_HAC', 'L1_NGC-DA', 'L1_NGC-SA', 'L1_SLAC', 'L23_PC']

num = 0
for metype in cfg.cellParamLabels:
    if cfg.popLabel[metype] in subPopLabels:
        num+=cfg.cellNumber[metype]
        print(metype,cfg.cellNumber[metype],cfg.popLabel[metype],cfg.popNumber[cfg.popLabel[metype]],num)

Number_L23_PC = cfg.popNumber['L23_PC'] 

cfg.cellNumber['L23_PC_cADpyr229'] = 5*338   # too much 'L23_PC' cells ~ L1 = 338
cfg.popNumber['L23_PC'] = 5*338

numConnectionCorrection = Number_L23_PC/cfg.popNumber['L23_PC']

print()
print('Number of L23_PC cells = Number of L1 cells')
print(numConnectionCorrection)

num = 0
for metype in cfg.cellParamLabels:
    if cfg.popLabel[metype] in subPopLabels:
        num+=cfg.cellNumber[metype]
        print(metype,cfg.cellNumber[metype],cfg.popLabel[metype],cfg.popNumber[cfg.popLabel[metype]],num)
# Out:
# L1_DAC_bNAC219 19 L1_DAC 58 19
# L1_DAC_cNAC187 39 L1_DAC 58 58
# L1_DLAC_cNAC187 24 L1_DLAC 24 82
# L1_HAC_bNAC219 19 L1_HAC 91 101
# L1_HAC_cIR216 10 L1_HAC 91 111
# L1_HAC_cNAC187 62 L1_HAC 91 173
# L1_NGC-DA_bNAC219 8 L1_NGC-DA 72 181
# L1_NGC-DA_cACint209 8 L1_NGC-DA 72 189
# L1_NGC-DA_cNAC187 48 L1_NGC-DA 72 237
# L1_NGC-DA_cSTUT189 8 L1_NGC-DA 72 245
# L1_NGC-SA_cNAC187 52 L1_NGC-SA 52 297
# L1_SLAC_bNAC219 14 L1_SLAC 41 311
# L1_SLAC_cACint209 8 L1_SLAC 41 319
# L1_SLAC_cNAC187 19 L1_SLAC 41 338
# L23_PC_cADpyr229 5877 L23_PC 5877 6215
#
# Number of L23_PC cells = Number of L1 cells
# 3.477514792899408
# L1_DAC_bNAC219 19 L1_DAC 58 19
# L1_DAC_cNAC187 39 L1_DAC 58 58
# L1_DLAC_cNAC187 24 L1_DLAC 24 82
# L1_HAC_bNAC219 19 L1_HAC 91 101
# L1_HAC_cIR216 10 L1_HAC 91 111
# L1_HAC_cNAC187 62 L1_HAC 91 173
# L1_NGC-DA_bNAC219 8 L1_NGC-DA 72 181
# L1_NGC-DA_cACint209 8 L1_NGC-DA 72 189
# L1_NGC-DA_cNAC187 48 L1_NGC-DA 72 237
# L1_NGC-DA_cSTUT189 8 L1_NGC-DA 72 245
# L1_NGC-SA_cNAC187 52 L1_NGC-SA 52 297
# L1_SLAC_bNAC219 14 L1_SLAC 41 311
# L1_SLAC_cACint209 8 L1_SLAC 41 319
# L1_SLAC_cNAC187 19 L1_SLAC 41 338
# L23_PC_cADpyr229 1690 L23_PC 1690 2028

# %%
#------------------------------------------------------------------------------  
cfg.S1pops = subPopLabels
cfg.S1cells = []
for metype in cfg.cellParamLabels:
    if cfg.popLabel[metype] in subPopLabels:        
        cfg.S1cells.append(metype)
        
cfg.thalamicpops = []

cfg.popParamLabels = cfg.S1pops
cfg.cellParamLabels = cfg.S1cells

# %%
#--------------------------------------------------------------------------
# Recording 
#--------------------------------------------------------------------------
cfg.allpops = cfg.popParamLabels
cfg.cellsrec = 0
if cfg.cellsrec == 0:  cfg.recordCells = cfg.allpops # record all cells
elif cfg.cellsrec == 1: cfg.recordCells = [(pop,0) for pop in cfg.allpops] # record one cell of each pop
elif cfg.cellsrec == 2: # record one cell of each cellMEtype (cfg.celldiversity = True)
	cfg.recordCells = []
	cellNumberLabel = 0 
	for metype in cfg.cellParamLabels:
		if metype in cfg.cellParamLabels:
			if cfg.cellNumber[metype] < 5:
				for numberME in range(cfg.cellNumber[metype]):
					cfg.recordCells.append((cfg.popLabel[metype],cellNumberLabel+numberME))
			else:
				for numberME in range(0,cfg.cellNumber[metype],int(cfg.cellNumber[metype]/4.5)):
					cfg.recordCells.append((cfg.popLabel[metype],cellNumberLabel+numberME))
			cellNumberLabel = cellNumberLabel + cfg.cellNumber[metype]
			if cellNumberLabel == cfg.popNumber[cfg.popLabel[metype]]:
				cellNumberLabel = 0 
                
cfg.recordTraces = {'V_soma': {'sec':'soma', 'loc':0.5, 'var':'v'}}  ## Dict with traces to record
cfg.recordStim = False			
cfg.recordTime = False  		
cfg.recordStep = 0.1

# %%
#------------------------------------------------------------------------------
# Saving
#------------------------------------------------------------------------------
cfg.simLabel = 'subNets_test_L1'
cfg.saveFolder = '../info/test/'+cfg.simLabel
# cfg.filename =                	## Set file output name
cfg.savePickle = False         	## Save pkl file
cfg.saveJson = True	           	## Save json file
cfg.saveDataInclude = ['simConfig','simData'] ## , 'netParams', 'simConfig', 
cfg.backupCfgFile = None 		##  
cfg.gatherOnlySimData = False	##  
cfg.saveCellSecs = False			
cfg.saveCellConns = True

# %%
"""
netParams.py
"""
# Network parameters
netParams = specs.NetParams()  # object of class NetParams to store the network parameters

netParams.scale = 1.0 # Scale factor for number of cells
netParams.sizeX = 420.0 # x-dimension (horizontal length) size in um
netParams.sizeY = 2082.0 # y-dimension (vertical height or cortical depth) size in um
netParams.sizeZ = 420.0 # z-dimension (horizontal depth) size in um
netParams.shape = 'cylinder' # cylindrical (column-like) volume

# r = 210 um and hexagonal side length = 230.9 um

# %%
#------------------------------------------------------------------------------
# General network parameters
#------------------------------------------------------------------------------
# Layer	height (um)	height (norma)	from	to
# L1	165		    0.079		    0.000	0.079
# L2	149		    0.072		    0.079	0.151
# L3	353		    0.170		    0.151	0.320
# L4	190		    0.091		    0.320	0.412
# L5	525		    0.252		    0.412	0.664
# L6	700		    0.336		    0.664	1.000
# L23	502		    0.241		    0.079	0.320
# All	2082	    1.000	


cellModels = ['HH_full']
Epops = ['L23_PC', 'L4_PC', 'L4_SS', 'L4_SP', 
             'L5_TTPC1', 'L5_TTPC2', 'L5_STPC', 'L5_UTPC',
             'L6_TPC_L1', 'L6_TPC_L4', 'L6_BPC', 'L6_IPC', 'L6_UTPC']
Ipops = []
for popName in cfg.S1pops:
    if popName not in Epops:
        Ipops.append(popName)

Epops = []
for popName in cfg.S1pops:
    if popName not in Ipops:
        Epops.append(popName)   

layer = {'1':[0.0, 0.079], '2': [0.079,0.151], '3': [0.151,0.320], '23': [0.079,0.320], '4':[0.320,0.412], '5': [0.412,0.664], '6': [0.664,1.0], 
'longS1': [2.2,2.3], 'longS2': [2.3,2.4]}  # normalized layer boundaries

# %%
#------------------------------------------------------------------------------
# General connectivity parameters
#------------------------------------------------------------------------------
netParams.defaultThreshold = -10.0 # spike threshold, 10 mV is NetCon default, lower it for all cells
netParams.defaultDelay = 0.1 # default conn delay (ms)(M1: 2.0 ms)
netParams.propVelocity = 300.0 #  300 μm/ms (Stuart et al., 1997)(M1: 500.0um/ms)
netParams.scaleConnWeight = 0.001 # weight conversion factor (from nS to uS)
netParams.scaleConnWeightNetStims = 0.001  # weight conversion factor (from nS to uS)

# %%
#------------------------------------------------------------------------------
# Population parameters
#------------------------------------------------------------------------------
## S1
cfg.scaleDensity = 1.0

for popName in cfg.S1pops:
	layernumber = popName[1:2]
	if layernumber == '2':
		netParams.popParams[popName] = {'cellType': popName, 'cellModel': 'HH_full', 'ynormRange': layer['23'], 
                                        'numCells': int(np.ceil(cfg.scaleDensity*cfg.popNumber[popName])), 'diversity': True}
	else:
		netParams.popParams[popName] = {'cellType': popName, 'cellModel': 'HH_full', 'ynormRange': layer[layernumber], 
                                        'numCells': int(np.ceil(cfg.scaleDensity*cfg.popNumber[popName])), 'diversity': True}

# %%
## S1 cell property rules
cellnumber = 0    
for cellName in cfg.S1cells:
    
    if cfg.cellNumber[cellName] < 5:
        morphoNumbers = cfg.cellNumber[cellName]
    else:
        morphoNumbers = 5
    
    popName = cfg.popLabel[cellName]
    cellFraction = 1.0*cfg.cellNumber[cellName]/(morphoNumbers*cfg.popNumber[popName])
    
    for morphoNumber in range(morphoNumbers):
        cellMe = cellName + '_' + str(morphoNumber+1)
        ## Load cell rules previously saved using netpyne format
        netParams.loadCellParamsRule(label = cellMe, fileName = 'cell_data/' + cellMe + '/' + cellMe + '_cellParams.pkl')    
        netParams.renameCellParamsSec(label = cellMe, oldSec = 'soma_0', newSec = 'soma')

        cellRule = {'conds': {'cellType': popName}, 'diversityFraction': cellFraction, 'secs': {}}  # cell rule dict
        cellRule['secs'] = netParams.cellParams[cellMe]['secs']     
        cellRule['conds'] = netParams.cellParams[cellMe]['conds']    
        cellRule['conds']['cellType'] = popName
        cellRule['globals'] = netParams.cellParams[cellMe]['globals']       
        cellRule['secLists'] = netParams.cellParams[cellMe]['secLists']                 
        cellRule['secLists']['all'][0] = 'soma' # replace 'soma_0'
        cellRule['secLists']['somatic'][0]  = 'soma' # replace 'soma_0'
                              
        cellRule['secLists']['spiny'] = {}
        cellRule['secLists']['spinyEE'] = {}

        nonSpiny = ['axon_0', 'axon_1']
        cellRule['secLists']['spiny'] = [sec for sec in cellRule['secLists']['all'] if sec not in nonSpiny]
        nonSpinyEE = ['axon_0', 'axon_1', 'soma']
        cellRule['secLists']['spinyEE'] = [sec for sec in cellRule['secLists']['all'] if sec not in nonSpinyEE]

        #-----------------------------------------------------------------------------------#
        if cfg.reducedtest:
            cellRule['secs'] = {}
            cellRule['secs']['soma'] = netParams.cellParams[cellMe]['secs']['soma']
            cellRule['secLists']['spiny'] = ['soma']
            cellRule['secLists']['spinyEE'] = ['soma']
            cellRule['secLists']['all'] = ['soma']
            cellRule['secLists']['basal'] = ['soma']    
        #-----------------------------------------------------------------------------------#
        netParams.cellParams[cellMe] = cellRule   # add dict to list of cell params   
        cellnumber=cellnumber+1

# %%
#------------------------------------------------------------------------------
# Synaptic mechanism parameters  - mods from M1 detailed
#------------------------------------------------------------------------------
## S1
netParams.synMechParams['AMPA'] = {'mod':'MyExp2SynBB', 'tau1': 0.2, 'tau2': 1.74, 'e': 0}
netParams.synMechParams['NMDA'] = {'mod': 'MyExp2SynNMDABB', 'tau1NMDA': 0.29, 'tau2NMDA': 43, 'e': 0}
netParams.synMechParams['GABAA6'] = {'mod':'MyExp2SynBB', 'tau1': 0.2, 'tau2': 6.44, 'e': -80}
netParams.synMechParams['GABAA'] = {'mod':'MyExp2SynBB', 'tau1': 0.2, 'tau2': 8.3, 'e': -80}
netParams.synMechParams['GABAA10'] = {'mod':'MyExp2SynBB', 'tau1': 0.2, 'tau2': 10.4, 'e': -80}
netParams.synMechParams['GABAB'] = {'mod':'MyExp2SynBB', 'tau1': 3.5, 'tau2': 260.9, 'e': -93} 

ESynMech = ['AMPA', 'NMDA']
ISynMech = ['GABAA', 'GABAB']
ISynMech6 = ['GABAA6', 'GABAB']
ISynMech10 = ['GABAA10', 'GABAB']

# %%
#------------------------------------------------------------------------------
# load data from S1 conn pre-processing file 
#------------------------------------------------------------------------------
with open('conn/conn.pkl', 'rb') as fileObj: connData = pickle.load(fileObj)

lmat = connData['lmat']
a0mat = connData['a0mat']
d0 = connData['d0']
dfinal = connData['dfinal']
pmat = {}
pmat[12.5] = connData['pmat12um']
pmat[25] = connData['pmat25um']
pmat[50] = connData['pmat50um']
pmat[75] = connData['pmat75um']
pmat[100] = connData['pmat100um']
pmat[125] = connData['pmat125um']
pmat[150] = connData['pmat150um']
pmat[175] = connData['pmat175um']
pmat[200] = connData['pmat200um'] #max value for d0=200

synperconnNumber = connData['synperconnNumber']
connNumber = connData['connNumber']
decay = connData['decay']
gsyn = connData['gsyn']
use = connData['use']

# %%
#------------------------------------------------------------------------------
# S1 Local connectivity parameters 
#------------------------------------------------------------------------------
cfg.addConn = True

cfg.synWeightFractionEE = [1.0, 1.0] # E -> E AMPA to NMDA ratio
cfg.synWeightFractionEI = [1.0, 1.0] # E -> I AMPA to NMDA ratio
cfg.synWeightFractionII = [1.0, 1.0]  # I -> I GABAA to GABAB ratio
cfg.synWeightFractionIE = [1.0, 1.0]  # I -> E GABAA to GABAB ratio
cfg.EEGain = 1.0
cfg.EIGain = 1.0
cfg.IIGain = 1.0
cfg.IEGain = 1.0

if cfg.addConn:      
# I -> I
    for pre in Ipops:
        for post in Ipops:
            if float(connNumber[pre][post]) > 0:        

                if int(float(d0[pre][post])) < 25:    #d0==12.5 -> single exponential fit
                    linear = 0
                    angular = 0
                    prob = '%s * exp(-dist_2D/%s)*(dist_2D<%s)' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post])                     
                elif int(float(d0[pre][post])) == 25:    #d0==25 -> exponential fit when dist_2D>25, else prob[0um:25um] = pmat[12.5]
                    linear = float(pmat[12.5][pre][post])
                    angular = 0
                    prob = '%s * exp(-dist_2D/%s)*(dist_2D<%s) if dist_2D > %s else %f * dist_2D + %f' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post],d0[pre][post],angular,linear)
                else:    #d0>25 -> exponential fit when dist_2D>d0, else prob[0um:d0] = linear interpolation [25:d0]
                    d01 = int(float(d0[pre][post]))
                    y1 = float(pmat[25][pre][post])
                    y2 = float(pmat[d01][pre][post])
                    x1 = 25
                    x2 = d01                   
                    angular = (y2 - y1)/(x2 - x1)
                    linear = y2 - x2*angular
                    prob = '%s * exp(-dist_2D/%s)*(dist_2D<%s) if dist_2D > %s else %f * dist_2D + %f' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post],d0[pre][post],angular,linear)
                
                if decay[pre][post] > 10.0:
                    synMechType =  ISynMech10
                elif decay[pre][post] < 7.0:
                    synMechType =  ISynMech6
                else:
                    synMechType =  ISynMech

                netParams.connParams['II_'+pre+'_'+post] = { 
                    'preConds': {'pop': pre}, 
                    'postConds': {'pop': post},
                    'synMech': synMechType,
                    'probability': prob,
                    'weight': gsyn[pre][post] * cfg.IIGain, 
                    'synMechWeightFactor': cfg.synWeightFractionII,
                    'delay': 'defaultDelay+dist_3D/propVelocity',
                    'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                    'sec': 'spiny'}       

## I -> E
    for pre in Ipops:
        for post in Epops:
            if float(connNumber[pre][post]) > 0:        

                if int(float(d0[pre][post])) < 25:    #d0==12.5 -> single exponential fit
                    linear = 0
                    angular = 0
                    prob = '%s*exp(-dist_2D/%s)*(dist_2D<%s)' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post])                     
                elif int(float(d0[pre][post])) == 25:    #d0==25 -> exponential fit when dist_2D>25, else prob[0um:25um] = pmat[12.5]
                    linear = float(pmat[12.5][pre][post])
                    angular = 0
                    prob = '%s*exp(-dist_2D/%s)*(dist_2D<%s) if dist_2D > %s else %f*dist_2D+%f' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post],d0[pre][post],angular,linear)
                else:    #d0>25 -> exponential fit when dist_2D>d0, else prob[0um:d0] = linear interpolation [25:d0]
                    d01 = int(float(d0[pre][post]))
                    y1 = float(pmat[25][pre][post])
                    y2 = float(pmat[d01][pre][post])
                    x1 = 25
                    x2 = d01                   
                    angular = (y2 - y1)/(x2 - x1)
                    linear = y2 - x2*angular
                    prob = '%s*exp(-dist_2D/%s)*(dist_2D<%s) if dist_2D > %s else %f * dist_2D + %f' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post],d0[pre][post],angular,linear)

                if decay[pre][post] > 10.0:
                    synMechType =  ISynMech10
                elif decay[pre][post] < 7.0:
                    synMechType =  ISynMech6
                else:
                    synMechType =  ISynMech

                netParams.connParams['IE_'+pre+'_'+post] = { 
                    'preConds': {'pop': pre}, 
                    'postConds': {'pop': post},
                    'synMech': synMechType,
                    'probability': prob,
                    'weight': gsyn[pre][post] * cfg.IEGain, 
                    'synMechWeightFactor': cfg.synWeightFractionIE,
                    'delay': 'defaultDelay+dist_3D/propVelocity',
                    'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                    'sec': 'spiny'}     
#------------------------------------------------------------------------------   
## E -> E
    if cfg.addConnEE:
        for pre in Epops:
            for post in Epops:
                if float(connNumber[pre][post]) > 0:        

                    if int(float(d0[pre][post])) < 25:    #d0==12.5 -> single exponential fit
                        linear = 0
                        angular = 0
                        prob = '%s * exp(-dist_2D/%s)*(dist_2D<%s)' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post])                     
                    elif int(float(d0[pre][post])) == 25:    #d0==25 -> exponential fit when dist_2D>25, else prob[0um:25um] = pmat[12.5]
                        linear = float(pmat[12.5][pre][post])
                        angular = 0
                        prob = '%s * exp(-dist_2D/%s)*(dist_2D<%s) if dist_2D > %s else %f * dist_2D + %f' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post],d0[pre][post],angular,linear)
                    else:    #d0>25 -> exponential fit when dist_2D>d0, else prob[0um:d0] = linear interpolation [25:d0]
                        d01 = int(float(d0[pre][post]))
                        y1 = float(pmat[25][pre][post])
                        y2 = float(pmat[d01][pre][post])
                        x1 = 25
                        x2 = d01                   
                        angular = (y2 - y1)/(x2 - x1)
                        linear = y2 - x2*angular
                        prob = '%s * exp(-dist_2D/%s)*(dist_2D<%s) if dist_2D > %s else %f * dist_2D + %f' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post],d0[pre][post],angular,linear)

                    netParams.connParams['EE_'+pre+'_'+post] = { 
                        'preConds': {'pop': pre}, 
                        'postConds': {'pop': post},
                        'synMech': ESynMech,
                        'probability': prob, 
                        'weight': gsyn[pre][post] * cfg.EEGain, 
                        'synMechWeightFactor': cfg.synWeightFractionEE,
                        'delay': 'defaultDelay+dist_3D/propVelocity',
                        'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                        'sec': 'spinyEE'}    
# ## E -> I
    for pre in Epops:
        for post in Ipops:
            if float(connNumber[pre][post]) > 0:        

                if int(float(d0[pre][post])) < 25:    #d0==12.5 -> single exponential fit
                    linear = 0
                    angular = 0
                    prob = '%s * exp(-dist_2D/%s)*(dist_2D<%s)' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post])                     
                elif int(float(d0[pre][post])) == 25:    #d0==25 -> exponential fit when dist_2D>25, else prob[0um:25um] = pmat[12.5]
                    linear = float(pmat[12.5][pre][post])
                    angular = 0
                    prob = '%s * exp(-dist_2D/%s)*(dist_2D<%s) if dist_2D > %s else %f * dist_2D + %f' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post],d0[pre][post],angular,linear)
                else:    #d0>25 -> exponential fit when dist_2D>d0, else prob[0um:d0] = linear interpolation [25:d0]
                    d01 = int(float(d0[pre][post]))
                    y1 = float(pmat[25][pre][post])
                    y2 = float(pmat[d01][pre][post])
                    x1 = 25
                    x2 = d01                   
                    angular = (y2 - y1)/(x2 - x1)
                    linear = y2 - x2*angular
                    prob = '%s * exp(-dist_2D/%s)*(dist_2D<%s) if dist_2D > %s else %f * dist_2D + %f' % (a0mat[pre][post],lmat[pre][post],dfinal[pre][post],d0[pre][post],angular,linear)

                netParams.connParams['EI_'+pre+'_'+post] = { 
                    'preConds': {'pop': pre}, 
                    'postConds': {'pop': post},
                    'synMech': ESynMech,
                    'probability': '%f * %s' % (numConnectionCorrection, prob), 
                    'weight': gsyn[pre][post] * cfg.EIGain, 
                    'synMechWeightFactor': cfg.synWeightFractionEI,
                    'delay': 'defaultDelay+dist_3D/propVelocity',
                    'synsPerConn': int(synperconnNumber[pre][post]+0.5),
                    'sec': 'spiny'}

# %%
for connpath in netParams.connParams.keys():
    print(connpath)
    print(netParams.connParams[connpath])
    print()
# Out:
# II_L1_DAC_L1_DAC
# {'preConds': {'pop': 'L1_DAC'}, 'postConds': {'pop': 'L1_DAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.07513 * exp(-dist_2D/71.91)*(dist_2D<350.0) if dist_2D > 50.0 else 0.000174 * dist_2D + 0.028420', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 13, 'sec': 'spiny'}
#
# II_L1_DAC_L1_DLAC
# {'preConds': {'pop': 'L1_DAC'}, 'postConds': {'pop': 'L1_DLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.10973 * exp(-dist_2D/64.94)*(dist_2D<375.0) if dist_2D > 125.0 else -0.000169 * dist_2D + 0.038038', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 13, 'sec': 'spiny'}
#
# II_L1_DAC_L1_HAC
# {'preConds': {'pop': 'L1_DAC'}, 'postConds': {'pop': 'L1_HAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.10459 * exp(-dist_2D/56.38)*(dist_2D<375.0) if dist_2D > 125.0 else -0.000228 * dist_2D + 0.040028', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 14, 'sec': 'spiny'}
#
# II_L1_DAC_L1_NGC-DA
# {'preConds': {'pop': 'L1_DAC'}, 'postConds': {'pop': 'L1_NGC-DA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.05558 * exp(-dist_2D/62.38)*(dist_2D<325.0) if dist_2D > 50.0 else -0.000221 * dist_2D + 0.035590', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 12, 'sec': 'spiny'}
#
# II_L1_DAC_L1_NGC-SA
# {'preConds': {'pop': 'L1_DAC'}, 'postConds': {'pop': 'L1_NGC-SA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.12821 * exp(-dist_2D/46.79)*(dist_2D<275.0) if dist_2D > 75.0 else -0.000143 * dist_2D + 0.036550', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 14, 'sec': 'spiny'}
#
# II_L1_DAC_L1_SLAC
# {'preConds': {'pop': 'L1_DAC'}, 'postConds': {'pop': 'L1_SLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.07757 * exp(-dist_2D/63.01)*(dist_2D<325.0) if dist_2D > 75.0 else 0.000084 * dist_2D + 0.016870', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 11, 'sec': 'spiny'}
#
# II_L1_DLAC_L1_DAC
# {'preConds': {'pop': 'L1_DLAC'}, 'postConds': {'pop': 'L1_DAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.90718 * exp(-dist_2D/36.65)*(dist_2D<350.0) if dist_2D > 150.0 else -0.000328 * dist_2D + 0.064352', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 15, 'sec': 'spiny'}
#
# II_L1_DLAC_L1_DLAC
# {'preConds': {'pop': 'L1_DLAC'}, 'postConds': {'pop': 'L1_DLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '24.55981 * exp(-dist_2D/19.98)*(dist_2D<275.0) if dist_2D > 150.0 else -0.000168 * dist_2D + 0.038710', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 17, 'sec': 'spiny'}
#
# II_L1_DLAC_L1_HAC
# {'preConds': {'pop': 'L1_DLAC'}, 'postConds': {'pop': 'L1_HAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.21216 * exp(-dist_2D/44.34)*(dist_2D<350.0) if dist_2D > 100.0 else -0.000315 * dist_2D + 0.054377', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 16, 'sec': 'spiny'}
#
# II_L1_DLAC_L1_NGC-DA
# {'preConds': {'pop': 'L1_DLAC'}, 'postConds': {'pop': 'L1_NGC-DA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.14148 * exp(-dist_2D/47.37)*(dist_2D<250.0) if dist_2D > 75.0 else -0.000158 * dist_2D + 0.040945', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 14, 'sec': 'spiny'}
#
# II_L1_DLAC_L1_NGC-SA
# {'preConds': {'pop': 'L1_DLAC'}, 'postConds': {'pop': 'L1_NGC-SA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.14693 * exp(-dist_2D/49.91)*(dist_2D<300.0) if dist_2D > 125.0 else -0.000278 * dist_2D + 0.046953', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 16, 'sec': 'spiny'}
#
# II_L1_DLAC_L1_SLAC
# {'preConds': {'pop': 'L1_DLAC'}, 'postConds': {'pop': 'L1_SLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.32859 * exp(-dist_2D/31.40)*(dist_2D<375.0) if dist_2D > 75.0 else -0.000406 * dist_2D + 0.060915', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 16, 'sec': 'spiny'}
#
# II_L1_HAC_L1_DAC
# {'preConds': {'pop': 'L1_HAC'}, 'postConds': {'pop': 'L1_DAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.14581 * exp(-dist_2D/67.05)*(dist_2D<375.0) if dist_2D > 100.0 else -0.000393 * dist_2D + 0.072373', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 14, 'sec': 'spiny'}
#
# II_L1_HAC_L1_DLAC
# {'preConds': {'pop': 'L1_HAC'}, 'postConds': {'pop': 'L1_DLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.15905 * exp(-dist_2D/62.41)*(dist_2D<375.0) if dist_2D > 50.0 else -0.000308 * dist_2D + 0.087270', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 16, 'sec': 'spiny'}
#
# II_L1_HAC_L1_HAC
# {'preConds': {'pop': 'L1_HAC'}, 'postConds': {'pop': 'L1_HAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.26099 * exp(-dist_2D/51.91)*(dist_2D<350.0) if dist_2D > 150.0 else -0.000280 * dist_2D + 0.056382', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 16, 'sec': 'spiny'}
#
# II_L1_HAC_L1_NGC-DA
# {'preConds': {'pop': 'L1_HAC'}, 'postConds': {'pop': 'L1_NGC-DA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.15934 * exp(-dist_2D/54.58)*(dist_2D<325.0) if dist_2D > 125.0 else -0.000309 * dist_2D + 0.054725', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 15, 'sec': 'spiny'}
#
# II_L1_HAC_L1_NGC-SA
# {'preConds': {'pop': 'L1_HAC'}, 'postConds': {'pop': 'L1_NGC-SA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.10409 * exp(-dist_2D/59.58)*(dist_2D<350.0) if dist_2D > 50.0 else -0.000327 * dist_2D + 0.061170', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 16, 'sec': 'spiny'}
#
# II_L1_HAC_L1_SLAC
# {'preConds': {'pop': 'L1_HAC'}, 'postConds': {'pop': 'L1_SLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.17989 * exp(-dist_2D/52.94)*(dist_2D<325.0) if dist_2D > 100.0 else -0.000249 * dist_2D + 0.052300', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 12, 'sec': 'spiny'}
#
# II_L1_NGC-DA_L1_DAC
# {'preConds': {'pop': 'L1_NGC-DA'}, 'postConds': {'pop': 'L1_DAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.15170 * exp(-dist_2D/53.06)*(dist_2D<275.0) if dist_2D > 50.0 else -0.000496 * dist_2D + 0.081810', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 17, 'sec': 'spiny'}
#
# II_L1_NGC-DA_L1_DLAC
# {'preConds': {'pop': 'L1_NGC-DA'}, 'postConds': {'pop': 'L1_DLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.09776 * exp(-dist_2D/64.57)*(dist_2D<200.0)', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 19, 'sec': 'spiny'}
#
# II_L1_NGC-DA_L1_HAC
# {'preConds': {'pop': 'L1_NGC-DA'}, 'postConds': {'pop': 'L1_HAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.15822 * exp(-dist_2D/46.78)*(dist_2D<350.0) if dist_2D > 50.0 else -0.000747 * dist_2D + 0.090560', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 18, 'sec': 'spiny'}
#
# II_L1_NGC-DA_L1_NGC-DA
# {'preConds': {'pop': 'L1_NGC-DA'}, 'postConds': {'pop': 'L1_NGC-DA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.07684 * exp(-dist_2D/62.84)*(dist_2D<200.0) if dist_2D > 25.0 else 0.000000 * dist_2D + 0.025720', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 15, 'sec': 'spiny'}
#
# II_L1_NGC-DA_L1_NGC-SA
# {'preConds': {'pop': 'L1_NGC-DA'}, 'postConds': {'pop': 'L1_NGC-SA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.06689 * exp(-dist_2D/69.06)*(dist_2D<200.0)', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 17, 'sec': 'spiny'}
#
# II_L1_NGC-DA_L1_SLAC
# {'preConds': {'pop': 'L1_NGC-DA'}, 'postConds': {'pop': 'L1_SLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.07307 * exp(-dist_2D/64.36)*(dist_2D<200.0)', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 16, 'sec': 'spiny'}
#
# II_L1_NGC-SA_L1_DAC
# {'preConds': {'pop': 'L1_NGC-SA'}, 'postConds': {'pop': 'L1_DAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.07676 * exp(-dist_2D/53.87)*(dist_2D<250.0)', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 14, 'sec': 'spiny'}
#
# II_L1_NGC-SA_L1_DLAC
# {'preConds': {'pop': 'L1_NGC-SA'}, 'postConds': {'pop': 'L1_DLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.10754 * exp(-dist_2D/37.92)*(dist_2D<225.0)', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 11, 'sec': 'spiny'}
#
# II_L1_NGC-SA_L1_HAC
# {'preConds': {'pop': 'L1_NGC-SA'}, 'postConds': {'pop': 'L1_HAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.09748 * exp(-dist_2D/43.30)*(dist_2D<350.0) if dist_2D > 50.0 else -0.000413 * dist_2D + 0.050680', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 16, 'sec': 'spiny'}
#
# II_L1_NGC-SA_L1_NGC-DA
# {'preConds': {'pop': 'L1_NGC-SA'}, 'postConds': {'pop': 'L1_NGC-DA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.05427 * exp(-dist_2D/55.12)*(dist_2D<175.0) if dist_2D > 25.0 else 0.000000 * dist_2D + 0.028980', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 14, 'sec': 'spiny'}
#
# II_L1_NGC-SA_L1_NGC-SA
# {'preConds': {'pop': 'L1_NGC-SA'}, 'postConds': {'pop': 'L1_NGC-SA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.07256 * exp(-dist_2D/45.02)*(dist_2D<225.0) if dist_2D > 50.0 else 0.000033 * dist_2D + 0.021900', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 15, 'sec': 'spiny'}
#
# II_L1_NGC-SA_L1_SLAC
# {'preConds': {'pop': 'L1_NGC-SA'}, 'postConds': {'pop': 'L1_SLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.03002 * exp(-dist_2D/74.33)*(dist_2D<150.0)', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 11, 'sec': 'spiny'}
#
# II_L1_SLAC_L1_DAC
# {'preConds': {'pop': 'L1_SLAC'}, 'postConds': {'pop': 'L1_DAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.28561 * exp(-dist_2D/31.88)*(dist_2D<300.0) if dist_2D > 75.0 else -0.000299 * dist_2D + 0.049525', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 11, 'sec': 'spiny'}
#
# II_L1_SLAC_L1_DLAC
# {'preConds': {'pop': 'L1_SLAC'}, 'postConds': {'pop': 'L1_DLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.20343 * exp(-dist_2D/35.27)*(dist_2D<225.0) if dist_2D > 125.0 else -0.000349 * dist_2D + 0.049393', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 14, 'sec': 'spiny'}
#
# II_L1_SLAC_L1_HAC
# {'preConds': {'pop': 'L1_SLAC'}, 'postConds': {'pop': 'L1_HAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.05908 * exp(-dist_2D/54.05)*(dist_2D<175.0)', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 12, 'sec': 'spiny'}
#
# II_L1_SLAC_L1_NGC-DA
# {'preConds': {'pop': 'L1_SLAC'}, 'postConds': {'pop': 'L1_NGC-DA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.04563 * exp(-dist_2D/54.45)*(dist_2D<200.0)', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 12, 'sec': 'spiny'}
#
# II_L1_SLAC_L1_NGC-SA
# {'preConds': {'pop': 'L1_SLAC'}, 'postConds': {'pop': 'L1_NGC-SA'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.06335 * exp(-dist_2D/46.34)*(dist_2D<200.0)', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 12, 'sec': 'spiny'}
#
# II_L1_SLAC_L1_SLAC
# {'preConds': {'pop': 'L1_SLAC'}, 'postConds': {'pop': 'L1_SLAC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.06383 * exp(-dist_2D/51.82)*(dist_2D<175.0) if dist_2D > 50.0 else 0.000388 * dist_2D + 0.004060', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 9, 'sec': 'spiny'}
#
# IE_L1_DAC_L23_PC
# {'preConds': {'pop': 'L1_DAC'}, 'postConds': {'pop': 'L23_PC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.07212*exp(-dist_2D/73.96)*(dist_2D<375.0) if dist_2D > 75.0 else -0.000209 * dist_2D + 0.041095', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 10, 'sec': 'spiny'}
#
# IE_L1_DLAC_L23_PC
# {'preConds': {'pop': 'L1_DLAC'}, 'postConds': {'pop': 'L23_PC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.10823*exp(-dist_2D/63.01)*(dist_2D<375.0) if dist_2D > 100.0 else -0.000208 * dist_2D + 0.042233', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 12, 'sec': 'spiny'}
#
# IE_L1_HAC_L23_PC
# {'preConds': {'pop': 'L1_HAC'}, 'postConds': {'pop': 'L23_PC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.08329*exp(-dist_2D/76.88)*(dist_2D<375.0) if dist_2D > 75.0 else -0.000220 * dist_2D + 0.046635', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 10, 'sec': 'spiny'}
#
# IE_L1_NGC-DA_L23_PC
# {'preConds': {'pop': 'L1_NGC-DA'}, 'postConds': {'pop': 'L23_PC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.12003*exp(-dist_2D/53.65)*(dist_2D<375.0) if dist_2D > 75.0 else -0.000283 * dist_2D + 0.049900', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 14, 'sec': 'spiny'}
#
# IE_L1_NGC-SA_L23_PC
# {'preConds': {'pop': 'L1_NGC-SA'}, 'postConds': {'pop': 'L23_PC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.04886*exp(-dist_2D/59.02)*(dist_2D<375.0) if dist_2D > 50.0 else -0.000189 * dist_2D + 0.029640', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 10, 'sec': 'spiny'}
#
# IE_L1_SLAC_L23_PC
# {'preConds': {'pop': 'L1_SLAC'}, 'postConds': {'pop': 'L23_PC'}, 'synMech': ['GABAA', 'GABAB'], 'probability': '0.05899*exp(-dist_2D/51.89)*(dist_2D<350.0) if dist_2D > 50.0 else -0.000239 * dist_2D + 0.033790', 'weight': 0.83, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 10, 'sec': 'spiny'}
#
# EE_L23_PC_L23_PC
# {'preConds': {'pop': 'L23_PC'}, 'postConds': {'pop': 'L23_PC'}, 'synMech': ['AMPA', 'NMDA'], 'probability': '0.10239 * exp(-dist_2D/62.30)*(dist_2D<375.0) if dist_2D > 50.0 else -0.000486 * dist_2D + 0.069060', 'weight': 0.68, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 3, 'sec': 'spinyEE'}
#
# EI_L23_PC_L1_DAC
# {'preConds': {'pop': 'L23_PC'}, 'postConds': {'pop': 'L1_DAC'}, 'synMech': ['AMPA', 'NMDA'], 'probability': '3.477515 * 0.00713 * exp(-dist_2D/91.88)*(dist_2D<375.0)', 'weight': 0.43, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 5, 'sec': 'spiny'}
#
# EI_L23_PC_L1_DLAC
# {'preConds': {'pop': 'L23_PC'}, 'postConds': {'pop': 'L1_DLAC'}, 'synMech': ['AMPA', 'NMDA'], 'probability': '3.477515 * 0.00668 * exp(-dist_2D/79.56)*(dist_2D<375.0) if dist_2D > 50.0 else -0.000040 * dist_2D + 0.005650', 'weight': 0.43, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 5, 'sec': 'spiny'}
#
# EI_L23_PC_L1_HAC
# {'preConds': {'pop': 'L23_PC'}, 'postConds': {'pop': 'L1_HAC'}, 'synMech': ['AMPA', 'NMDA'], 'probability': '3.477515 * 0.00521 * exp(-dist_2D/83.45)*(dist_2D<375.0) if dist_2D > 125.0 else -0.000012 * dist_2D + 0.002670', 'weight': 0.43, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 4, 'sec': 'spiny'}
#
# EI_L23_PC_L1_NGC-DA
# {'preConds': {'pop': 'L23_PC'}, 'postConds': {'pop': 'L1_NGC-DA'}, 'synMech': ['AMPA', 'NMDA'], 'probability': '3.477515 * 0.00306 * exp(-dist_2D/86.94)*(dist_2D<375.0) if dist_2D > 50.0 else -0.000013 * dist_2D + 0.002390', 'weight': 0.43, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 5, 'sec': 'spiny'}
#
# EI_L23_PC_L1_NGC-SA
# {'preConds': {'pop': 'L23_PC'}, 'postConds': {'pop': 'L1_NGC-SA'}, 'synMech': ['AMPA', 'NMDA'], 'probability': '3.477515 * 0.00358 * exp(-dist_2D/82.77)*(dist_2D<375.0) if dist_2D > 100.0 else -0.000013 * dist_2D + 0.002427', 'weight': 0.43, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 5, 'sec': 'spiny'}
#
# EI_L23_PC_L1_SLAC
# {'preConds': {'pop': 'L23_PC'}, 'postConds': {'pop': 'L1_SLAC'}, 'synMech': ['AMPA', 'NMDA'], 'probability': '3.477515 * 0.00532 * exp(-dist_2D/62.65)*(dist_2D<375.0)', 'weight': 0.43, 'synMechWeightFactor': [1.0, 1.0], 'delay': 'defaultDelay+dist_3D/propVelocity', 'synsPerConn': 6, 'sec': 'spiny'}

# %%
#------------------------------------------------------------------------------
# Spontaneous synapses + background - data from Rat
#------------------------------------------------------------------------------
cfg.addStimSynS1 = True
cfg.rateStimE = 9.0
cfg.rateStimI = 9.0

#------------------------------------------------------------------------------
# NetStim inputs to simulate Spontaneous synapses + background in S1 neurons - data from Rat
#------------------------------------------------------------------------------
SourcesNumber = 5 # for each post Mtype - sec distribution
synperNeuronStimI = connData['synperNeuronStimI']
synperNeuronStimE = connData['synperNeuronStimE']
GsynStimI = connData['GsynStimI']
GsynStimE = connData['GsynStimE']
   
if cfg.addStimSynS1:      
    for post in Ipops + Epops:

        synperNeuron = synperNeuronStimI[post]
        ratespontaneous = cfg.rateStimI
        for qSnum in range(SourcesNumber):
            ratesdifferentiation = (0.8 + 0.4*qSnum/(SourcesNumber-1)) * (synperNeuron*ratespontaneous)/SourcesNumber
            netParams.stimSourceParams['StimSynS1_S_all_INH->' + post + '_' + str(qSnum)] = {'type': 'NetStim', 'rate': ratesdifferentiation, 'noise': 1.0}

        synperNeuron = synperNeuronStimE[post]
        ratespontaneous = cfg.rateStimE
        for qSnum in range(SourcesNumber):
            ratesdifferentiation = (0.8 + 0.4*qSnum/(SourcesNumber-1)) * (synperNeuron*ratespontaneous)/SourcesNumber
            netParams.stimSourceParams['StimSynS1_S_all_EXC->' + post + '_' + str(qSnum)] = {'type': 'NetStim', 'rate': ratesdifferentiation, 'noise': 1.0}
            
    #------------------------------------------------------------------------------
    for post in Epops:
        for qSnum in range(SourcesNumber):
            netParams.stimTargetParams['StimSynS1_T_all_EXC->' + post + '_' + str(qSnum)] = {
                'source': 'StimSynS1_S_all_EXC->' + post + '_' + str(qSnum), 
                'conds': {'cellType': post}, 
                'ynorm':[0,1], 
                'sec': 'spinyEE', 
                'loc': 0.5, 
                'synMechWeightFactor': [1.0],
                'weight': GsynStimE[post],
                'delay': 0.1, 
                'synMech': 'AMPA'}

    for post in Ipops:
        for qSnum in range(SourcesNumber):
            netParams.stimTargetParams['StimSynS1_T_all_EXC->' + post + '_' + str(qSnum)] = {
                'source': 'StimSynS1_S_all_EXC->' + post + '_' + str(qSnum), 
                'conds': {'cellType': post}, 
                'ynorm':[0,1], 
                'sec': 'spiny', 
                'loc': 0.5, 
                'synMechWeightFactor': [1.0],
                'weight': GsynStimE[post],
                'delay': 0.1, 
                'synMech': 'AMPA'}

    for post in Epops+Ipops:
        for qSnum in range(SourcesNumber):
            netParams.stimTargetParams['StimSynS1_T_all_INH->' + post + '_' + str(qSnum)] = {
                'source': 'StimSynS1_S_all_INH->' + post + '_' + str(qSnum), 
                'conds': {'cellType': post}, 
                'ynorm':[0,1], 
                'sec': 'spiny', 
                'loc': 0.5, 
                'synMechWeightFactor': [1.0],
                'weight': GsynStimI[post],
                'delay': 0.1, 
                'synMech': 'GABAA'}

# %%
# for stimpath in netParams.stimSourceParams.keys():
#     print(stimpath)
#     print(netParams.stimSourceParams[stimpath])
#     print()

# %%
# for stimpath in netParams.stimTargetParams.keys():
#     print(stimpath)
#     print(netParams.stimTargetParams[stimpath])
#     print()

# %% [markdown]
# ## Run small Nets in a sigle job

# %%
sim.initialize(
    simConfig = cfg, 	
    netParams = netParams)  				# create network object and set cfg and net params
sim.net.createPops()               			# instantiate network populations
sim.net.createCells()              			# instantiate network cells based on defined populations
sim.net.connectCells()            			# create connections between cells based on params
sim.net.addStims() 							# add network stimulation
sim.setupRecording()              			# setup variables to record for each cell (spikes, V traces, etc)
sim.runSim()                      			# run parallel Neuron simulation  
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()
# Out:
# Start time:  2021-07-05 22:55:49.489250
#
# Creating network of 7 cell populations on 1 hosts...
#   Number of cells on node 0: 2028
#   Done; cell creation time = 25.09 s.
# Making connections...
#   Number of connections on node 0: 39213
#   Number of synaptic contacts on node 0: 345638
#   Done; cell connection time = 66.19 s.
# Adding stims...
#   Number of stims on node 0: 20280
#   Done; cell stims creation time = 3.97 s.
# Recording 2028 traces of 1 types on node 0
# 0.0s
#
# Running simulation for 500.0 ms...

# %% [markdown]
# ## Net infos

# %%
# features = ['numConns','convergence']
test = sim.analysis.plotConn(includePre=subPopLabels, includePost = subPopLabels, feature='numConns', figSize=(6, 6), fontSize=8, saveData=None, 
                               saveFig=True, showFig=False);

# %%
test[1]['connMatrix'] # total of synapses [AMPA, NMDA] or [GABAA, GABAB]

# %%
connNumber = connData['connNumber']
synperconnNumber = connData['synperconnNumber']

i=0
for pre in subPopLabels:
    j=0
    for post in subPopLabels:
        synperconn = int(synperconnNumber[pre][post]+0.5)        
        print('%s->%s \n   MCs_BBP=%.1f   NetPyNE=%.1f' % (pre,post,float(connNumber[pre][post]),(test[1]['connMatrix'][i][j]/(2*synperconn))))
        j+=1
    i+=1

# %%
sim.analysis.plot2Dnet(include=subPopLabels,view='xy', showConns=False, 
                               popColors=None, tagsFile=None, figSize=(6, 6), fontSize=8, saveData=None, 
                               saveFig=True, showFig=True, lineWidth=0.1);

# %%
# sim.analysis.plot2Dnet(include=subPopLabels,view='xy', showConns=False, 
#                                popColors=None, tagsFile=None, figSize=(6, 6), fontSize=12, saveData=None, 
#                                saveFig=None, showFig=True, lineWidth=0.1);
# sim.analysis.plot2Dnet(include=subPopLabels,view='xz', showConns=False, 
#                                popColors=None, tagsFile=None, figSize=(6, 6), fontSize=12, saveData=None, 
#                                saveFig=None, showFig=True, lineWidth=0.1);

# %% [markdown]
# ## Raster and traces

# %%
sim.analysis.plotRaster(include=subPopLabels, timeRange=[0,cfg.duration], orderBy='y', orderInverse=True, labels='legend', popRates=True, lw=5, marker='.', markerSize=24, figSize=(12, 6), fontSize=20, dpi=500, saveFig=True, showFig=False);

# %%
for metype in cfg.cellParamLabels:
    if cfg.popLabel[metype] in subPopLabels:
        print(metype,cfg.cellNumber[metype],cfg.popLabel[metype],cfg.popNumber[cfg.popLabel[metype]])

# %%
traces = [(mtype, [i for i in range(0,cfg.popNumber[mtype],int(cfg.popNumber[mtype]/4.5))]) for mtype in subPopLabels]
traces

# %%
sim.analysis.plotTraces(include=traces, timeRange=[0,cfg.duration], overlay=False, oneFigPer='trace', ylim=[-90,50], subtitles= False, axis=False, scaleBarLoc=1, figSize=(12, 8), fontSize=12, saveFig=True);

# %%
subPopLabels

# %%
for pops in subPopLabels:
    sim.analysis.plotTraces(include=[pops], timeRange=[0,cfg.duration], overlay=True, oneFigPer='trace', ylim=[-80,50], axis=False, scaleBarLoc=3, figSize=(12, 4), fontSize=15, saveFig='../info/test/'+cfg.simLabel+'/'+cfg.simLabel +'_'+pops+ '_Vt.png');
