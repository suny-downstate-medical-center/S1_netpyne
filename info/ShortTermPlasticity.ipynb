# %% [markdown]
# # S1 synapses with short-term plasticity

# %%
# ! git clone https://github.com/suny-downstate-medical-center/S1_netpyne.git

# %%
import json
import os, sys
import numpy as np

# %% [markdown]
# ## Cell Number per population from BBP S1 model

# %%
Epops= ['L23_PC', 'L4_PC', 'L4_SS', 'L4_SP', 
             'L5_TTPC1', 'L5_TTPC2', 'L5_STPC', 'L5_UTPC',
             'L6_TPC_L1', 'L6_TPC_L4', 'L6_BPC', 'L6_IPC', 'L6_UTPC']

with open('anatomy/S1-cells-distributions-Rat.txt') as mtype_file:
    mtype_content = mtype_file.read()       

popParamLabels = []
Ipops = []

for line in mtype_content.split('\n')[:-1]:
    metype, mtype, etype, n, m = line.split()
    if mtype not in popParamLabels:
        popParamLabels.append(mtype)
        if mtype not in Epops:
            Ipops.append(mtype)
n2 = 0
metag = {}
popNumber2 = {}
cellNumber = {} 
popLabel = {} 
popLabelEl = {} 
meParamLabels = {} 
for line in mtype_content.split('\n')[:-1]:
    metype, mtype, etype, n, m = line.split()
    cellNumber[metype] = int(n)
    popLabel[metype] = mtype
    popLabelEl[metype] = etype
    popNumber2[mtype] = int(m)
    metag[metype] = n2    
    n2 = n2 + 1

# %%
#------------------------------------------------------------------------------
# load data from S1 conn pre-processing file 
#------------------------------------------------------------------------------
with open('conn/conn.pkl', 'rb') as fileObj: connData = pickle.load(fileObj)

lmat = connData['lmat']
a0mat = connData['a0mat']
d0 = connData['d0']
dfinal = connData['dfinal']
pmat = {}
pmat[12.5] = connData['pmat12um']
pmat[25] = connData['pmat25um']
pmat[50] = connData['pmat50um']
pmat[75] = connData['pmat75um']
pmat[100] = connData['pmat100um']
pmat[125] = connData['pmat125um']
pmat[150] = connData['pmat150um']
pmat[175] = connData['pmat175um']
pmat[200] = connData['pmat200um'] #max value for d0=200

synperconnNumber = connData['synperconnNumber']
connNumber = connData['connNumber']
decay = connData['decay']
gsyn = connData['gsyn']
# use = connData['use']

# print(netParams.connParams)

# %% [markdown]
# ## CA1 MOD

# %%
synmechparams = {}
for pre in Epops+Ipops:
    for post in Epops+Ipops:
        proj = '%s:%s' % (pre, post)
        if proj in data['BBP_S1']['connProb']:  
          if pre in Epops:
            mod = 'DetAMPANMDA'
            tau = 'tau_d_AMPA'
          else:
            mod = 'DetGABAAB'
            tau = 'tau_d_GABAA'

          conn = connType[ConnTypes[pre][post][0]]
          
          synmechparams[proj] = {'mod': mod,
                                 tau: dfS6['decay'][conn],
                                 #'tau_d_NMDA': 61.0, 
                                 'Use': dfS6['use'][conn],
                                 'Dep': dfS6['dep'][conn], 
                                 'Fac': dfS6['fac'][conn], 
                                 'gmax': dfS6['gsyn'][conn]}

# %%
synmechparams
# Out:
# {'L23_PC:L23_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.46,
#   'gmax': 0.68,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_SS': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_SP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_TTPC1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_TTPC2': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_STPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_TPC_L1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_TPC_L4': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_BPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_IPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L1_DAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L1_DLAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L1_HAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L1_NGC-DA': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L1_NGC-SA': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L1_SLAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L23_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L23_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L23_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L23_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L23_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L23_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L23_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L23_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L23_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L4_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L5_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L23_PC:L6_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L23_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.86,
#   'gmax': 0.68,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_SS': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.86,
#   'gmax': 0.68,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_SP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.86,
#   'gmax': 0.68,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_TTPC1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_TTPC2': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_STPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_TPC_L1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_TPC_L4': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_BPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_IPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L23_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L23_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L23_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L23_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L23_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L23_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L23_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L23_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L23_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L4_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L5_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_PC:L6_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L23_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.79,
#   'gmax': 0.19,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_SS': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.86,
#   'gmax': 0.68,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_SP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.86,
#   'gmax': 0.68,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_TTPC1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_TTPC2': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_STPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_TPC_L1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_TPC_L4': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_BPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_IPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L1_DAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L1_DLAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L1_HAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L1_SLAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L23_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L23_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L23_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L23_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L23_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L23_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L23_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L23_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L23_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L4_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L5_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SS:L6_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L23_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_SS': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.86,
#   'gmax': 0.68,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_SP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.86,
#   'gmax': 0.68,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_TTPC1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_TTPC2': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_STPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_TPC_L1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_TPC_L4': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_BPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_IPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L23_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L23_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L23_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L23_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L23_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L23_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L23_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L23_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L4_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L5_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L4_SP:L6_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L23_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_SS': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_SP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_TTPC1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 1.5,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_TTPC2': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 1.5,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_STPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_TPC_L1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_TPC_L4': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_BPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_IPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L1_DAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L1_HAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L1_NGC-DA': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L23_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L23_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L23_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L23_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L23_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L23_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L23_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L23_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L4_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L5_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC1:L6_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L23_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_SS': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_SP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_TTPC1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 1.5,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_TTPC2': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 1.5,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_STPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_TPC_L1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_TPC_L4': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_BPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_IPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L1_DAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L1_HAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L1_NGC-DA': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L1_NGC-SA': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L1_SLAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L23_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L23_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L23_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L23_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L23_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L23_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L23_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L23_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L4_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L5_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_TTPC2:L6_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L23_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L4_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L4_SS': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L4_SP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_TTPC1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_TTPC2': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_STPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.39,
#   'gmax': 0.8,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_TPC_L1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_TPC_L4': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_BPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_IPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L23_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L23_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L23_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L23_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L23_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L23_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L23_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L4_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L4_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L4_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L4_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L4_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L4_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L4_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L5_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_STPC:L6_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L23_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_PC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_SS': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_SP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L5_TTPC1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L5_TTPC2': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L5_STPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L5_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L6_TPC_L1': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L6_TPC_L4': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L6_BPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L6_IPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L6_UTPC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L1_DAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L1_HAC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L23_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L23_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L23_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L23_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L23_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L23_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L23_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L23_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_NBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_NGC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L4_SBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L5_BP': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L5_BTC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L5_ChC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L5_DBC': {'Dep': 671.0,
#   'Fac': 17.0,
#   'Use': 0.5,
#   'gmax': 0.43,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L5_LBC': {'Dep': 227.0,
#   'Fac': 13.0,
#   'Use': 0.72,
#   'gmax': 0.72,
#   'mod': 'DetAMPANMDA',
#   'tau_d_AMPA': 1.74},
#  'L5_UTPC:L5_MC': {'Dep': 138.0,
#   'Fac': 670.0,
#   'Use': 0.09,
#   'gmax': 0.11,
#   'mod': 'DetAMPANMDA',
# ...
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L4_DBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L4_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L4_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L4_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L4_NGC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L4_SBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L5_BP': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L5_BTC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L5_ChC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L5_DBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L5_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L5_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L5_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L5_SBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L6_BP': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L6_BTC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L6_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L6_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L6_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_DBC:L6_SBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L23_PC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L4_PC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L4_SS': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L4_SP': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L5_TTPC1': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L5_TTPC2': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L5_STPC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L5_UTPC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L6_TPC_L1': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L6_TPC_L4': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L6_BPC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L6_IPC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L6_UTPC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_LBC:L1_DAC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L1_DLAC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L1_HAC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L1_NGC-DA': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L1_NGC-SA': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L1_SLAC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L23_BP': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L23_BTC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L23_ChC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L23_DBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L23_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L23_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L23_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L23_NGC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L23_SBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L4_BTC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L4_ChC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L4_DBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L4_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L4_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L4_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L4_NGC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L4_SBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L5_BTC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L5_ChC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L5_DBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L5_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L5_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L5_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L5_SBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L6_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L6_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_LBC:L6_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L23_PC': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_PC': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_SS': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_SP': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_TTPC1': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_TTPC2': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_STPC': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_UTPC': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L6_TPC_L1': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L6_TPC_L4': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L6_BPC': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L6_IPC': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L6_UTPC': {'Dep': 1250.0,
#   'Fac': 2.0,
#   'Use': 0.3,
#   'gmax': 0.75,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L1_DAC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L1_DLAC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L1_HAC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L1_NGC-DA': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L1_NGC-SA': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L1_SLAC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L23_BP': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L23_BTC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L23_ChC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L23_DBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L23_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L23_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L23_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L23_NGC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L23_SBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_BTC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_ChC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_DBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_NGC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L4_SBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_BTC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_ChC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_DBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L5_SBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L6_LBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L6_MC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L6_NBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_MC:L6_SBC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_NBC:L23_PC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L4_PC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L4_SS': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L4_SP': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L5_TTPC1': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L5_TTPC2': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L5_STPC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L5_UTPC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L6_TPC_L1': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L6_TPC_L4': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L6_BPC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L6_UTPC': {'Dep': 144.0,
#   'Fac': 62.0,
#   'Use': 0.32,
#   'gmax': 0.91,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 6.44},
#  'L23_NBC:L1_DAC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  'L23_NBC:L1_DLAC': {'Dep': 706.0,
#   'Fac': 21.0,
#   'Use': 0.25,
#   'gmax': 0.83,
#   'mod': 'DetGABAAB',
#   'tau_d_GABAA': 8.3},
#  ...}

# %%
#for pre in Epops+Ipops:
#    for post in Epops+Ipops:
#        proj = '%s:%s' % (pre, post)
#        if proj in data['BBP_S1']['connProb']:  
#          if pre in Epops:
#            mod = 'DetAMPANMDA'
#          else:
#            mod = 'DetGABAAB'
#
#          conn = connType[ConnTypes[pre][post][0]]
#          
#          netParams.synMechParams[proj] = {'mod': mod,
#                                           'tau_d_AMPA': dfS6['decay'][conn],
#                                           #'tau_d_NMDA': 61.0, 
#                                           'Use': dfS6['use'][conn],
#                                           'Dep': dfS6['dep'][conn], 
#                                           'Fac': dfS6['fac'][conn], 
#                                           'gmax': dfS6['gsyn'][conn]}
